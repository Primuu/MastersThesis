# %% [markdown]
# # Model training: GRU (multitasking)
#
# ---
#
# ## Table of Contents
#
# 1. [Imports](#imports)
# 2. [Data loading and splitting](#data-loading-and-splitting)
# 3. [Setting training parameters](#setting-training-parameters)
# 4. [Model training](#model-training)
# 5. [Model evaluation](#model-evaluation)
# 6. [Summary](#summary)
# 7. [Model serialization](#model-serialization)

# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# # Data loading and splitting

# %%
base_dir = os.path.abspath(os.path.join(os.path.dirname(os.getcwd()), '..'))

# %%
train_file_sentiment = os.path.join(base_dir, 'train_sentiment.csv')
val_file_sentiment = os.path.join(base_dir, 'val_sentiment.csv')
test_file_sentiment = os.path.join(base_dir, 'test_sentiment.csv')

if not all([os.path.exists(train_file_sentiment), os.path.exists(val_file_sentiment), os.path.exists(test_file_sentiment)]):
    sentiment_df = pd.read_parquet('../../data/sentiment_without_outliers/sentiment_without_outliers.parquet')
    sentiment_df = sentiment_df.drop(columns=['text_length'])
    
    train_data_sentiment, temp_data = train_test_split(sentiment_df, test_size=0.3, stratify=sentiment_df['label'], random_state=42)
    val_data_sentiment, test_data_sentiment = train_test_split(temp_data, test_size=0.5, stratify=temp_data['label'], random_state=42)

    train_data_sentiment.to_csv(train_file_sentiment, index=False)
    val_data_sentiment.to_csv(val_file_sentiment, index=False)
    test_data_sentiment.to_csv(test_file_sentiment, index=False)
else:
    train_data_sentiment = pd.read_csv(train_file_sentiment)
    val_data_sentiment = pd.read_csv(val_file_sentiment)
    test_data_sentiment = pd.read_csv(test_file_sentiment)

# %%
train_file_emotion = os.path.join(base_dir, 'train_emotion.csv')
val_file_emotion = os.path.join(base_dir, 'val_emotion.csv')
test_file_emotion = os.path.join(base_dir, 'test_emotion.csv')

if not all([os.path.exists(train_file_emotion), os.path.exists(val_file_emotion), os.path.exists(test_file_emotion)]):
    emotion_df = pd.read_parquet('../../data/emotion_without_outliers/emotion_without_outliers.parquet')
    emotion_df = emotion_df.drop(columns=['text_length'])
    
    target_samples_per_class = 16_667  # 100k / 6 classes of emotions
    
    balanced_data = emotion_df.groupby('label', group_keys=False).apply(
        lambda x: x.sample(n=min(len(x), target_samples_per_class), random_state=42)
    )
    
    train_data_emotion, temp_data = train_test_split(balanced_data, test_size=0.3, stratify=balanced_data['label'], random_state=42)
    val_data_emotion, test_data_emotion = train_test_split(temp_data, test_size=0.5, stratify=temp_data['label'], random_state=42)

    train_data_emotion.to_csv(train_file_emotion, index=False)
    val_data_emotion.to_csv(val_file_emotion, index=False)
    test_data_emotion.to_csv(test_file_emotion, index=False)
else:
    train_data_emotion = pd.read_csv(train_file_emotion)
    val_data_emotion = pd.read_csv(val_file_emotion)
    test_data_emotion = pd.read_csv(test_file_emotion)

# %% [markdown]
# # Setting training parameters
#
# Due to the uneven distribution of classes in the dataset, the classes will be weighted.

# %%
MAX_NUM_WORDS = 20000
MAX_SEQ_LENGTH = 256

tokenizer = Tokenizer(num_words=MAX_NUM_WORDS, oov_token="<OOV>")
tokenizer.fit_on_texts(train_data_sentiment['text'].tolist() + train_data_emotion['text'].tolist())

# %%
def encode_texts(texts):
    sequences = tokenizer.texts_to_sequences(texts)
    return pad_sequences(sequences, maxlen=MAX_SEQ_LENGTH, padding='post', truncating='post')

# %%
X_train_sentiment = encode_texts(train_data_sentiment['text'])
X_val_sentiment = encode_texts(val_data_sentiment['text'])
X_test_sentiment = encode_texts(test_data_sentiment['text'])

y_train_sentiment = train_data_sentiment['label'].values
y_val_sentiment = val_data_sentiment['label'].values
y_test_sentiment = test_data_sentiment['label'].values

# %%
X_train_emotion = encode_texts(train_data_emotion['text'])
X_val_emotion = encode_texts(val_data_emotion['text'])
X_test_emotion = encode_texts(test_data_emotion['text'])

y_train_emotion = train_data_emotion['label'].values
y_val_emotion = val_data_emotion['label'].values
y_test_emotion = test_data_emotion['label'].values

# %%
class_weights_sentiment = torch.tensor(compute_class_weight('balanced', classes=np.unique(y_train_sentiment), y=y_train_sentiment), dtype=torch.float)
class_weights_emotion = torch.tensor(compute_class_weight('balanced', classes=np.unique(y_train_emotion), y=y_train_emotion), dtype=torch.float)

# %%
class MultiTaskDataset(Dataset):
    def __init__(self, X_sent, y_sent, X_emot, y_emot):
        self.X_sent = torch.tensor(X_sent, dtype=torch.long)
        self.y_sent = torch.tensor(y_sent, dtype=torch.long)
        self.X_emot = torch.tensor(X_emot, dtype=torch.long)
        self.y_emot = torch.tensor(y_emot, dtype=torch.long)

    def __len__(self):
        return min(len(self.y_sent), len(self.y_emot))

    def __getitem__(self, idx):
        return {
            'input_ids_sent': self.X_sent[idx],
            'label_sent': self.y_sent[idx],
            'input_ids_emot': self.X_emot[idx],
            'label_emot': self.y_emot[idx]
        }

# %%
train_dataset = MultiTaskDataset(X_train_sentiment, y_train_sentiment, X_train_emotion, y_train_emotion)
val_dataset = MultiTaskDataset(X_val_sentiment, y_val_sentiment, X_val_emotion, y_val_emotion)
test_dataset = MultiTaskDataset(X_test_sentiment, y_test_sentiment, X_test_emotion, y_test_emotion)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)

# %% [markdown]
# # Model training

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class MultiTaskGRU(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_labels_sentiment, num_labels_emotion):
        super(MultiTaskGRU, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.gru = nn.GRU(embed_dim, hidden_dim, batch_first=True)
        self.fc_sentiment = nn.Linear(hidden_dim, num_labels_sentiment)
        self.fc_emotion = nn.Linear(hidden_dim, num_labels_emotion)
    
    def forward(self, input_ids_sent, input_ids_emot):
        embedded_sent = self.embedding(input_ids_sent)
        embedded_emot = self.embedding(input_ids_emot)

        gru_out_sent, _ = self.gru(embedded_sent)
        gru_out_emot, _ = self.gru(embedded_emot)

        out_sentiment = self.fc_sentiment(gru_out_sent[:, -1, :])
        out_emotion = self.fc_emotion(gru_out_emot[:, -1, :])

        return out_sentiment, out_emotion

# %%
model = MultiTaskGRU(vocab_size=MAX_NUM_WORDS, embed_dim=256, hidden_dim=256, num_labels_sentiment=3, num_labels_emotion=6).to(device)

# %%
loss_fn_sentiment = nn.CrossEntropyLoss(weight=class_weights_sentiment.to(device))
loss_fn_emotion = nn.CrossEntropyLoss(weight=class_weights_emotion.to(device))
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
def train_epoch(model, data_loader, loss_fn_sent, loss_fn_emot, optimizer, device, epoch):
    model.train()
    total_loss = 0
    correct_sentiment = 0
    correct_emotion = 0
    total_sentiment_samples = 0
    total_emotion_samples = 0

    for batch_idx, batch in enumerate(data_loader):
        input_ids_sent = batch['input_ids_sent'].to(device)
        labels_sent = batch['label_sent'].to(device)
        input_ids_emot = batch['input_ids_emot'].to(device)
        labels_emot = batch['label_emot'].to(device)

        optimizer.zero_grad()

        logits_sent, logits_emot = model(input_ids_sent, input_ids_emot)

        loss_sent = loss_fn_sent(logits_sent, labels_sent)
        loss_emot = loss_fn_emot(logits_emot, labels_emot)

        loss = loss_sent + loss_emot
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        _, preds_sent = torch.max(logits_sent, dim=1)
        _, preds_emot = torch.max(logits_emot, dim=1)

        correct_sentiment += (preds_sent == labels_sent).sum().item()
        correct_emotion += (preds_emot == labels_emot).sum().item()
        total_sentiment_samples += labels_sent.size(0)
        total_emotion_samples += labels_emot.size(0)
        
        if batch_idx % 10 == 0:
            avg_loss = total_loss / (batch_idx + 1)
            acc_sent = 100. * correct_sentiment / total_sentiment_samples
            acc_emot = 100. * correct_emotion / total_emotion_samples
            print(f"Epoch {epoch}. Batch {batch_idx}/{len(data_loader)}: "
                  f"AvgLoss: {avg_loss:.2f}, S.Acc: {acc_sent:.2f}%, E.Acc: {acc_emot:.2f}%")

    avg_loss = total_loss / len(data_loader)
    accuracy_sentiment = 100. * correct_sentiment / total_sentiment_samples
    accuracy_emotion = 100. * correct_emotion / total_emotion_samples
    return avg_loss, accuracy_sentiment, accuracy_emotion

# %%
def eval_model(model, data_loader, device):
    model.eval()
    correct_sentiment = 0
    correct_emotion = 0
    total_sentiment_samples = 0
    total_emotion_samples = 0

    with torch.no_grad():
        for batch in data_loader:
            input_ids_sent = batch['input_ids_sent'].to(device)
            labels_sent = batch['label_sent'].to(device)
            input_ids_emot = batch['input_ids_emot'].to(device)
            labels_emot = batch['label_emot'].to(device)

            logits_sent, logits_emot = model(input_ids_sent, input_ids_emot)

            _, preds_sent = torch.max(logits_sent, dim=1)
            _, preds_emot = torch.max(logits_emot, dim=1)

            correct_sentiment += (preds_sent == labels_sent).sum().item()
            correct_emotion += (preds_emot == labels_emot).sum().item()
            total_sentiment_samples += labels_sent.size(0)
            total_emotion_samples += labels_emot.size(0)

    accuracy_sentiment = 100. * correct_sentiment / total_sentiment_samples
    accuracy_emotion = 100. * correct_emotion / total_emotion_samples
    return accuracy_sentiment, accuracy_emotion

# %%
for epoch in range(2):
    train_loss, train_acc_sent, train_acc_emot = train_epoch(
        model, train_loader, loss_fn_sentiment, loss_fn_emotion, optimizer, device, epoch
    )
    print(f"Train Loss: {train_loss:.4f}, "
          f"Train Sentiment Accuracy: {train_acc_sent:.2f}%, "
          f"Train Emotion Accuracy: {train_acc_emot:.2f}%")
    val_acc_sent, val_acc_emot = eval_model(model, val_loader, device)
    print(f"Validation Sentiment Accuracy: {val_acc_sent:.2f}%, Validation Emotion Accuracy: {val_acc_emot:.2f}%")
# Out:
# Epoch 0. Batch 0/4290: AvgLoss: 3.00, S.Acc: 31.25%, E.Acc: 12.50%
# Epoch 0. Batch 10/4290: AvgLoss: 3.20, S.Acc: 30.68%, E.Acc: 19.32%
# Epoch 0. Batch 20/4290: AvgLoss: 3.13, S.Acc: 31.85%, E.Acc: 18.45%
# Epoch 0. Batch 30/4290: AvgLoss: 3.07, S.Acc: 30.65%, E.Acc: 17.14%
# Epoch 0. Batch 40/4290: AvgLoss: 3.06, S.Acc: 33.38%, E.Acc: 16.62%
# Epoch 0. Batch 50/4290: AvgLoss: 3.04, S.Acc: 33.33%, E.Acc: 16.42%
# Epoch 0. Batch 60/4290: AvgLoss: 3.03, S.Acc: 31.76%, E.Acc: 16.39%
# Epoch 0. Batch 70/4290: AvgLoss: 3.03, S.Acc: 30.90%, E.Acc: 16.64%
# Epoch 0. Batch 80/4290: AvgLoss: 3.03, S.Acc: 30.56%, E.Acc: 16.51%
# Epoch 0. Batch 90/4290: AvgLoss: 3.02, S.Acc: 31.32%, E.Acc: 16.41%
# Epoch 0. Batch 100/4290: AvgLoss: 3.01, S.Acc: 30.88%, E.Acc: 16.58%
# Epoch 0. Batch 110/4290: AvgLoss: 3.01, S.Acc: 30.57%, E.Acc: 16.50%
# Epoch 0. Batch 120/4290: AvgLoss: 3.01, S.Acc: 31.04%, E.Acc: 16.74%
# Epoch 0. Batch 130/4290: AvgLoss: 3.01, S.Acc: 31.25%, E.Acc: 16.60%
# Epoch 0. Batch 140/4290: AvgLoss: 3.00, S.Acc: 31.60%, E.Acc: 16.53%
# Epoch 0. Batch 150/4290: AvgLoss: 3.00, S.Acc: 32.91%, E.Acc: 16.85%
# Epoch 0. Batch 160/4290: AvgLoss: 2.99, S.Acc: 33.27%, E.Acc: 16.81%
# Epoch 0. Batch 170/4290: AvgLoss: 2.99, S.Acc: 33.08%, E.Acc: 16.92%
# Epoch 0. Batch 180/4290: AvgLoss: 2.99, S.Acc: 33.08%, E.Acc: 17.02%
# Epoch 0. Batch 190/4290: AvgLoss: 2.99, S.Acc: 33.41%, E.Acc: 17.11%
# Epoch 0. Batch 200/4290: AvgLoss: 2.99, S.Acc: 33.55%, E.Acc: 17.07%
# Epoch 0. Batch 210/4290: AvgLoss: 2.99, S.Acc: 33.50%, E.Acc: 17.36%
# Epoch 0. Batch 220/4290: AvgLoss: 2.98, S.Acc: 33.48%, E.Acc: 17.48%
# Epoch 0. Batch 230/4290: AvgLoss: 2.98, S.Acc: 33.63%, E.Acc: 17.69%
# Epoch 0. Batch 240/4290: AvgLoss: 2.98, S.Acc: 34.02%, E.Acc: 17.89%
# Epoch 0. Batch 250/4290: AvgLoss: 2.98, S.Acc: 33.52%, E.Acc: 17.80%
# Epoch 0. Batch 260/4290: AvgLoss: 2.98, S.Acc: 33.64%, E.Acc: 17.67%
# Epoch 0. Batch 270/4290: AvgLoss: 2.97, S.Acc: 33.30%, E.Acc: 17.57%
# Epoch 0. Batch 280/4290: AvgLoss: 2.97, S.Acc: 33.70%, E.Acc: 17.50%
# Epoch 0. Batch 290/4290: AvgLoss: 2.97, S.Acc: 33.55%, E.Acc: 17.44%
# Epoch 0. Batch 300/4290: AvgLoss: 2.97, S.Acc: 33.47%, E.Acc: 17.40%
# Epoch 0. Batch 310/4290: AvgLoss: 2.97, S.Acc: 33.30%, E.Acc: 17.40%
# Epoch 0. Batch 320/4290: AvgLoss: 2.97, S.Acc: 33.78%, E.Acc: 17.37%
# Epoch 0. Batch 330/4290: AvgLoss: 2.96, S.Acc: 33.99%, E.Acc: 17.26%
# Epoch 0. Batch 340/4290: AvgLoss: 2.96, S.Acc: 33.61%, E.Acc: 17.21%
# Epoch 0. Batch 350/4290: AvgLoss: 2.96, S.Acc: 33.60%, E.Acc: 17.04%
# Epoch 0. Batch 360/4290: AvgLoss: 2.96, S.Acc: 33.64%, E.Acc: 17.05%
# Epoch 0. Batch 370/4290: AvgLoss: 2.96, S.Acc: 33.44%, E.Acc: 16.95%
# Epoch 0. Batch 380/4290: AvgLoss: 2.96, S.Acc: 33.25%, E.Acc: 16.88%
# Epoch 0. Batch 390/4290: AvgLoss: 2.96, S.Acc: 33.14%, E.Acc: 16.85%
# Epoch 0. Batch 400/4290: AvgLoss: 2.96, S.Acc: 33.01%, E.Acc: 16.91%
# Epoch 0. Batch 410/4290: AvgLoss: 2.96, S.Acc: 32.80%, E.Acc: 16.96%
# Epoch 0. Batch 420/4290: AvgLoss: 2.96, S.Acc: 32.99%, E.Acc: 17.07%
# Epoch 0. Batch 430/4290: AvgLoss: 2.96, S.Acc: 33.08%, E.Acc: 17.01%
# Epoch 0. Batch 440/4290: AvgLoss: 2.96, S.Acc: 32.96%, E.Acc: 17.04%
# Epoch 0. Batch 450/4290: AvgLoss: 2.96, S.Acc: 32.86%, E.Acc: 17.03%
# Epoch 0. Batch 460/4290: AvgLoss: 2.96, S.Acc: 32.97%, E.Acc: 17.00%
# Epoch 0. Batch 470/4290: AvgLoss: 2.96, S.Acc: 33.05%, E.Acc: 17.12%
# Epoch 0. Batch 480/4290: AvgLoss: 2.96, S.Acc: 32.93%, E.Acc: 17.16%
# Epoch 0. Batch 490/4290: AvgLoss: 2.96, S.Acc: 32.90%, E.Acc: 17.11%
# Epoch 0. Batch 500/4290: AvgLoss: 2.96, S.Acc: 32.95%, E.Acc: 17.05%
# Epoch 0. Batch 510/4290: AvgLoss: 2.95, S.Acc: 32.94%, E.Acc: 16.99%
# Epoch 0. Batch 520/4290: AvgLoss: 2.95, S.Acc: 32.77%, E.Acc: 17.03%
# Epoch 0. Batch 530/4290: AvgLoss: 2.95, S.Acc: 32.71%, E.Acc: 17.13%
# Epoch 0. Batch 540/4290: AvgLoss: 2.95, S.Acc: 32.84%, E.Acc: 17.14%
# Epoch 0. Batch 550/4290: AvgLoss: 2.95, S.Acc: 32.96%, E.Acc: 17.08%
# Epoch 0. Batch 560/4290: AvgLoss: 2.95, S.Acc: 32.85%, E.Acc: 17.19%
# Epoch 0. Batch 570/4290: AvgLoss: 2.95, S.Acc: 32.72%, E.Acc: 17.21%
# Epoch 0. Batch 580/4290: AvgLoss: 2.95, S.Acc: 32.61%, E.Acc: 17.22%
# Epoch 0. Batch 590/4290: AvgLoss: 2.95, S.Acc: 32.47%, E.Acc: 17.17%
# Epoch 0. Batch 600/4290: AvgLoss: 2.95, S.Acc: 32.70%, E.Acc: 17.14%
# Epoch 0. Batch 610/4290: AvgLoss: 2.95, S.Acc: 32.82%, E.Acc: 17.07%
# Epoch 0. Batch 620/4290: AvgLoss: 2.95, S.Acc: 32.76%, E.Acc: 17.06%
# Epoch 0. Batch 630/4290: AvgLoss: 2.95, S.Acc: 32.77%, E.Acc: 17.06%
# Epoch 0. Batch 640/4290: AvgLoss: 2.95, S.Acc: 32.62%, E.Acc: 17.14%
# Epoch 0. Batch 650/4290: AvgLoss: 2.95, S.Acc: 32.63%, E.Acc: 17.12%
# Epoch 0. Batch 660/4290: AvgLoss: 2.95, S.Acc: 32.64%, E.Acc: 17.13%
# Epoch 0. Batch 670/4290: AvgLoss: 2.95, S.Acc: 32.70%, E.Acc: 17.12%
# Epoch 0. Batch 680/4290: AvgLoss: 2.95, S.Acc: 32.82%, E.Acc: 17.13%
# Epoch 0. Batch 690/4290: AvgLoss: 2.95, S.Acc: 32.72%, E.Acc: 17.07%
# Epoch 0. Batch 700/4290: AvgLoss: 2.95, S.Acc: 32.77%, E.Acc: 17.02%
# Epoch 0. Batch 710/4290: AvgLoss: 2.95, S.Acc: 32.67%, E.Acc: 17.04%
# Epoch 0. Batch 720/4290: AvgLoss: 2.95, S.Acc: 32.71%, E.Acc: 17.02%
# Epoch 0. Batch 730/4290: AvgLoss: 2.95, S.Acc: 32.78%, E.Acc: 17.01%
# Epoch 0. Batch 740/4290: AvgLoss: 2.95, S.Acc: 32.89%, E.Acc: 17.00%
# Epoch 0. Batch 750/4290: AvgLoss: 2.95, S.Acc: 32.85%, E.Acc: 17.01%
# Epoch 0. Batch 760/4290: AvgLoss: 2.95, S.Acc: 32.84%, E.Acc: 17.03%
# Epoch 0. Batch 770/4290: AvgLoss: 2.95, S.Acc: 32.83%, E.Acc: 17.05%
# Epoch 0. Batch 780/4290: AvgLoss: 2.95, S.Acc: 32.93%, E.Acc: 17.10%
# Epoch 0. Batch 790/4290: AvgLoss: 2.95, S.Acc: 32.96%, E.Acc: 17.08%
# Epoch 0. Batch 800/4290: AvgLoss: 2.95, S.Acc: 32.82%, E.Acc: 17.13%
# Epoch 0. Batch 810/4290: AvgLoss: 2.95, S.Acc: 32.76%, E.Acc: 17.15%
# Epoch 0. Batch 820/4290: AvgLoss: 2.94, S.Acc: 32.68%, E.Acc: 17.16%
# Epoch 0. Batch 830/4290: AvgLoss: 2.94, S.Acc: 32.84%, E.Acc: 17.13%
# Epoch 0. Batch 840/4290: AvgLoss: 2.94, S.Acc: 32.99%, E.Acc: 17.14%
# Epoch 0. Batch 1980/4290: AvgLoss: 2.71, S.Acc: 36.92%, E.Acc: 27.95%
# Epoch 0. Batch 1990/4290: AvgLoss: 2.70, S.Acc: 37.01%, E.Acc: 28.22%
# Epoch 0. Batch 2000/4290: AvgLoss: 2.69, S.Acc: 37.07%, E.Acc: 28.52%
# Epoch 0. Batch 2010/4290: AvgLoss: 2.69, S.Acc: 37.13%, E.Acc: 28.80%
# Epoch 0. Batch 2020/4290: AvgLoss: 2.68, S.Acc: 37.22%, E.Acc: 29.05%
# Epoch 0. Batch 2030/4290: AvgLoss: 2.68, S.Acc: 37.31%, E.Acc: 29.33%
# Epoch 0. Batch 2040/4290: AvgLoss: 2.67, S.Acc: 37.38%, E.Acc: 29.57%
# Epoch 0. Batch 2050/4290: AvgLoss: 2.66, S.Acc: 37.45%, E.Acc: 29.84%
# Epoch 0. Batch 2060/4290: AvgLoss: 2.66, S.Acc: 37.56%, E.Acc: 30.12%
# Epoch 0. Batch 2070/4290: AvgLoss: 2.65, S.Acc: 37.65%, E.Acc: 30.41%
# Epoch 0. Batch 2080/4290: AvgLoss: 2.64, S.Acc: 37.73%, E.Acc: 30.67%
# Epoch 0. Batch 2090/4290: AvgLoss: 2.64, S.Acc: 37.81%, E.Acc: 30.94%
# Epoch 0. Batch 2100/4290: AvgLoss: 2.63, S.Acc: 37.87%, E.Acc: 31.20%
# Epoch 0. Batch 2110/4290: AvgLoss: 2.63, S.Acc: 37.95%, E.Acc: 31.48%
# Epoch 0. Batch 2120/4290: AvgLoss: 2.62, S.Acc: 38.02%, E.Acc: 31.75%
# Epoch 0. Batch 2130/4290: AvgLoss: 2.61, S.Acc: 38.10%, E.Acc: 32.02%
# Epoch 0. Batch 2140/4290: AvgLoss: 2.61, S.Acc: 38.17%, E.Acc: 32.29%
# Epoch 0. Batch 2150/4290: AvgLoss: 2.60, S.Acc: 38.26%, E.Acc: 32.53%
# Epoch 0. Batch 2160/4290: AvgLoss: 2.60, S.Acc: 38.32%, E.Acc: 32.80%
# Epoch 0. Batch 2170/4290: AvgLoss: 2.59, S.Acc: 38.42%, E.Acc: 33.05%
# Epoch 0. Batch 2180/4290: AvgLoss: 2.58, S.Acc: 38.51%, E.Acc: 33.30%
# Epoch 0. Batch 2190/4290: AvgLoss: 2.58, S.Acc: 38.59%, E.Acc: 33.55%
# Epoch 0. Batch 2200/4290: AvgLoss: 2.57, S.Acc: 38.65%, E.Acc: 33.79%
# Epoch 0. Batch 2210/4290: AvgLoss: 2.57, S.Acc: 38.69%, E.Acc: 34.02%
# Epoch 0. Batch 2220/4290: AvgLoss: 2.56, S.Acc: 38.74%, E.Acc: 34.26%
# Epoch 0. Batch 2230/4290: AvgLoss: 2.55, S.Acc: 38.84%, E.Acc: 34.50%
# Epoch 0. Batch 2240/4290: AvgLoss: 2.55, S.Acc: 38.91%, E.Acc: 34.74%
# Epoch 0. Batch 2250/4290: AvgLoss: 2.54, S.Acc: 38.97%, E.Acc: 34.95%
# Epoch 0. Batch 2260/4290: AvgLoss: 2.54, S.Acc: 39.02%, E.Acc: 35.19%
# Epoch 0. Batch 2270/4290: AvgLoss: 2.53, S.Acc: 39.10%, E.Acc: 35.43%
# Epoch 0. Batch 2280/4290: AvgLoss: 2.53, S.Acc: 39.14%, E.Acc: 35.67%
# Epoch 0. Batch 2290/4290: AvgLoss: 2.52, S.Acc: 39.19%, E.Acc: 35.92%
# Epoch 0. Batch 2300/4290: AvgLoss: 2.52, S.Acc: 39.24%, E.Acc: 36.15%
# Epoch 0. Batch 2310/4290: AvgLoss: 2.51, S.Acc: 39.30%, E.Acc: 36.39%
# Epoch 0. Batch 2320/4290: AvgLoss: 2.50, S.Acc: 39.38%, E.Acc: 36.62%
# Epoch 0. Batch 2330/4290: AvgLoss: 2.50, S.Acc: 39.43%, E.Acc: 36.84%
# Epoch 0. Batch 2340/4290: AvgLoss: 2.49, S.Acc: 39.48%, E.Acc: 37.05%
# Epoch 0. Batch 2350/4290: AvgLoss: 2.49, S.Acc: 39.52%, E.Acc: 37.26%
# Epoch 0. Batch 2360/4290: AvgLoss: 2.48, S.Acc: 39.57%, E.Acc: 37.50%
# Epoch 0. Batch 2370/4290: AvgLoss: 2.48, S.Acc: 39.63%, E.Acc: 37.73%
# Epoch 0. Batch 2380/4290: AvgLoss: 2.47, S.Acc: 39.72%, E.Acc: 37.96%
# Epoch 0. Batch 2390/4290: AvgLoss: 2.47, S.Acc: 39.81%, E.Acc: 38.17%
# Epoch 0. Batch 2400/4290: AvgLoss: 2.46, S.Acc: 39.88%, E.Acc: 38.40%
# Epoch 0. Batch 2410/4290: AvgLoss: 2.46, S.Acc: 39.95%, E.Acc: 38.59%
# Epoch 0. Batch 2420/4290: AvgLoss: 2.45, S.Acc: 40.00%, E.Acc: 38.80%
# Epoch 0. Batch 2430/4290: AvgLoss: 2.45, S.Acc: 40.05%, E.Acc: 39.01%
# Epoch 0. Batch 2440/4290: AvgLoss: 2.44, S.Acc: 40.10%, E.Acc: 39.21%
# Epoch 0. Batch 2450/4290: AvgLoss: 2.44, S.Acc: 40.16%, E.Acc: 39.41%
# Epoch 0. Batch 2460/4290: AvgLoss: 2.43, S.Acc: 40.24%, E.Acc: 39.61%
# Epoch 0. Batch 2470/4290: AvgLoss: 2.43, S.Acc: 40.31%, E.Acc: 39.80%
# Epoch 0. Batch 2480/4290: AvgLoss: 2.42, S.Acc: 40.38%, E.Acc: 39.99%
# Epoch 0. Batch 2490/4290: AvgLoss: 2.42, S.Acc: 40.45%, E.Acc: 40.19%
# Epoch 0. Batch 2500/4290: AvgLoss: 2.41, S.Acc: 40.50%, E.Acc: 40.40%
# Epoch 0. Batch 2510/4290: AvgLoss: 2.41, S.Acc: 40.54%, E.Acc: 40.61%
# Epoch 0. Batch 2520/4290: AvgLoss: 2.40, S.Acc: 40.60%, E.Acc: 40.81%
# Epoch 0. Batch 2530/4290: AvgLoss: 2.40, S.Acc: 40.70%, E.Acc: 41.00%
# Epoch 0. Batch 2540/4290: AvgLoss: 2.39, S.Acc: 40.74%, E.Acc: 41.19%
# Epoch 0. Batch 2550/4290: AvgLoss: 2.39, S.Acc: 40.81%, E.Acc: 41.38%
# Epoch 0. Batch 2560/4290: AvgLoss: 2.38, S.Acc: 40.90%, E.Acc: 41.57%
# Epoch 0. Batch 2570/4290: AvgLoss: 2.38, S.Acc: 40.95%, E.Acc: 41.77%
# Epoch 0. Batch 2580/4290: AvgLoss: 2.37, S.Acc: 41.03%, E.Acc: 41.97%
# Epoch 0. Batch 2590/4290: AvgLoss: 2.37, S.Acc: 41.06%, E.Acc: 42.18%
# Epoch 0. Batch 2600/4290: AvgLoss: 2.36, S.Acc: 41.12%, E.Acc: 42.37%
# Epoch 0. Batch 2610/4290: AvgLoss: 2.36, S.Acc: 41.17%, E.Acc: 42.56%
# Epoch 0. Batch 2620/4290: AvgLoss: 2.35, S.Acc: 41.24%, E.Acc: 42.74%
# Epoch 0. Batch 2630/4290: AvgLoss: 2.35, S.Acc: 41.32%, E.Acc: 42.94%
# Epoch 0. Batch 2640/4290: AvgLoss: 2.34, S.Acc: 41.39%, E.Acc: 43.12%
# Epoch 0. Batch 2650/4290: AvgLoss: 2.34, S.Acc: 41.46%, E.Acc: 43.29%
# Epoch 0. Batch 2660/4290: AvgLoss: 2.33, S.Acc: 41.52%, E.Acc: 43.48%
# Epoch 0. Batch 2670/4290: AvgLoss: 2.33, S.Acc: 41.59%, E.Acc: 43.67%
# Epoch 0. Batch 2680/4290: AvgLoss: 2.32, S.Acc: 41.66%, E.Acc: 43.87%
# Epoch 0. Batch 2690/4290: AvgLoss: 2.32, S.Acc: 41.72%, E.Acc: 44.05%
# Epoch 0. Batch 2700/4290: AvgLoss: 2.31, S.Acc: 41.82%, E.Acc: 44.23%
# Epoch 0. Batch 2710/4290: AvgLoss: 2.31, S.Acc: 41.89%, E.Acc: 44.40%
# Epoch 0. Batch 2720/4290: AvgLoss: 2.30, S.Acc: 41.94%, E.Acc: 44.58%
# Epoch 0. Batch 2730/4290: AvgLoss: 2.30, S.Acc: 41.99%, E.Acc: 44.75%
# Epoch 0. Batch 2740/4290: AvgLoss: 2.30, S.Acc: 42.04%, E.Acc: 44.91%
# Epoch 0. Batch 2750/4290: AvgLoss: 2.29, S.Acc: 42.08%, E.Acc: 45.07%
# Epoch 0. Batch 2760/4290: AvgLoss: 2.29, S.Acc: 42.11%, E.Acc: 45.24%
# Epoch 0. Batch 2770/4290: AvgLoss: 2.28, S.Acc: 42.18%, E.Acc: 45.40%
# Epoch 0. Batch 2780/4290: AvgLoss: 2.28, S.Acc: 42.26%, E.Acc: 45.56%
# Epoch 0. Batch 2790/4290: AvgLoss: 2.27, S.Acc: 42.31%, E.Acc: 45.72%
# Epoch 0. Batch 2800/4290: AvgLoss: 2.27, S.Acc: 42.38%, E.Acc: 45.89%
# Epoch 0. Batch 2810/4290: AvgLoss: 2.27, S.Acc: 42.42%, E.Acc: 46.06%
# Epoch 0. Batch 2820/4290: AvgLoss: 2.26, S.Acc: 42.48%, E.Acc: 46.21%
# Epoch 0. Batch 2830/4290: AvgLoss: 2.26, S.Acc: 42.55%, E.Acc: 46.36%
# Epoch 0. Batch 2840/4290: AvgLoss: 2.25, S.Acc: 42.61%, E.Acc: 46.54%
# Epoch 0. Batch 2850/4290: AvgLoss: 2.25, S.Acc: 42.66%, E.Acc: 46.69%
# Epoch 0. Batch 2860/4290: AvgLoss: 2.24, S.Acc: 42.74%, E.Acc: 46.84%
# Epoch 0. Batch 2870/4290: AvgLoss: 2.24, S.Acc: 42.77%, E.Acc: 47.02%
# Epoch 0. Batch 2880/4290: AvgLoss: 2.24, S.Acc: 42.83%, E.Acc: 47.17%
# Epoch 0. Batch 2890/4290: AvgLoss: 2.23, S.Acc: 42.86%, E.Acc: 47.33%
# Epoch 0. Batch 2900/4290: AvgLoss: 2.23, S.Acc: 42.90%, E.Acc: 47.47%
# Epoch 0. Batch 2910/4290: AvgLoss: 2.22, S.Acc: 42.97%, E.Acc: 47.63%
# Epoch 0. Batch 2920/4290: AvgLoss: 2.22, S.Acc: 43.01%, E.Acc: 47.79%
# Epoch 0. Batch 2930/4290: AvgLoss: 2.22, S.Acc: 43.08%, E.Acc: 47.93%
# Epoch 0. Batch 2940/4290: AvgLoss: 2.21, S.Acc: 43.12%, E.Acc: 48.09%
# Epoch 0. Batch 2950/4290: AvgLoss: 2.21, S.Acc: 43.14%, E.Acc: 48.22%
# Epoch 0. Batch 2960/4290: AvgLoss: 2.21, S.Acc: 43.20%, E.Acc: 48.37%
# Epoch 0. Batch 2970/4290: AvgLoss: 2.20, S.Acc: 43.26%, E.Acc: 48.52%
# Epoch 0. Batch 2980/4290: AvgLoss: 2.20, S.Acc: 43.31%, E.Acc: 48.66%
# Epoch 0. Batch 2990/4290: AvgLoss: 2.19, S.Acc: 43.38%, E.Acc: 48.81%
# Epoch 0. Batch 3000/4290: AvgLoss: 2.19, S.Acc: 43.43%, E.Acc: 48.96%
# Epoch 0. Batch 3010/4290: AvgLoss: 2.19, S.Acc: 43.49%, E.Acc: 49.10%
# Epoch 0. Batch 3020/4290: AvgLoss: 2.18, S.Acc: 43.54%, E.Acc: 49.24%
# Epoch 0. Batch 3030/4290: AvgLoss: 2.18, S.Acc: 43.61%, E.Acc: 49.38%
# Epoch 0. Batch 3040/4290: AvgLoss: 2.17, S.Acc: 43.67%, E.Acc: 49.52%
# Epoch 0. Batch 3050/4290: AvgLoss: 2.17, S.Acc: 43.72%, E.Acc: 49.66%
# Epoch 0. Batch 3060/4290: AvgLoss: 2.17, S.Acc: 43.76%, E.Acc: 49.81%
# Epoch 0. Batch 3070/4290: AvgLoss: 2.16, S.Acc: 43.82%, E.Acc: 49.94%
# Epoch 0. Batch 3080/4290: AvgLoss: 2.16, S.Acc: 43.85%, E.Acc: 50.07%
# Epoch 0. Batch 3090/4290: AvgLoss: 2.16, S.Acc: 43.91%, E.Acc: 50.21%
# Epoch 0. Batch 3100/4290: AvgLoss: 2.15, S.Acc: 43.94%, E.Acc: 50.34%
# Epoch 0. Batch 3110/4290: AvgLoss: 2.15, S.Acc: 43.98%, E.Acc: 50.48%
# Epoch 0. Batch 3120/4290: AvgLoss: 2.15, S.Acc: 44.03%, E.Acc: 50.61%
# Epoch 0. Batch 3130/4290: AvgLoss: 2.14, S.Acc: 44.07%, E.Acc: 50.74%
# Epoch 0. Batch 3140/4290: AvgLoss: 2.14, S.Acc: 44.10%, E.Acc: 50.89%
# Epoch 0. Batch 3150/4290: AvgLoss: 2.14, S.Acc: 44.14%, E.Acc: 51.01%
# Epoch 0. Batch 3160/4290: AvgLoss: 2.13, S.Acc: 44.19%, E.Acc: 51.15%
# Epoch 0. Batch 3170/4290: AvgLoss: 2.13, S.Acc: 44.23%, E.Acc: 51.28%
# Epoch 0. Batch 3180/4290: AvgLoss: 2.13, S.Acc: 44.28%, E.Acc: 51.41%
# Epoch 0. Batch 3190/4290: AvgLoss: 2.12, S.Acc: 44.33%, E.Acc: 51.53%
# Epoch 0. Batch 3200/4290: AvgLoss: 2.12, S.Acc: 44.37%, E.Acc: 51.67%
# Epoch 0. Batch 3210/4290: AvgLoss: 2.12, S.Acc: 44.44%, E.Acc: 51.79%
# Epoch 0. Batch 3220/4290: AvgLoss: 2.11, S.Acc: 44.46%, E.Acc: 51.92%
# Epoch 0. Batch 3230/4290: AvgLoss: 2.11, S.Acc: 44.53%, E.Acc: 52.05%
# Epoch 0. Batch 3240/4290: AvgLoss: 2.11, S.Acc: 44.57%, E.Acc: 52.17%
# Epoch 0. Batch 3250/4290: AvgLoss: 2.10, S.Acc: 44.63%, E.Acc: 52.29%
# Epoch 0. Batch 3260/4290: AvgLoss: 2.10, S.Acc: 44.66%, E.Acc: 52.41%
# Epoch 0. Batch 3270/4290: AvgLoss: 2.10, S.Acc: 44.71%, E.Acc: 52.54%
# Epoch 0. Batch 3280/4290: AvgLoss: 2.09, S.Acc: 44.74%, E.Acc: 52.65%
# Epoch 0. Batch 3290/4290: AvgLoss: 2.09, S.Acc: 44.75%, E.Acc: 52.78%
# Epoch 0. Batch 3300/4290: AvgLoss: 2.09, S.Acc: 44.80%, E.Acc: 52.90%
# Epoch 0. Batch 3310/4290: AvgLoss: 2.08, S.Acc: 44.85%, E.Acc: 53.00%
# Epoch 0. Batch 3320/4290: AvgLoss: 2.08, S.Acc: 44.90%, E.Acc: 53.12%
# Epoch 0. Batch 3330/4290: AvgLoss: 2.08, S.Acc: 44.93%, E.Acc: 53.24%
# Epoch 0. Batch 3340/4290: AvgLoss: 2.07, S.Acc: 44.96%, E.Acc: 53.36%
# Epoch 0. Batch 3350/4290: AvgLoss: 2.07, S.Acc: 45.02%, E.Acc: 53.48%
# Epoch 0. Batch 3360/4290: AvgLoss: 2.07, S.Acc: 45.08%, E.Acc: 53.58%
# Epoch 0. Batch 3370/4290: AvgLoss: 2.07, S.Acc: 45.14%, E.Acc: 53.70%
# Epoch 0. Batch 3380/4290: AvgLoss: 2.06, S.Acc: 45.19%, E.Acc: 53.80%
# Epoch 0. Batch 3390/4290: AvgLoss: 2.06, S.Acc: 45.22%, E.Acc: 53.93%
# Epoch 0. Batch 3400/4290: AvgLoss: 2.06, S.Acc: 45.25%, E.Acc: 54.05%
# Epoch 0. Batch 3410/4290: AvgLoss: 2.05, S.Acc: 45.29%, E.Acc: 54.16%
# Epoch 0. Batch 3420/4290: AvgLoss: 2.05, S.Acc: 45.33%, E.Acc: 54.28%
# Epoch 0. Batch 3430/4290: AvgLoss: 2.05, S.Acc: 45.36%, E.Acc: 54.40%
# Epoch 0. Batch 3440/4290: AvgLoss: 2.04, S.Acc: 45.42%, E.Acc: 54.52%
# Epoch 0. Batch 3450/4290: AvgLoss: 2.04, S.Acc: 45.47%, E.Acc: 54.63%
# Epoch 0. Batch 3460/4290: AvgLoss: 2.04, S.Acc: 45.49%, E.Acc: 54.74%
# Epoch 0. Batch 3470/4290: AvgLoss: 2.04, S.Acc: 45.55%, E.Acc: 54.84%
# Epoch 0. Batch 3480/4290: AvgLoss: 2.03, S.Acc: 45.58%, E.Acc: 54.94%
# Epoch 0. Batch 3490/4290: AvgLoss: 2.03, S.Acc: 45.62%, E.Acc: 55.05%
# Epoch 0. Batch 3500/4290: AvgLoss: 2.03, S.Acc: 45.66%, E.Acc: 55.15%
# Epoch 0. Batch 3510/4290: AvgLoss: 2.02, S.Acc: 45.72%, E.Acc: 55.26%
# Epoch 0. Batch 3520/4290: AvgLoss: 2.02, S.Acc: 45.75%, E.Acc: 55.37%
# Epoch 0. Batch 3530/4290: AvgLoss: 2.02, S.Acc: 45.75%, E.Acc: 55.47%
# Epoch 0. Batch 3540/4290: AvgLoss: 2.02, S.Acc: 45.79%, E.Acc: 55.57%
# Epoch 0. Batch 3550/4290: AvgLoss: 2.01, S.Acc: 45.83%, E.Acc: 55.68%
# Epoch 0. Batch 3560/4290: AvgLoss: 2.01, S.Acc: 45.87%, E.Acc: 55.79%
# Epoch 0. Batch 3570/4290: AvgLoss: 2.01, S.Acc: 45.90%, E.Acc: 55.89%
# Epoch 0. Batch 3580/4290: AvgLoss: 2.01, S.Acc: 45.92%, E.Acc: 55.99%
# Epoch 0. Batch 3590/4290: AvgLoss: 2.00, S.Acc: 45.96%, E.Acc: 56.09%
# Epoch 0. Batch 3600/4290: AvgLoss: 2.00, S.Acc: 46.00%, E.Acc: 56.19%
# Epoch 0. Batch 3610/4290: AvgLoss: 2.00, S.Acc: 46.03%, E.Acc: 56.29%
# Epoch 0. Batch 3620/4290: AvgLoss: 1.99, S.Acc: 46.06%, E.Acc: 56.39%
# Epoch 0. Batch 3630/4290: AvgLoss: 1.99, S.Acc: 46.11%, E.Acc: 56.50%
# Epoch 0. Batch 3640/4290: AvgLoss: 1.99, S.Acc: 46.13%, E.Acc: 56.60%
# Epoch 0. Batch 3650/4290: AvgLoss: 1.99, S.Acc: 46.17%, E.Acc: 56.70%
# Epoch 0. Batch 3660/4290: AvgLoss: 1.98, S.Acc: 46.21%, E.Acc: 56.80%
# Epoch 0. Batch 3670/4290: AvgLoss: 1.98, S.Acc: 46.24%, E.Acc: 56.90%
# Epoch 0. Batch 3680/4290: AvgLoss: 1.98, S.Acc: 46.27%, E.Acc: 57.00%
# Epoch 0. Batch 3690/4290: AvgLoss: 1.98, S.Acc: 46.31%, E.Acc: 57.10%
# Epoch 0. Batch 3700/4290: AvgLoss: 1.97, S.Acc: 46.35%, E.Acc: 57.20%
# Epoch 0. Batch 3710/4290: AvgLoss: 1.97, S.Acc: 46.41%, E.Acc: 57.31%
# Epoch 0. Batch 3720/4290: AvgLoss: 1.97, S.Acc: 46.46%, E.Acc: 57.40%
# Epoch 0. Batch 3730/4290: AvgLoss: 1.96, S.Acc: 46.50%, E.Acc: 57.50%
# Epoch 0. Batch 3740/4290: AvgLoss: 1.96, S.Acc: 46.55%, E.Acc: 57.60%
# Epoch 0. Batch 3750/4290: AvgLoss: 1.96, S.Acc: 46.58%, E.Acc: 57.69%
# Epoch 0. Batch 3760/4290: AvgLoss: 1.96, S.Acc: 46.62%, E.Acc: 57.78%
# Epoch 0. Batch 3770/4290: AvgLoss: 1.95, S.Acc: 46.66%, E.Acc: 57.88%
# Epoch 0. Batch 3780/4290: AvgLoss: 1.95, S.Acc: 46.70%, E.Acc: 57.96%
# Epoch 0. Batch 3790/4290: AvgLoss: 1.95, S.Acc: 46.73%, E.Acc: 58.06%
# Epoch 0. Batch 3800/4290: AvgLoss: 1.95, S.Acc: 46.76%, E.Acc: 58.15%
# Epoch 0. Batch 3810/4290: AvgLoss: 1.94, S.Acc: 46.80%, E.Acc: 58.25%
# Epoch 0. Batch 3820/4290: AvgLoss: 1.94, S.Acc: 46.84%, E.Acc: 58.33%
# Epoch 0. Batch 3830/4290: AvgLoss: 1.94, S.Acc: 46.88%, E.Acc: 58.42%
# Epoch 0. Batch 3840/4290: AvgLoss: 1.94, S.Acc: 46.92%, E.Acc: 58.50%
# Epoch 0. Batch 3850/4290: AvgLoss: 1.93, S.Acc: 46.95%, E.Acc: 58.59%
# Epoch 0. Batch 3860/4290: AvgLoss: 1.93, S.Acc: 47.00%, E.Acc: 58.66%
# Epoch 0. Batch 3870/4290: AvgLoss: 1.93, S.Acc: 47.04%, E.Acc: 58.75%
# Epoch 0. Batch 3880/4290: AvgLoss: 1.93, S.Acc: 47.07%, E.Acc: 58.84%
# Epoch 0. Batch 3890/4290: AvgLoss: 1.92, S.Acc: 47.12%, E.Acc: 58.93%
# Epoch 0. Batch 3900/4290: AvgLoss: 1.92, S.Acc: 47.14%, E.Acc: 59.02%
# Epoch 0. Batch 3910/4290: AvgLoss: 1.92, S.Acc: 47.17%, E.Acc: 59.10%
# Epoch 0. Batch 3920/4290: AvgLoss: 1.92, S.Acc: 47.21%, E.Acc: 59.19%
# Epoch 0. Batch 3930/4290: AvgLoss: 1.92, S.Acc: 47.25%, E.Acc: 59.26%
# Epoch 0. Batch 3940/4290: AvgLoss: 1.91, S.Acc: 47.29%, E.Acc: 59.34%
# Epoch 0. Batch 3950/4290: AvgLoss: 1.91, S.Acc: 47.34%, E.Acc: 59.43%
# Epoch 0. Batch 3960/4290: AvgLoss: 1.91, S.Acc: 47.38%, E.Acc: 59.52%
# Epoch 0. Batch 3970/4290: AvgLoss: 1.91, S.Acc: 47.42%, E.Acc: 59.60%
# Epoch 0. Batch 3980/4290: AvgLoss: 1.90, S.Acc: 47.45%, E.Acc: 59.67%
# Epoch 0. Batch 3990/4290: AvgLoss: 1.90, S.Acc: 47.49%, E.Acc: 59.75%
# Epoch 0. Batch 4000/4290: AvgLoss: 1.90, S.Acc: 47.52%, E.Acc: 59.83%
# Epoch 0. Batch 4010/4290: AvgLoss: 1.90, S.Acc: 47.57%, E.Acc: 59.91%
# Epoch 0. Batch 4020/4290: AvgLoss: 1.90, S.Acc: 47.60%, E.Acc: 59.99%
# Epoch 0. Batch 4030/4290: AvgLoss: 1.89, S.Acc: 47.63%, E.Acc: 60.07%
# Epoch 0. Batch 4040/4290: AvgLoss: 1.89, S.Acc: 47.67%, E.Acc: 60.15%
# Epoch 0. Batch 4050/4290: AvgLoss: 1.89, S.Acc: 47.71%, E.Acc: 60.24%
# Epoch 0. Batch 4060/4290: AvgLoss: 1.89, S.Acc: 47.75%, E.Acc: 60.32%
# Epoch 0. Batch 4070/4290: AvgLoss: 1.88, S.Acc: 47.78%, E.Acc: 60.40%
# Epoch 0. Batch 4080/4290: AvgLoss: 1.88, S.Acc: 47.81%, E.Acc: 60.47%
# Epoch 0. Batch 4090/4290: AvgLoss: 1.88, S.Acc: 47.85%, E.Acc: 60.55%
# Epoch 0. Batch 4100/4290: AvgLoss: 1.88, S.Acc: 47.88%, E.Acc: 60.62%
# Epoch 0. Batch 4110/4290: AvgLoss: 1.88, S.Acc: 47.91%, E.Acc: 60.70%
# Epoch 0. Batch 4120/4290: AvgLoss: 1.87, S.Acc: 47.94%, E.Acc: 60.79%
# Epoch 0. Batch 4130/4290: AvgLoss: 1.87, S.Acc: 47.96%, E.Acc: 60.86%
# Epoch 0. Batch 4140/4290: AvgLoss: 1.87, S.Acc: 47.98%, E.Acc: 60.95%
# Epoch 0. Batch 4150/4290: AvgLoss: 1.87, S.Acc: 48.02%, E.Acc: 61.02%
# Epoch 0. Batch 4160/4290: AvgLoss: 1.87, S.Acc: 48.05%, E.Acc: 61.09%
# Epoch 0. Batch 4170/4290: AvgLoss: 1.86, S.Acc: 48.10%, E.Acc: 61.17%
# Epoch 0. Batch 4180/4290: AvgLoss: 1.86, S.Acc: 48.14%, E.Acc: 61.25%
# Epoch 0. Batch 4190/4290: AvgLoss: 1.86, S.Acc: 48.19%, E.Acc: 61.33%
# Epoch 0. Batch 4200/4290: AvgLoss: 1.86, S.Acc: 48.23%, E.Acc: 61.41%
# Epoch 0. Batch 4210/4290: AvgLoss: 1.85, S.Acc: 48.27%, E.Acc: 61.50%
# Epoch 0. Batch 4220/4290: AvgLoss: 1.85, S.Acc: 48.29%, E.Acc: 61.57%
# Epoch 0. Batch 4230/4290: AvgLoss: 1.85, S.Acc: 48.32%, E.Acc: 61.65%
# Epoch 0. Batch 4240/4290: AvgLoss: 1.85, S.Acc: 48.37%, E.Acc: 61.72%
# Epoch 0. Batch 4250/4290: AvgLoss: 1.85, S.Acc: 48.39%, E.Acc: 61.80%
# Epoch 0. Batch 4260/4290: AvgLoss: 1.84, S.Acc: 48.43%, E.Acc: 61.87%
# Epoch 0. Batch 4270/4290: AvgLoss: 1.84, S.Acc: 48.46%, E.Acc: 61.95%
# Epoch 0. Batch 4280/4290: AvgLoss: 1.84, S.Acc: 48.50%, E.Acc: 62.02%
# Train Loss: 1.8377, Train Sentiment Accuracy: 48.51%, Train Emotion Accuracy: 62.08%
# Validation Sentiment Accuracy: 61.67%, Validation Emotion Accuracy: 93.48%
# Epoch 1. Batch 0/4290: AvgLoss: 0.63, S.Acc: 81.25%, E.Acc: 93.75%
# Epoch 1. Batch 10/4290: AvgLoss: 0.80, S.Acc: 72.73%, E.Acc: 95.45%
# Epoch 1. Batch 20/4290: AvgLoss: 0.83, S.Acc: 70.24%, E.Acc: 94.94%
# Epoch 1. Batch 30/4290: AvgLoss: 0.86, S.Acc: 68.15%, E.Acc: 94.15%
# Epoch 1. Batch 40/4290: AvgLoss: 0.88, S.Acc: 65.70%, E.Acc: 94.82%
# Epoch 1. Batch 50/4290: AvgLoss: 0.88, S.Acc: 64.71%, E.Acc: 94.98%
# Epoch 1. Batch 60/4290: AvgLoss: 0.86, S.Acc: 65.68%, E.Acc: 95.49%
# Epoch 1. Batch 70/4290: AvgLoss: 0.85, S.Acc: 66.37%, E.Acc: 95.42%
# Epoch 1. Batch 80/4290: AvgLoss: 0.85, S.Acc: 66.90%, E.Acc: 95.14%
# Epoch 1. Batch 90/4290: AvgLoss: 0.84, S.Acc: 67.38%, E.Acc: 94.71%
# Epoch 1. Batch 100/4290: AvgLoss: 0.85, S.Acc: 67.26%, E.Acc: 94.55%
# Epoch 1. Batch 110/4290: AvgLoss: 0.86, S.Acc: 67.57%, E.Acc: 94.09%
# Epoch 1. Batch 120/4290: AvgLoss: 0.85, S.Acc: 67.72%, E.Acc: 94.27%
# Epoch 1. Batch 130/4290: AvgLoss: 0.86, S.Acc: 67.37%, E.Acc: 94.13%
# Epoch 1. Batch 140/4290: AvgLoss: 0.86, S.Acc: 67.38%, E.Acc: 94.24%
# Epoch 1. Batch 150/4290: AvgLoss: 0.85, S.Acc: 67.63%, E.Acc: 94.16%
# Epoch 1. Batch 160/4290: AvgLoss: 0.85, S.Acc: 67.31%, E.Acc: 94.22%
# Epoch 1. Batch 170/4290: AvgLoss: 0.85, S.Acc: 67.58%, E.Acc: 94.23%
# Epoch 1. Batch 180/4290: AvgLoss: 0.86, S.Acc: 67.20%, E.Acc: 94.13%
# Epoch 1. Batch 190/4290: AvgLoss: 0.86, S.Acc: 67.05%, E.Acc: 94.11%
# Epoch 1. Batch 200/4290: AvgLoss: 0.86, S.Acc: 66.95%, E.Acc: 94.00%
# Epoch 1. Batch 210/4290: AvgLoss: 0.87, S.Acc: 66.80%, E.Acc: 93.81%
# Epoch 1. Batch 1930/4290: AvgLoss: 0.85, S.Acc: 67.34%, E.Acc: 93.93%
# Epoch 1. Batch 1940/4290: AvgLoss: 0.85, S.Acc: 67.33%, E.Acc: 93.95%
# Epoch 1. Batch 1950/4290: AvgLoss: 0.85, S.Acc: 67.35%, E.Acc: 93.95%
# Epoch 1. Batch 1960/4290: AvgLoss: 0.85, S.Acc: 67.31%, E.Acc: 93.94%
# Epoch 1. Batch 1970/4290: AvgLoss: 0.85, S.Acc: 67.30%, E.Acc: 93.95%
# Epoch 1. Batch 1980/4290: AvgLoss: 0.85, S.Acc: 67.28%, E.Acc: 93.96%
# Epoch 1. Batch 1990/4290: AvgLoss: 0.85, S.Acc: 67.26%, E.Acc: 93.97%
# Epoch 1. Batch 2000/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 93.98%
# Epoch 1. Batch 2010/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.98%
# Epoch 1. Batch 2020/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.99%
# Epoch 1. Batch 2030/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.98%
# Epoch 1. Batch 2040/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.99%
# Epoch 1. Batch 2050/4290: AvgLoss: 0.85, S.Acc: 67.17%, E.Acc: 93.98%
# Epoch 1. Batch 2060/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.99%
# Epoch 1. Batch 2070/4290: AvgLoss: 0.85, S.Acc: 67.17%, E.Acc: 93.97%
# Epoch 1. Batch 2080/4290: AvgLoss: 0.85, S.Acc: 67.15%, E.Acc: 93.97%
# Epoch 1. Batch 2090/4290: AvgLoss: 0.85, S.Acc: 67.14%, E.Acc: 93.97%
# Epoch 1. Batch 2100/4290: AvgLoss: 0.85, S.Acc: 67.10%, E.Acc: 93.98%
# Epoch 1. Batch 2110/4290: AvgLoss: 0.85, S.Acc: 67.10%, E.Acc: 93.97%
# Epoch 1. Batch 2120/4290: AvgLoss: 0.85, S.Acc: 67.11%, E.Acc: 93.97%
# Epoch 1. Batch 2130/4290: AvgLoss: 0.85, S.Acc: 67.14%, E.Acc: 93.98%
# Epoch 1. Batch 2140/4290: AvgLoss: 0.85, S.Acc: 67.15%, E.Acc: 93.99%
# Epoch 1. Batch 2150/4290: AvgLoss: 0.85, S.Acc: 67.17%, E.Acc: 93.99%
# Epoch 1. Batch 2160/4290: AvgLoss: 0.85, S.Acc: 67.15%, E.Acc: 93.99%
# Epoch 1. Batch 2170/4290: AvgLoss: 0.85, S.Acc: 67.11%, E.Acc: 93.98%
# Epoch 1. Batch 2180/4290: AvgLoss: 0.85, S.Acc: 67.11%, E.Acc: 93.98%
# Epoch 1. Batch 2190/4290: AvgLoss: 0.85, S.Acc: 67.10%, E.Acc: 93.97%
# Epoch 1. Batch 2200/4290: AvgLoss: 0.85, S.Acc: 67.09%, E.Acc: 93.96%
# Epoch 1. Batch 2210/4290: AvgLoss: 0.85, S.Acc: 67.10%, E.Acc: 93.96%
# Epoch 1. Batch 2220/4290: AvgLoss: 0.85, S.Acc: 67.11%, E.Acc: 93.96%
# Epoch 1. Batch 2230/4290: AvgLoss: 0.85, S.Acc: 67.10%, E.Acc: 93.98%
# Epoch 1. Batch 2240/4290: AvgLoss: 0.85, S.Acc: 67.09%, E.Acc: 93.98%
# Epoch 1. Batch 2250/4290: AvgLoss: 0.85, S.Acc: 67.10%, E.Acc: 93.99%
# Epoch 1. Batch 2260/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 93.99%
# Epoch 1. Batch 2270/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 93.99%
# Epoch 1. Batch 2280/4290: AvgLoss: 0.85, S.Acc: 67.14%, E.Acc: 94.00%
# Epoch 1. Batch 2290/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 93.99%
# Epoch 1. Batch 2300/4290: AvgLoss: 0.85, S.Acc: 67.13%, E.Acc: 93.98%
# Epoch 1. Batch 2310/4290: AvgLoss: 0.85, S.Acc: 67.11%, E.Acc: 93.96%
# Epoch 1. Batch 2320/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 93.96%
# Epoch 1. Batch 2330/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 93.97%
# Epoch 1. Batch 2340/4290: AvgLoss: 0.85, S.Acc: 67.14%, E.Acc: 93.97%
# Epoch 1. Batch 2350/4290: AvgLoss: 0.85, S.Acc: 67.15%, E.Acc: 93.97%
# Epoch 1. Batch 2360/4290: AvgLoss: 0.85, S.Acc: 67.14%, E.Acc: 93.98%
# Epoch 1. Batch 2370/4290: AvgLoss: 0.85, S.Acc: 67.16%, E.Acc: 93.98%
# Epoch 1. Batch 2380/4290: AvgLoss: 0.85, S.Acc: 67.16%, E.Acc: 93.99%
# Epoch 1. Batch 2390/4290: AvgLoss: 0.85, S.Acc: 67.17%, E.Acc: 93.99%
# Epoch 1. Batch 2400/4290: AvgLoss: 0.85, S.Acc: 67.18%, E.Acc: 93.97%
# Epoch 1. Batch 2410/4290: AvgLoss: 0.85, S.Acc: 67.17%, E.Acc: 93.97%
# Epoch 1. Batch 2420/4290: AvgLoss: 0.85, S.Acc: 67.20%, E.Acc: 93.96%
# Epoch 1. Batch 2430/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 93.96%
# Epoch 1. Batch 2440/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.97%
# Epoch 1. Batch 2450/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.98%
# Epoch 1. Batch 2460/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 94.00%
# Epoch 1. Batch 2470/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 94.01%
# Epoch 1. Batch 2480/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 94.02%
# Epoch 1. Batch 2490/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 94.02%
# Epoch 1. Batch 2500/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 94.02%
# Epoch 1. Batch 2510/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 94.04%
# Epoch 1. Batch 2520/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 94.04%
# Epoch 1. Batch 2530/4290: AvgLoss: 0.85, S.Acc: 67.20%, E.Acc: 94.05%
# Epoch 1. Batch 2540/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 94.05%
# Epoch 1. Batch 2550/4290: AvgLoss: 0.85, S.Acc: 67.20%, E.Acc: 94.04%
# Epoch 1. Batch 2560/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 94.03%
# Epoch 1. Batch 2570/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 94.01%
# Epoch 1. Batch 2580/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 94.01%
# Epoch 1. Batch 2590/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 94.00%
# Epoch 1. Batch 2600/4290: AvgLoss: 0.85, S.Acc: 67.20%, E.Acc: 94.01%
# Epoch 1. Batch 2610/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.99%
# Epoch 1. Batch 2620/4290: AvgLoss: 0.85, S.Acc: 67.18%, E.Acc: 94.00%
# Epoch 1. Batch 2630/4290: AvgLoss: 0.85, S.Acc: 67.17%, E.Acc: 94.00%
# Epoch 1. Batch 2640/4290: AvgLoss: 0.85, S.Acc: 67.16%, E.Acc: 94.01%
# Epoch 1. Batch 2650/4290: AvgLoss: 0.85, S.Acc: 67.17%, E.Acc: 94.00%
# Epoch 1. Batch 2660/4290: AvgLoss: 0.85, S.Acc: 67.14%, E.Acc: 94.00%
# Epoch 1. Batch 2670/4290: AvgLoss: 0.85, S.Acc: 67.14%, E.Acc: 94.00%
# Epoch 1. Batch 2680/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 94.00%
# Epoch 1. Batch 2690/4290: AvgLoss: 0.85, S.Acc: 67.14%, E.Acc: 94.01%
# Epoch 1. Batch 2700/4290: AvgLoss: 0.85, S.Acc: 67.13%, E.Acc: 94.01%
# Epoch 1. Batch 2710/4290: AvgLoss: 0.85, S.Acc: 67.11%, E.Acc: 94.01%
# Epoch 1. Batch 2720/4290: AvgLoss: 0.85, S.Acc: 67.13%, E.Acc: 94.00%
# Epoch 1. Batch 2730/4290: AvgLoss: 0.85, S.Acc: 67.13%, E.Acc: 94.01%
# Epoch 1. Batch 2740/4290: AvgLoss: 0.85, S.Acc: 67.14%, E.Acc: 94.01%
# Epoch 1. Batch 2750/4290: AvgLoss: 0.85, S.Acc: 67.13%, E.Acc: 94.02%
# Epoch 1. Batch 2760/4290: AvgLoss: 0.85, S.Acc: 67.13%, E.Acc: 94.03%
# Epoch 1. Batch 2770/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 94.03%
# Epoch 1. Batch 2780/4290: AvgLoss: 0.85, S.Acc: 67.11%, E.Acc: 94.04%
# Epoch 1. Batch 2790/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 94.03%
# Epoch 1. Batch 2800/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 94.03%
# Epoch 1. Batch 2810/4290: AvgLoss: 0.85, S.Acc: 67.11%, E.Acc: 94.02%
# Epoch 1. Batch 2820/4290: AvgLoss: 0.85, S.Acc: 67.09%, E.Acc: 94.01%
# Epoch 1. Batch 2830/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 94.01%
# Epoch 1. Batch 2840/4290: AvgLoss: 0.85, S.Acc: 67.13%, E.Acc: 94.02%
# Epoch 1. Batch 2850/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 94.02%
# Epoch 1. Batch 2860/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 94.01%
# Epoch 1. Batch 2870/4290: AvgLoss: 0.85, S.Acc: 67.13%, E.Acc: 94.02%
# Epoch 1. Batch 2880/4290: AvgLoss: 0.85, S.Acc: 67.16%, E.Acc: 94.03%
# Epoch 1. Batch 2890/4290: AvgLoss: 0.85, S.Acc: 67.18%, E.Acc: 94.04%
# Epoch 1. Batch 2900/4290: AvgLoss: 0.85, S.Acc: 67.16%, E.Acc: 94.04%
# Epoch 1. Batch 2910/4290: AvgLoss: 0.85, S.Acc: 67.15%, E.Acc: 94.04%
# Epoch 1. Batch 2920/4290: AvgLoss: 0.85, S.Acc: 67.18%, E.Acc: 94.05%
# Epoch 1. Batch 2930/4290: AvgLoss: 0.85, S.Acc: 67.18%, E.Acc: 94.04%
# Epoch 1. Batch 2940/4290: AvgLoss: 0.85, S.Acc: 67.20%, E.Acc: 94.04%
# Epoch 1. Batch 2950/4290: AvgLoss: 0.85, S.Acc: 67.20%, E.Acc: 94.04%
# Epoch 1. Batch 2960/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 94.04%
# Epoch 1. Batch 2970/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 94.04%
# Epoch 1. Batch 2980/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 94.04%
# Epoch 1. Batch 2990/4290: AvgLoss: 0.85, S.Acc: 67.25%, E.Acc: 94.04%
# Epoch 1. Batch 3000/4290: AvgLoss: 0.85, S.Acc: 67.26%, E.Acc: 94.04%
# Epoch 1. Batch 3010/4290: AvgLoss: 0.85, S.Acc: 67.26%, E.Acc: 94.04%
# Epoch 1. Batch 3020/4290: AvgLoss: 0.85, S.Acc: 67.26%, E.Acc: 94.03%
# Epoch 1. Batch 3030/4290: AvgLoss: 0.85, S.Acc: 67.27%, E.Acc: 94.03%
# Epoch 1. Batch 3040/4290: AvgLoss: 0.85, S.Acc: 67.27%, E.Acc: 94.03%
# Epoch 1. Batch 3050/4290: AvgLoss: 0.85, S.Acc: 67.26%, E.Acc: 94.02%
# Epoch 1. Batch 3060/4290: AvgLoss: 0.85, S.Acc: 67.25%, E.Acc: 94.02%
# Epoch 1. Batch 3070/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 94.01%
# Epoch 1. Batch 3080/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 94.02%
# Epoch 1. Batch 3090/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 94.02%
# Epoch 1. Batch 3100/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 94.01%
# Epoch 1. Batch 3110/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 94.01%
# Epoch 1. Batch 3120/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 94.00%
# Epoch 1. Batch 3130/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 94.00%
# Epoch 1. Batch 3140/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 94.00%
# Epoch 1. Batch 3150/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.99%
# Epoch 1. Batch 3160/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 94.00%
# Epoch 1. Batch 3170/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.99%
# Epoch 1. Batch 3180/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.98%
# Epoch 1. Batch 3190/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.99%
# Epoch 1. Batch 3200/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.99%
# Epoch 1. Batch 3210/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 94.00%
# Epoch 1. Batch 3220/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.99%
# Epoch 1. Batch 3230/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 93.98%
# Epoch 1. Batch 3240/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 93.99%
# Epoch 1. Batch 3250/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.98%
# Epoch 1. Batch 3260/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.96%
# Epoch 1. Batch 3270/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 93.96%
# Epoch 1. Batch 3280/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.96%
# Epoch 1. Batch 3290/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.95%
# Epoch 1. Batch 3300/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.94%
# Epoch 1. Batch 3310/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.94%
# Epoch 1. Batch 3320/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.93%
# Epoch 1. Batch 3330/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.93%
# Epoch 1. Batch 3340/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.94%
# Epoch 1. Batch 3350/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.94%
# Epoch 1. Batch 3360/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 93.94%
# Epoch 1. Batch 3370/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.94%
# Epoch 1. Batch 3380/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.93%
# Epoch 1. Batch 3390/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.92%
# Epoch 1. Batch 3400/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 93.92%
# Epoch 1. Batch 3410/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 93.91%
# Epoch 1. Batch 3420/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 93.91%
# Epoch 1. Batch 3430/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.92%
# Epoch 1. Batch 3440/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 93.92%
# Epoch 1. Batch 3450/4290: AvgLoss: 0.85, S.Acc: 67.25%, E.Acc: 93.93%
# Epoch 1. Batch 3460/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 93.94%
# Epoch 1. Batch 3470/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.94%
# Epoch 1. Batch 3480/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.95%
# Epoch 1. Batch 3490/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 93.95%
# Epoch 1. Batch 3500/4290: AvgLoss: 0.85, S.Acc: 67.18%, E.Acc: 93.95%
# Epoch 1. Batch 3510/4290: AvgLoss: 0.85, S.Acc: 67.17%, E.Acc: 93.95%
# Epoch 1. Batch 3520/4290: AvgLoss: 0.85, S.Acc: 67.18%, E.Acc: 93.95%
# Epoch 1. Batch 3530/4290: AvgLoss: 0.85, S.Acc: 67.20%, E.Acc: 93.95%
# Epoch 1. Batch 3540/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.96%
# Epoch 1. Batch 3550/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.96%
# Epoch 1. Batch 3560/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 93.96%
# Epoch 1. Batch 3570/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 93.96%
# Epoch 1. Batch 3580/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 93.95%
# Epoch 1. Batch 3590/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 93.96%
# Epoch 1. Batch 3600/4290: AvgLoss: 0.85, S.Acc: 67.20%, E.Acc: 93.96%
# Epoch 1. Batch 3610/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 93.95%
# Epoch 1. Batch 3620/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.96%
# Epoch 1. Batch 3630/4290: AvgLoss: 0.85, S.Acc: 67.23%, E.Acc: 93.95%
# Epoch 1. Batch 3640/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 93.95%
# Epoch 1. Batch 3650/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 93.95%
# Epoch 1. Batch 3660/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 93.95%
# Epoch 1. Batch 3670/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 93.96%
# Epoch 1. Batch 3680/4290: AvgLoss: 0.85, S.Acc: 67.26%, E.Acc: 93.96%
# Epoch 1. Batch 3690/4290: AvgLoss: 0.85, S.Acc: 67.26%, E.Acc: 93.96%
# Epoch 1. Batch 3700/4290: AvgLoss: 0.85, S.Acc: 67.26%, E.Acc: 93.96%
# Epoch 1. Batch 3710/4290: AvgLoss: 0.85, S.Acc: 67.28%, E.Acc: 93.97%
# Epoch 1. Batch 3720/4290: AvgLoss: 0.85, S.Acc: 67.27%, E.Acc: 93.96%
# Epoch 1. Batch 3730/4290: AvgLoss: 0.85, S.Acc: 67.27%, E.Acc: 93.97%
# Epoch 1. Batch 3740/4290: AvgLoss: 0.85, S.Acc: 67.25%, E.Acc: 93.96%
# Epoch 1. Batch 3750/4290: AvgLoss: 0.85, S.Acc: 67.27%, E.Acc: 93.96%
# Epoch 1. Batch 3760/4290: AvgLoss: 0.85, S.Acc: 67.25%, E.Acc: 93.96%
# Epoch 1. Batch 3770/4290: AvgLoss: 0.85, S.Acc: 67.25%, E.Acc: 93.97%
# Epoch 1. Batch 3780/4290: AvgLoss: 0.85, S.Acc: 67.25%, E.Acc: 93.97%
# Epoch 1. Batch 3790/4290: AvgLoss: 0.85, S.Acc: 67.26%, E.Acc: 93.98%
# Epoch 1. Batch 3800/4290: AvgLoss: 0.85, S.Acc: 67.26%, E.Acc: 93.98%
# Epoch 1. Batch 3810/4290: AvgLoss: 0.85, S.Acc: 67.25%, E.Acc: 93.97%
# Epoch 1. Batch 3820/4290: AvgLoss: 0.85, S.Acc: 67.24%, E.Acc: 93.98%
# Epoch 1. Batch 3830/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.99%
# Epoch 1. Batch 3840/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.99%
# Epoch 1. Batch 3850/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 93.99%
# Epoch 1. Batch 3860/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 93.99%
# Epoch 1. Batch 3870/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 94.00%
# Epoch 1. Batch 3880/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 94.00%
# Epoch 1. Batch 3890/4290: AvgLoss: 0.85, S.Acc: 67.22%, E.Acc: 94.00%
# Epoch 1. Batch 3900/4290: AvgLoss: 0.85, S.Acc: 67.21%, E.Acc: 94.00%
# Epoch 1. Batch 3910/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.99%
# Epoch 1. Batch 3920/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 94.00%
# Epoch 1. Batch 3930/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 94.00%
# Epoch 1. Batch 3940/4290: AvgLoss: 0.85, S.Acc: 67.18%, E.Acc: 94.00%
# Epoch 1. Batch 3950/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 94.00%
# Epoch 1. Batch 3960/4290: AvgLoss: 0.85, S.Acc: 67.18%, E.Acc: 94.01%
# Epoch 1. Batch 3970/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 94.01%
# Epoch 1. Batch 3980/4290: AvgLoss: 0.85, S.Acc: 67.16%, E.Acc: 94.01%
# Epoch 1. Batch 3990/4290: AvgLoss: 0.85, S.Acc: 67.17%, E.Acc: 94.01%
# Epoch 1. Batch 4000/4290: AvgLoss: 0.85, S.Acc: 67.18%, E.Acc: 94.01%
# Epoch 1. Batch 4010/4290: AvgLoss: 0.85, S.Acc: 67.17%, E.Acc: 94.01%
# Epoch 1. Batch 4020/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 94.00%
# Epoch 1. Batch 4030/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.99%
# Epoch 1. Batch 4040/4290: AvgLoss: 0.85, S.Acc: 67.18%, E.Acc: 93.99%
# Epoch 1. Batch 4050/4290: AvgLoss: 0.85, S.Acc: 67.18%, E.Acc: 93.99%
# Epoch 1. Batch 4060/4290: AvgLoss: 0.85, S.Acc: 67.18%, E.Acc: 93.99%
# Epoch 1. Batch 4070/4290: AvgLoss: 0.85, S.Acc: 67.17%, E.Acc: 93.99%
# Epoch 1. Batch 4080/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.99%
# Epoch 1. Batch 4090/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.99%
# Epoch 1. Batch 4100/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.99%
# Epoch 1. Batch 4110/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.99%
# Epoch 1. Batch 4120/4290: AvgLoss: 0.85, S.Acc: 67.19%, E.Acc: 93.98%
# Epoch 1. Batch 4130/4290: AvgLoss: 0.85, S.Acc: 67.17%, E.Acc: 93.99%
# Epoch 1. Batch 4140/4290: AvgLoss: 0.85, S.Acc: 67.15%, E.Acc: 93.99%
# Epoch 1. Batch 4150/4290: AvgLoss: 0.85, S.Acc: 67.16%, E.Acc: 93.98%
# Epoch 1. Batch 4160/4290: AvgLoss: 0.85, S.Acc: 67.16%, E.Acc: 93.98%
# Epoch 1. Batch 4170/4290: AvgLoss: 0.85, S.Acc: 67.16%, E.Acc: 93.98%
# Epoch 1. Batch 4180/4290: AvgLoss: 0.85, S.Acc: 67.16%, E.Acc: 93.99%
# Epoch 1. Batch 4190/4290: AvgLoss: 0.85, S.Acc: 67.16%, E.Acc: 93.99%
# Epoch 1. Batch 4200/4290: AvgLoss: 0.85, S.Acc: 67.16%, E.Acc: 93.99%
# Epoch 1. Batch 4210/4290: AvgLoss: 0.85, S.Acc: 67.14%, E.Acc: 93.99%
# Epoch 1. Batch 4220/4290: AvgLoss: 0.85, S.Acc: 67.15%, E.Acc: 93.99%
# Epoch 1. Batch 4230/4290: AvgLoss: 0.85, S.Acc: 67.13%, E.Acc: 93.99%
# Epoch 1. Batch 4240/4290: AvgLoss: 0.85, S.Acc: 67.13%, E.Acc: 93.99%
# Epoch 1. Batch 4250/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 93.99%
# Epoch 1. Batch 4260/4290: AvgLoss: 0.85, S.Acc: 67.13%, E.Acc: 93.99%
# Epoch 1. Batch 4270/4290: AvgLoss: 0.85, S.Acc: 67.13%, E.Acc: 93.99%
# Epoch 1. Batch 4280/4290: AvgLoss: 0.85, S.Acc: 67.12%, E.Acc: 93.99%
# Train Loss: 0.8529, Train Sentiment Accuracy: 67.11%, Train Emotion Accuracy: 93.99%
# Validation Sentiment Accuracy: 63.74%, Validation Emotion Accuracy: 94.05%

# %% [markdown]
# # Model evaluation

# %%
test_acc_sent, test_acc_emot = eval_model(model, test_loader, device)

print(f"Test Sentiment Accuracy: {test_acc_sent:.2f}%")
print(f"Test Emotion Accuracy: {test_acc_emot:.2f}%")
# Out:
# Test Sentiment Accuracy: 64.08%
# Test Emotion Accuracy: 94.00%

# %% [markdown]
# # Summary
#
# | Epoch        | Train Accuracy Sentiment | Validation Accuracy Sentiment | Train Accuracy Emotion | Validation Accuracy Emotion |
# |--------------|--------------------------|-------------------------------|------------------------|-----------------------------|
# | **Epoch 1**  | 48.51%                   | 61.67%                        | 62.08%                 | 93.48%                      |
# | **Epoch 2**  | 67.11%                   | 63.74%                        | 93.99%                 | 94.05%                      |
#
# ### Observation
# * The training accuracy for both sentiment and emotion classification steadily improves over epochs.

# %% [markdown]
# # Model serialization

# %%
torch.save(model.state_dict(), './GRU_multitask_model_underfitted/gru_multitask_model_underfitted.pth')
