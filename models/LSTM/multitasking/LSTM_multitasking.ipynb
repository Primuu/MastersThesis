# %% [markdown]
# # Model training: LSTM (multitasking)
#
# ---
#
# ## Table of Contents
#
# 1. [Imports](#imports)
# 2. [Data loading and splitting](#data-loading-and-splitting)
# 3. [Setting training parameters](#setting-training-parameters)
# 4. [Model training](#model-training)
# 5. [Model evaluation](#model-evaluation)
# 6. [Summary](#summary)
# 7. [Model serialization](#model-serialization)

# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# # Data loading and splitting

# %%
base_dir = os.path.abspath(os.path.join(os.path.dirname(os.getcwd()), '..'))

# %%
train_file_sentiment = os.path.join(base_dir, 'train_sentiment.csv')
val_file_sentiment = os.path.join(base_dir, 'val_sentiment.csv')
test_file_sentiment = os.path.join(base_dir, 'test_sentiment.csv')

if not all([os.path.exists(train_file_sentiment), os.path.exists(val_file_sentiment), os.path.exists(test_file_sentiment)]):
    sentiment_df = pd.read_parquet('../../data/sentiment_without_outliers/sentiment_without_outliers.parquet')
    sentiment_df = sentiment_df.drop(columns=['text_length'])
    
    train_data_sentiment, temp_data = train_test_split(sentiment_df, test_size=0.3, stratify=sentiment_df['label'], random_state=42)
    val_data_sentiment, test_data_sentiment = train_test_split(temp_data, test_size=0.5, stratify=temp_data['label'], random_state=42)

    train_data_sentiment.to_csv(train_file_sentiment, index=False)
    val_data_sentiment.to_csv(val_file_sentiment, index=False)
    test_data_sentiment.to_csv(test_file_sentiment, index=False)
else:
    train_data_sentiment = pd.read_csv(train_file_sentiment)
    val_data_sentiment = pd.read_csv(val_file_sentiment)
    test_data_sentiment = pd.read_csv(test_file_sentiment)

# %%
train_file_emotion = os.path.join(base_dir, 'train_emotion.csv')
val_file_emotion = os.path.join(base_dir, 'val_emotion.csv')
test_file_emotion = os.path.join(base_dir, 'test_emotion.csv')

if not all([os.path.exists(train_file_emotion), os.path.exists(val_file_emotion), os.path.exists(test_file_emotion)]):
    emotion_df = pd.read_parquet('../../data/emotion_without_outliers/emotion_without_outliers.parquet')
    emotion_df = emotion_df.drop(columns=['text_length'])
    
    target_samples_per_class = 16_667  # 100k / 6 classes of emotions
    
    balanced_data = emotion_df.groupby('label', group_keys=False).apply(
        lambda x: x.sample(n=min(len(x), target_samples_per_class), random_state=42)
    )
    
    train_data_emotion, temp_data = train_test_split(balanced_data, test_size=0.3, stratify=balanced_data['label'], random_state=42)
    val_data_emotion, test_data_emotion = train_test_split(temp_data, test_size=0.5, stratify=temp_data['label'], random_state=42)

    train_data_emotion.to_csv(train_file_emotion, index=False)
    val_data_emotion.to_csv(val_file_emotion, index=False)
    test_data_emotion.to_csv(test_file_emotion, index=False)
else:
    train_data_emotion = pd.read_csv(train_file_emotion)
    val_data_emotion = pd.read_csv(val_file_emotion)
    test_data_emotion = pd.read_csv(test_file_emotion)

# %% [markdown]
# # Setting training parameters
#
# Due to the uneven distribution of classes in the dataset, the classes will be weighted.

# %%
MAX_NUM_WORDS = 20000
MAX_SEQ_LENGTH = 256

tokenizer = Tokenizer(num_words=MAX_NUM_WORDS, oov_token="<OOV>")
tokenizer.fit_on_texts(train_data_sentiment['text'].tolist() + train_data_emotion['text'].tolist())

# %%
def encode_texts(texts):
    sequences = tokenizer.texts_to_sequences(texts)
    return pad_sequences(sequences, maxlen=MAX_SEQ_LENGTH, padding='post', truncating='post')

# %%
X_train_sentiment = encode_texts(train_data_sentiment['text'])
X_val_sentiment = encode_texts(val_data_sentiment['text'])
X_test_sentiment = encode_texts(test_data_sentiment['text'])

y_train_sentiment = train_data_sentiment['label'].values
y_val_sentiment = val_data_sentiment['label'].values
y_test_sentiment = test_data_sentiment['label'].values

# %%
X_train_emotion = encode_texts(train_data_emotion['text'])
X_val_emotion = encode_texts(val_data_emotion['text'])
X_test_emotion = encode_texts(test_data_emotion['text'])

y_train_emotion = train_data_emotion['label'].values
y_val_emotion = val_data_emotion['label'].values
y_test_emotion = test_data_emotion['label'].values

# %%
class_weights_sentiment = torch.tensor(compute_class_weight('balanced', classes=np.unique(y_train_sentiment), y=y_train_sentiment), dtype=torch.float)
class_weights_emotion = torch.tensor(compute_class_weight('balanced', classes=np.unique(y_train_emotion), y=y_train_emotion), dtype=torch.float)

# %%
class MultiTaskDataset(Dataset):
    def __init__(self, X_sent, y_sent, X_emot, y_emot):
        self.X_sent = torch.tensor(X_sent, dtype=torch.long)
        self.y_sent = torch.tensor(y_sent, dtype=torch.long)
        self.X_emot = torch.tensor(X_emot, dtype=torch.long)
        self.y_emot = torch.tensor(y_emot, dtype=torch.long)

    def __len__(self):
        return min(len(self.y_sent), len(self.y_emot))

    def __getitem__(self, idx):
        return {
            'input_ids_sent': self.X_sent[idx],
            'label_sent': self.y_sent[idx],
            'input_ids_emot': self.X_emot[idx],
            'label_emot': self.y_emot[idx]
        }

# %%
train_dataset = MultiTaskDataset(X_train_sentiment, y_train_sentiment, X_train_emotion, y_train_emotion)
val_dataset = MultiTaskDataset(X_val_sentiment, y_val_sentiment, X_val_emotion, y_val_emotion)
test_dataset = MultiTaskDataset(X_test_sentiment, y_test_sentiment, X_test_emotion, y_test_emotion)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)

# %% [markdown]
# # Model training

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class MultiTaskLSTM(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_labels_sentiment, num_labels_emotion):
        super(MultiTaskLSTM, self).__init__()
        self.relu = nn.ReLU()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True, bidirectional=True)
        self.dropout = nn.Dropout(0.5)
        self.fc_sentiment = nn.Linear(hidden_dim * 2, num_labels_sentiment)
        self.fc_emotion = nn.Linear(hidden_dim * 2, num_labels_emotion)
    
    def forward(self, input_ids_sent, input_ids_emot):
        embedded_sent = self.embedding(input_ids_sent)
        embedded_emot = self.embedding(input_ids_emot)

        lstm_out_sent, _ = self.lstm(embedded_sent)
        lstm_out_emot, _ = self.lstm(embedded_emot)

        pooled_sent = torch.mean(lstm_out_sent, dim=1)
        pooled_emot = torch.mean(lstm_out_emot, dim=1)

        dropped_sent = self.dropout(pooled_sent)
        dropped_emot = self.dropout(pooled_emot)

        out_sentiment = self.fc_sentiment(self.relu(dropped_sent))
        out_emotion = self.fc_emotion(self.relu(dropped_emot))

        return out_sentiment, out_emotion

# %%
model = MultiTaskLSTM(vocab_size=MAX_NUM_WORDS, embed_dim=256, hidden_dim=256, num_labels_sentiment=3, num_labels_emotion=6).to(device)

# %%
loss_fn_sentiment = nn.CrossEntropyLoss(weight=class_weights_sentiment.to(device))
loss_fn_emotion = nn.CrossEntropyLoss(weight=class_weights_emotion.to(device))
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
def train_epoch(model, data_loader, loss_fn_sent, loss_fn_emot, optimizer, device, epoch):
    model.train()
    total_loss = 0
    correct_sentiment = 0
    correct_emotion = 0
    total_sentiment_samples = 0
    total_emotion_samples = 0

    for batch_idx, batch in enumerate(data_loader):
        input_ids_sent = batch['input_ids_sent'].to(device)
        labels_sent = batch['label_sent'].to(device)
        input_ids_emot = batch['input_ids_emot'].to(device)
        labels_emot = batch['label_emot'].to(device)

        optimizer.zero_grad()

        logits_sent, logits_emot = model(input_ids_sent, input_ids_emot)

        loss_sent = loss_fn_sent(logits_sent, labels_sent)
        loss_emot = loss_fn_emot(logits_emot, labels_emot)

        loss = loss_sent + loss_emot
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        _, preds_sent = torch.max(logits_sent, dim=1)
        _, preds_emot = torch.max(logits_emot, dim=1)

        correct_sentiment += (preds_sent == labels_sent).sum().item()
        correct_emotion += (preds_emot == labels_emot).sum().item()
        total_sentiment_samples += labels_sent.size(0)
        total_emotion_samples += labels_emot.size(0)
        
        if batch_idx % 10 == 0:
            avg_loss = total_loss / (batch_idx + 1)
            acc_sent = 100. * correct_sentiment / total_sentiment_samples
            acc_emot = 100. * correct_emotion / total_emotion_samples
            print(f"Epoch {epoch}. Batch {batch_idx}/{len(data_loader)}: "
                  f"AvgLoss: {avg_loss:.2f}, S.Acc: {acc_sent:.2f}%, E.Acc: {acc_emot:.2f}%")

    avg_loss = total_loss / len(data_loader)
    accuracy_sentiment = 100. * correct_sentiment / total_sentiment_samples
    accuracy_emotion = 100. * correct_emotion / total_emotion_samples
    return avg_loss, accuracy_sentiment, accuracy_emotion

# %%
def eval_model(model, data_loader, device):
    model.eval()
    correct_sentiment = 0
    correct_emotion = 0
    total_sentiment_samples = 0
    total_emotion_samples = 0

    with torch.no_grad():
        for batch in data_loader:
            input_ids_sent = batch['input_ids_sent'].to(device)
            labels_sent = batch['label_sent'].to(device)
            input_ids_emot = batch['input_ids_emot'].to(device)
            labels_emot = batch['label_emot'].to(device)

            logits_sent, logits_emot = model(input_ids_sent, input_ids_emot)

            _, preds_sent = torch.max(logits_sent, dim=1)
            _, preds_emot = torch.max(logits_emot, dim=1)

            correct_sentiment += (preds_sent == labels_sent).sum().item()
            correct_emotion += (preds_emot == labels_emot).sum().item()
            total_sentiment_samples += labels_sent.size(0)
            total_emotion_samples += labels_emot.size(0)

    accuracy_sentiment = 100. * correct_sentiment / total_sentiment_samples
    accuracy_emotion = 100. * correct_emotion / total_emotion_samples
    return accuracy_sentiment, accuracy_emotion

# %%
for epoch in range(2):
    train_loss, train_acc_sent, train_acc_emot = train_epoch(
        model, train_loader, loss_fn_sentiment, loss_fn_emotion, optimizer, device, epoch
    )
    print(f"Train Loss: {train_loss:.4f}, "
          f"Train Sentiment Accuracy: {train_acc_sent:.2f}%, "
          f"Train Emotion Accuracy: {train_acc_emot:.2f}%")
    val_acc_sent, val_acc_emot = eval_model(model, val_loader, device)
    print(f"Validation Sentiment Accuracy: {val_acc_sent:.2f}%, Validation Emotion Accuracy: {val_acc_emot:.2f}%")
# Out:
# Epoch 0. Batch 0/4290: AvgLoss: 2.95, S.Acc: 43.75%, E.Acc: 12.50%
# Epoch 0. Batch 10/4290: AvgLoss: 2.94, S.Acc: 28.98%, E.Acc: 15.34%
# Epoch 0. Batch 20/4290: AvgLoss: 2.93, S.Acc: 32.14%, E.Acc: 16.96%
# Epoch 0. Batch 30/4290: AvgLoss: 2.94, S.Acc: 31.85%, E.Acc: 15.73%
# Epoch 0. Batch 40/4290: AvgLoss: 2.93, S.Acc: 31.40%, E.Acc: 16.31%
# Epoch 0. Batch 50/4290: AvgLoss: 2.93, S.Acc: 32.35%, E.Acc: 16.30%
# Epoch 0. Batch 60/4290: AvgLoss: 2.93, S.Acc: 31.35%, E.Acc: 16.29%
# Epoch 0. Batch 70/4290: AvgLoss: 2.93, S.Acc: 31.16%, E.Acc: 16.20%
# Epoch 0. Batch 80/4290: AvgLoss: 2.92, S.Acc: 30.94%, E.Acc: 16.51%
# Epoch 0. Batch 90/4290: AvgLoss: 2.92, S.Acc: 31.94%, E.Acc: 16.90%
# Epoch 0. Batch 100/4290: AvgLoss: 2.92, S.Acc: 31.75%, E.Acc: 16.58%
# Epoch 0. Batch 110/4290: AvgLoss: 2.92, S.Acc: 32.09%, E.Acc: 16.39%
# Epoch 0. Batch 120/4290: AvgLoss: 2.92, S.Acc: 31.77%, E.Acc: 16.43%
# Epoch 0. Batch 130/4290: AvgLoss: 2.91, S.Acc: 32.06%, E.Acc: 16.32%
# Epoch 0. Batch 140/4290: AvgLoss: 2.91, S.Acc: 32.71%, E.Acc: 16.18%
# Epoch 0. Batch 150/4290: AvgLoss: 2.91, S.Acc: 33.44%, E.Acc: 16.27%
# Epoch 0. Batch 160/4290: AvgLoss: 2.91, S.Acc: 34.12%, E.Acc: 16.38%
# Epoch 0. Batch 170/4290: AvgLoss: 2.91, S.Acc: 34.32%, E.Acc: 16.52%
# Epoch 0. Batch 180/4290: AvgLoss: 2.91, S.Acc: 34.63%, E.Acc: 16.54%
# Epoch 0. Batch 190/4290: AvgLoss: 2.91, S.Acc: 34.26%, E.Acc: 16.62%
# Epoch 0. Batch 200/4290: AvgLoss: 2.91, S.Acc: 34.42%, E.Acc: 16.88%
# Epoch 0. Batch 210/4290: AvgLoss: 2.91, S.Acc: 33.86%, E.Acc: 16.94%
# Epoch 0. Batch 220/4290: AvgLoss: 2.91, S.Acc: 33.60%, E.Acc: 17.02%
# Epoch 0. Batch 230/4290: AvgLoss: 2.91, S.Acc: 34.04%, E.Acc: 17.05%
# Epoch 0. Batch 240/4290: AvgLoss: 2.91, S.Acc: 34.10%, E.Acc: 16.99%
# Epoch 0. Batch 250/4290: AvgLoss: 2.91, S.Acc: 34.11%, E.Acc: 16.88%
# Epoch 0. Batch 260/4290: AvgLoss: 2.91, S.Acc: 34.20%, E.Acc: 16.79%
# Epoch 0. Batch 270/4290: AvgLoss: 2.91, S.Acc: 34.29%, E.Acc: 17.04%
# Epoch 0. Batch 280/4290: AvgLoss: 2.90, S.Acc: 34.39%, E.Acc: 17.17%
# Epoch 0. Batch 290/4290: AvgLoss: 2.90, S.Acc: 34.45%, E.Acc: 17.23%
# Epoch 0. Batch 300/4290: AvgLoss: 2.90, S.Acc: 34.63%, E.Acc: 17.28%
# Epoch 0. Batch 310/4290: AvgLoss: 2.90, S.Acc: 34.81%, E.Acc: 17.22%
# Epoch 0. Batch 320/4290: AvgLoss: 2.90, S.Acc: 34.87%, E.Acc: 17.19%
# Epoch 0. Batch 330/4290: AvgLoss: 2.90, S.Acc: 34.76%, E.Acc: 17.30%
# Epoch 0. Batch 340/4290: AvgLoss: 2.90, S.Acc: 34.62%, E.Acc: 17.38%
# Epoch 0. Batch 350/4290: AvgLoss: 2.90, S.Acc: 34.70%, E.Acc: 17.54%
# Epoch 0. Batch 360/4290: AvgLoss: 2.90, S.Acc: 35.02%, E.Acc: 17.50%
# Epoch 0. Batch 370/4290: AvgLoss: 2.90, S.Acc: 35.18%, E.Acc: 17.49%
# Epoch 0. Batch 380/4290: AvgLoss: 2.90, S.Acc: 35.42%, E.Acc: 17.39%
# Epoch 0. Batch 390/4290: AvgLoss: 2.90, S.Acc: 35.36%, E.Acc: 17.49%
# Epoch 0. Batch 400/4290: AvgLoss: 2.90, S.Acc: 35.24%, E.Acc: 17.53%
# Epoch 0. Batch 410/4290: AvgLoss: 2.90, S.Acc: 35.34%, E.Acc: 17.66%
# Epoch 0. Batch 420/4290: AvgLoss: 2.90, S.Acc: 35.64%, E.Acc: 17.76%
# Epoch 0. Batch 430/4290: AvgLoss: 2.90, S.Acc: 35.83%, E.Acc: 17.87%
# Epoch 0. Batch 440/4290: AvgLoss: 2.89, S.Acc: 36.18%, E.Acc: 18.06%
# Epoch 0. Batch 450/4290: AvgLoss: 2.89, S.Acc: 36.57%, E.Acc: 18.15%
# Epoch 0. Batch 460/4290: AvgLoss: 2.89, S.Acc: 36.65%, E.Acc: 18.23%
# Epoch 0. Batch 470/4290: AvgLoss: 2.89, S.Acc: 36.57%, E.Acc: 18.27%
# Epoch 0. Batch 480/4290: AvgLoss: 2.89, S.Acc: 36.68%, E.Acc: 18.58%
# Epoch 0. Batch 490/4290: AvgLoss: 2.89, S.Acc: 36.90%, E.Acc: 18.74%
# Epoch 0. Batch 500/4290: AvgLoss: 2.89, S.Acc: 37.04%, E.Acc: 18.76%
# Epoch 0. Batch 510/4290: AvgLoss: 2.89, S.Acc: 37.26%, E.Acc: 18.81%
# Epoch 0. Batch 520/4290: AvgLoss: 2.88, S.Acc: 37.37%, E.Acc: 18.91%
# Epoch 0. Batch 530/4290: AvgLoss: 2.88, S.Acc: 37.52%, E.Acc: 18.97%
# Epoch 0. Batch 540/4290: AvgLoss: 2.88, S.Acc: 37.72%, E.Acc: 19.07%
# Epoch 0. Batch 550/4290: AvgLoss: 2.88, S.Acc: 37.65%, E.Acc: 19.20%
# Epoch 0. Batch 560/4290: AvgLoss: 2.88, S.Acc: 37.73%, E.Acc: 19.39%
# Epoch 0. Batch 570/4290: AvgLoss: 2.88, S.Acc: 37.82%, E.Acc: 19.52%
# Epoch 0. Batch 580/4290: AvgLoss: 2.87, S.Acc: 37.97%, E.Acc: 19.62%
# Epoch 0. Batch 590/4290: AvgLoss: 2.87, S.Acc: 37.90%, E.Acc: 19.77%
# Epoch 0. Batch 600/4290: AvgLoss: 2.87, S.Acc: 37.86%, E.Acc: 19.89%
# Epoch 0. Batch 610/4290: AvgLoss: 2.87, S.Acc: 37.92%, E.Acc: 20.03%
# Epoch 0. Batch 620/4290: AvgLoss: 2.87, S.Acc: 38.02%, E.Acc: 20.03%
# Epoch 0. Batch 630/4290: AvgLoss: 2.87, S.Acc: 38.02%, E.Acc: 20.09%
# Epoch 0. Batch 640/4290: AvgLoss: 2.87, S.Acc: 38.16%, E.Acc: 20.20%
# Epoch 0. Batch 650/4290: AvgLoss: 2.86, S.Acc: 38.33%, E.Acc: 20.32%
# Epoch 0. Batch 660/4290: AvgLoss: 2.86, S.Acc: 38.35%, E.Acc: 20.44%
# Epoch 0. Batch 670/4290: AvgLoss: 2.86, S.Acc: 38.38%, E.Acc: 20.66%
# Epoch 0. Batch 680/4290: AvgLoss: 2.86, S.Acc: 38.36%, E.Acc: 20.79%
# Epoch 0. Batch 690/4290: AvgLoss: 2.85, S.Acc: 38.39%, E.Acc: 20.89%
# Epoch 0. Batch 700/4290: AvgLoss: 2.85, S.Acc: 38.55%, E.Acc: 21.07%
# Epoch 0. Batch 710/4290: AvgLoss: 2.85, S.Acc: 38.69%, E.Acc: 21.16%
# Epoch 0. Batch 720/4290: AvgLoss: 2.84, S.Acc: 38.87%, E.Acc: 21.44%
# Epoch 0. Batch 730/4290: AvgLoss: 2.84, S.Acc: 39.13%, E.Acc: 21.65%
# Epoch 0. Batch 740/4290: AvgLoss: 2.84, S.Acc: 39.25%, E.Acc: 21.77%
# Epoch 0. Batch 750/4290: AvgLoss: 2.83, S.Acc: 39.33%, E.Acc: 21.84%
# Epoch 0. Batch 760/4290: AvgLoss: 2.83, S.Acc: 39.39%, E.Acc: 22.02%
# Epoch 0. Batch 770/4290: AvgLoss: 2.83, S.Acc: 39.41%, E.Acc: 22.14%
# Epoch 0. Batch 780/4290: AvgLoss: 2.82, S.Acc: 39.54%, E.Acc: 22.34%
# Epoch 0. Batch 790/4290: AvgLoss: 2.82, S.Acc: 39.49%, E.Acc: 22.48%
# Epoch 0. Batch 800/4290: AvgLoss: 2.82, S.Acc: 39.59%, E.Acc: 22.71%
# Epoch 0. Batch 810/4290: AvgLoss: 2.81, S.Acc: 39.72%, E.Acc: 22.91%
# Epoch 0. Batch 820/4290: AvgLoss: 2.81, S.Acc: 39.88%, E.Acc: 23.07%
# Epoch 0. Batch 830/4290: AvgLoss: 2.80, S.Acc: 40.00%, E.Acc: 23.27%
# Epoch 0. Batch 840/4290: AvgLoss: 2.80, S.Acc: 40.01%, E.Acc: 23.42%
# Epoch 0. Batch 850/4290: AvgLoss: 2.80, S.Acc: 40.10%, E.Acc: 23.58%
# Epoch 0. Batch 860/4290: AvgLoss: 2.79, S.Acc: 40.25%, E.Acc: 23.74%
# Epoch 0. Batch 870/4290: AvgLoss: 2.79, S.Acc: 40.40%, E.Acc: 23.99%
# Epoch 0. Batch 880/4290: AvgLoss: 2.78, S.Acc: 40.44%, E.Acc: 24.23%
# Epoch 0. Batch 890/4290: AvgLoss: 2.78, S.Acc: 40.44%, E.Acc: 24.40%
# Epoch 0. Batch 900/4290: AvgLoss: 2.78, S.Acc: 40.48%, E.Acc: 24.62%
# Epoch 0. Batch 910/4290: AvgLoss: 2.77, S.Acc: 40.53%, E.Acc: 24.84%
# Epoch 0. Batch 920/4290: AvgLoss: 2.77, S.Acc: 40.59%, E.Acc: 25.08%
# Epoch 0. Batch 930/4290: AvgLoss: 2.76, S.Acc: 40.63%, E.Acc: 25.27%
# Epoch 0. Batch 940/4290: AvgLoss: 2.76, S.Acc: 40.77%, E.Acc: 25.39%
# Epoch 0. Batch 950/4290: AvgLoss: 2.75, S.Acc: 40.88%, E.Acc: 25.57%
# Epoch 0. Batch 960/4290: AvgLoss: 2.75, S.Acc: 40.94%, E.Acc: 25.75%
# Epoch 0. Batch 970/4290: AvgLoss: 2.74, S.Acc: 41.05%, E.Acc: 25.98%
# Epoch 0. Batch 980/4290: AvgLoss: 2.74, S.Acc: 41.21%, E.Acc: 26.22%
# Epoch 0. Batch 990/4290: AvgLoss: 2.73, S.Acc: 41.32%, E.Acc: 26.36%
# Epoch 0. Batch 1000/4290: AvgLoss: 2.73, S.Acc: 41.37%, E.Acc: 26.55%
# Epoch 0. Batch 1010/4290: AvgLoss: 2.72, S.Acc: 41.46%, E.Acc: 26.74%
# Epoch 0. Batch 1020/4290: AvgLoss: 2.72, S.Acc: 41.53%, E.Acc: 26.93%
# Epoch 0. Batch 1030/4290: AvgLoss: 2.71, S.Acc: 41.60%, E.Acc: 27.12%
# Epoch 0. Batch 1040/4290: AvgLoss: 2.71, S.Acc: 41.68%, E.Acc: 27.39%
# Epoch 0. Batch 1050/4290: AvgLoss: 2.70, S.Acc: 41.79%, E.Acc: 27.61%
# Epoch 0. Batch 1060/4290: AvgLoss: 2.70, S.Acc: 41.88%, E.Acc: 27.90%
# Epoch 0. Batch 1070/4290: AvgLoss: 2.69, S.Acc: 41.98%, E.Acc: 28.15%
# Epoch 0. Batch 1080/4290: AvgLoss: 2.68, S.Acc: 42.04%, E.Acc: 28.42%
# Epoch 0. Batch 1090/4290: AvgLoss: 2.68, S.Acc: 42.13%, E.Acc: 28.64%
# Epoch 0. Batch 1100/4290: AvgLoss: 2.67, S.Acc: 42.19%, E.Acc: 28.96%
# Epoch 0. Batch 1110/4290: AvgLoss: 2.67, S.Acc: 42.25%, E.Acc: 29.26%
# Epoch 0. Batch 1120/4290: AvgLoss: 2.66, S.Acc: 42.32%, E.Acc: 29.49%
# Epoch 0. Batch 1130/4290: AvgLoss: 2.66, S.Acc: 42.43%, E.Acc: 29.71%
# Epoch 0. Batch 1140/4290: AvgLoss: 2.65, S.Acc: 42.52%, E.Acc: 29.93%
# Epoch 0. Batch 1150/4290: AvgLoss: 2.64, S.Acc: 42.65%, E.Acc: 30.18%
# Epoch 0. Batch 1160/4290: AvgLoss: 2.64, S.Acc: 42.73%, E.Acc: 30.44%
# Epoch 0. Batch 1170/4290: AvgLoss: 2.63, S.Acc: 42.82%, E.Acc: 30.73%
# Epoch 0. Batch 1180/4290: AvgLoss: 2.62, S.Acc: 42.91%, E.Acc: 30.96%
# Epoch 0. Batch 1190/4290: AvgLoss: 2.62, S.Acc: 43.05%, E.Acc: 31.19%
# Epoch 0. Batch 1200/4290: AvgLoss: 2.61, S.Acc: 43.10%, E.Acc: 31.43%
# Epoch 0. Batch 1210/4290: AvgLoss: 2.61, S.Acc: 43.19%, E.Acc: 31.67%
# Epoch 0. Batch 1220/4290: AvgLoss: 2.60, S.Acc: 43.26%, E.Acc: 31.89%
# Epoch 0. Batch 1230/4290: AvgLoss: 2.60, S.Acc: 43.30%, E.Acc: 32.18%
# Epoch 0. Batch 1240/4290: AvgLoss: 2.59, S.Acc: 43.33%, E.Acc: 32.46%
# Epoch 0. Batch 1250/4290: AvgLoss: 2.59, S.Acc: 43.42%, E.Acc: 32.76%
# Epoch 0. Batch 1260/4290: AvgLoss: 2.58, S.Acc: 43.43%, E.Acc: 33.01%
# Epoch 0. Batch 1270/4290: AvgLoss: 2.57, S.Acc: 43.47%, E.Acc: 33.29%
# Epoch 0. Batch 1280/4290: AvgLoss: 2.57, S.Acc: 43.56%, E.Acc: 33.52%
# Epoch 0. Batch 1290/4290: AvgLoss: 2.56, S.Acc: 43.71%, E.Acc: 33.77%
# Epoch 0. Batch 1300/4290: AvgLoss: 2.56, S.Acc: 43.80%, E.Acc: 34.03%
# Epoch 0. Batch 1310/4290: AvgLoss: 2.55, S.Acc: 43.89%, E.Acc: 34.27%
# Epoch 0. Batch 1320/4290: AvgLoss: 2.55, S.Acc: 43.96%, E.Acc: 34.46%
# Epoch 0. Batch 1330/4290: AvgLoss: 2.54, S.Acc: 44.00%, E.Acc: 34.68%
# Epoch 0. Batch 1340/4290: AvgLoss: 2.54, S.Acc: 44.12%, E.Acc: 34.90%
# Epoch 0. Batch 1350/4290: AvgLoss: 2.53, S.Acc: 44.20%, E.Acc: 35.16%
# Epoch 0. Batch 1360/4290: AvgLoss: 2.52, S.Acc: 44.26%, E.Acc: 35.37%
# Epoch 0. Batch 1370/4290: AvgLoss: 2.52, S.Acc: 44.29%, E.Acc: 35.62%
# Epoch 0. Batch 1380/4290: AvgLoss: 2.51, S.Acc: 44.36%, E.Acc: 35.87%
# Epoch 0. Batch 1390/4290: AvgLoss: 2.51, S.Acc: 44.41%, E.Acc: 36.08%
# Epoch 0. Batch 1400/4290: AvgLoss: 2.50, S.Acc: 44.44%, E.Acc: 36.28%
# Epoch 0. Batch 1410/4290: AvgLoss: 2.50, S.Acc: 44.47%, E.Acc: 36.51%
# Epoch 0. Batch 1420/4290: AvgLoss: 2.49, S.Acc: 44.55%, E.Acc: 36.74%
# Epoch 0. Batch 1430/4290: AvgLoss: 2.48, S.Acc: 44.63%, E.Acc: 36.97%
# Epoch 0. Batch 1440/4290: AvgLoss: 2.48, S.Acc: 44.67%, E.Acc: 37.23%
# Epoch 0. Batch 1450/4290: AvgLoss: 2.47, S.Acc: 44.74%, E.Acc: 37.50%
# Epoch 0. Batch 1460/4290: AvgLoss: 2.47, S.Acc: 44.80%, E.Acc: 37.71%
# Epoch 0. Batch 1470/4290: AvgLoss: 2.46, S.Acc: 44.82%, E.Acc: 37.92%
# Epoch 0. Batch 1480/4290: AvgLoss: 2.46, S.Acc: 44.88%, E.Acc: 38.15%
# Epoch 0. Batch 1490/4290: AvgLoss: 2.45, S.Acc: 44.92%, E.Acc: 38.35%
# Epoch 0. Batch 1500/4290: AvgLoss: 2.45, S.Acc: 44.95%, E.Acc: 38.60%
# Epoch 0. Batch 1510/4290: AvgLoss: 2.44, S.Acc: 45.04%, E.Acc: 38.85%
# Epoch 0. Batch 1520/4290: AvgLoss: 2.44, S.Acc: 45.09%, E.Acc: 39.05%
# Epoch 0. Batch 1530/4290: AvgLoss: 2.43, S.Acc: 45.17%, E.Acc: 39.27%
# Epoch 0. Batch 1540/4290: AvgLoss: 2.42, S.Acc: 45.23%, E.Acc: 39.44%
# Epoch 0. Batch 1550/4290: AvgLoss: 2.42, S.Acc: 45.31%, E.Acc: 39.65%
# Epoch 0. Batch 1560/4290: AvgLoss: 2.41, S.Acc: 45.38%, E.Acc: 39.90%
# Epoch 0. Batch 1570/4290: AvgLoss: 2.41, S.Acc: 45.39%, E.Acc: 40.11%
# Epoch 0. Batch 1580/4290: AvgLoss: 2.40, S.Acc: 45.42%, E.Acc: 40.33%
# Epoch 0. Batch 1590/4290: AvgLoss: 2.40, S.Acc: 45.44%, E.Acc: 40.56%
# Epoch 0. Batch 1600/4290: AvgLoss: 2.39, S.Acc: 45.48%, E.Acc: 40.80%
# Epoch 0. Batch 1610/4290: AvgLoss: 2.39, S.Acc: 45.50%, E.Acc: 41.07%
# Epoch 0. Batch 1620/4290: AvgLoss: 2.38, S.Acc: 45.53%, E.Acc: 41.29%
# Epoch 0. Batch 1630/4290: AvgLoss: 2.38, S.Acc: 45.61%, E.Acc: 41.49%
# Epoch 0. Batch 1640/4290: AvgLoss: 2.37, S.Acc: 45.69%, E.Acc: 41.70%
# Epoch 0. Batch 1650/4290: AvgLoss: 2.37, S.Acc: 45.75%, E.Acc: 41.90%
# Epoch 0. Batch 1660/4290: AvgLoss: 2.36, S.Acc: 45.82%, E.Acc: 42.12%
# Epoch 0. Batch 1670/4290: AvgLoss: 2.36, S.Acc: 45.85%, E.Acc: 42.31%
# Epoch 0. Batch 1680/4290: AvgLoss: 2.35, S.Acc: 45.90%, E.Acc: 42.51%
# Epoch 0. Batch 1690/4290: AvgLoss: 2.35, S.Acc: 45.94%, E.Acc: 42.68%
# Epoch 0. Batch 1700/4290: AvgLoss: 2.35, S.Acc: 46.01%, E.Acc: 42.85%
# Epoch 0. Batch 1990/4290: AvgLoss: 2.21, S.Acc: 47.32%, E.Acc: 48.61%
# Epoch 0. Batch 2000/4290: AvgLoss: 2.21, S.Acc: 47.37%, E.Acc: 48.77%
# Epoch 0. Batch 2010/4290: AvgLoss: 2.20, S.Acc: 47.42%, E.Acc: 48.93%
# Epoch 0. Batch 2020/4290: AvgLoss: 2.20, S.Acc: 47.49%, E.Acc: 49.10%
# Epoch 0. Batch 2030/4290: AvgLoss: 2.19, S.Acc: 47.53%, E.Acc: 49.30%
# Epoch 0. Batch 2040/4290: AvgLoss: 2.19, S.Acc: 47.55%, E.Acc: 49.47%
# Epoch 0. Batch 2050/4290: AvgLoss: 2.18, S.Acc: 47.58%, E.Acc: 49.65%
# Epoch 0. Batch 2060/4290: AvgLoss: 2.18, S.Acc: 47.70%, E.Acc: 49.82%
# Epoch 0. Batch 2070/4290: AvgLoss: 2.18, S.Acc: 47.74%, E.Acc: 49.99%
# Epoch 0. Batch 2080/4290: AvgLoss: 2.17, S.Acc: 47.76%, E.Acc: 50.16%
# Epoch 0. Batch 2090/4290: AvgLoss: 2.17, S.Acc: 47.82%, E.Acc: 50.34%
# Epoch 0. Batch 2100/4290: AvgLoss: 2.16, S.Acc: 47.85%, E.Acc: 50.51%
# Epoch 0. Batch 2110/4290: AvgLoss: 2.16, S.Acc: 47.88%, E.Acc: 50.70%
# Epoch 0. Batch 2120/4290: AvgLoss: 2.15, S.Acc: 47.93%, E.Acc: 50.87%
# Epoch 0. Batch 2130/4290: AvgLoss: 2.15, S.Acc: 47.98%, E.Acc: 51.05%
# Epoch 0. Batch 2140/4290: AvgLoss: 2.15, S.Acc: 48.06%, E.Acc: 51.21%
# Epoch 0. Batch 2150/4290: AvgLoss: 2.14, S.Acc: 48.15%, E.Acc: 51.38%
# Epoch 0. Batch 2160/4290: AvgLoss: 2.14, S.Acc: 48.19%, E.Acc: 51.58%
# Epoch 0. Batch 2170/4290: AvgLoss: 2.13, S.Acc: 48.24%, E.Acc: 51.74%
# Epoch 0. Batch 2180/4290: AvgLoss: 2.13, S.Acc: 48.28%, E.Acc: 51.92%
# Epoch 0. Batch 2190/4290: AvgLoss: 2.12, S.Acc: 48.36%, E.Acc: 52.09%
# Epoch 0. Batch 2200/4290: AvgLoss: 2.12, S.Acc: 48.41%, E.Acc: 52.23%
# Epoch 0. Batch 2210/4290: AvgLoss: 2.12, S.Acc: 48.45%, E.Acc: 52.39%
# Epoch 0. Batch 2220/4290: AvgLoss: 2.11, S.Acc: 48.48%, E.Acc: 52.53%
# Epoch 0. Batch 2230/4290: AvgLoss: 2.11, S.Acc: 48.52%, E.Acc: 52.69%
# Epoch 0. Batch 2240/4290: AvgLoss: 2.11, S.Acc: 48.55%, E.Acc: 52.86%
# Epoch 0. Batch 2250/4290: AvgLoss: 2.10, S.Acc: 48.62%, E.Acc: 53.00%
# Epoch 0. Batch 2260/4290: AvgLoss: 2.10, S.Acc: 48.66%, E.Acc: 53.15%
# Epoch 0. Batch 2270/4290: AvgLoss: 2.09, S.Acc: 48.71%, E.Acc: 53.31%
# Epoch 0. Batch 2280/4290: AvgLoss: 2.09, S.Acc: 48.75%, E.Acc: 53.46%
# Epoch 0. Batch 2290/4290: AvgLoss: 2.09, S.Acc: 48.81%, E.Acc: 53.62%
# Epoch 0. Batch 2300/4290: AvgLoss: 2.08, S.Acc: 48.83%, E.Acc: 53.77%
# Epoch 0. Batch 2310/4290: AvgLoss: 2.08, S.Acc: 48.90%, E.Acc: 53.93%
# Epoch 0. Batch 2320/4290: AvgLoss: 2.08, S.Acc: 48.93%, E.Acc: 54.07%
# Epoch 0. Batch 2330/4290: AvgLoss: 2.07, S.Acc: 48.98%, E.Acc: 54.20%
# Epoch 0. Batch 2340/4290: AvgLoss: 2.07, S.Acc: 49.03%, E.Acc: 54.35%
# Epoch 0. Batch 2350/4290: AvgLoss: 2.07, S.Acc: 49.09%, E.Acc: 54.48%
# Epoch 0. Batch 2360/4290: AvgLoss: 2.06, S.Acc: 49.11%, E.Acc: 54.63%
# Epoch 0. Batch 2370/4290: AvgLoss: 2.06, S.Acc: 49.14%, E.Acc: 54.77%
# Epoch 0. Batch 2380/4290: AvgLoss: 2.06, S.Acc: 49.17%, E.Acc: 54.90%
# Epoch 0. Batch 2390/4290: AvgLoss: 2.05, S.Acc: 49.21%, E.Acc: 55.05%
# Epoch 0. Batch 2400/4290: AvgLoss: 2.05, S.Acc: 49.25%, E.Acc: 55.20%
# Epoch 0. Batch 2410/4290: AvgLoss: 2.04, S.Acc: 49.29%, E.Acc: 55.34%
# Epoch 0. Batch 2420/4290: AvgLoss: 2.04, S.Acc: 49.31%, E.Acc: 55.49%
# Epoch 0. Batch 2430/4290: AvgLoss: 2.04, S.Acc: 49.33%, E.Acc: 55.64%
# Epoch 0. Batch 2440/4290: AvgLoss: 2.03, S.Acc: 49.37%, E.Acc: 55.77%
# Epoch 0. Batch 2450/4290: AvgLoss: 2.03, S.Acc: 49.43%, E.Acc: 55.92%
# Epoch 0. Batch 2460/4290: AvgLoss: 2.03, S.Acc: 49.46%, E.Acc: 56.06%
# Epoch 0. Batch 2470/4290: AvgLoss: 2.02, S.Acc: 49.52%, E.Acc: 56.19%
# Epoch 0. Batch 2480/4290: AvgLoss: 2.02, S.Acc: 49.54%, E.Acc: 56.34%
# Epoch 0. Batch 2490/4290: AvgLoss: 2.02, S.Acc: 49.59%, E.Acc: 56.48%
# Epoch 0. Batch 2500/4290: AvgLoss: 2.01, S.Acc: 49.59%, E.Acc: 56.61%
# Epoch 0. Batch 2510/4290: AvgLoss: 2.01, S.Acc: 49.61%, E.Acc: 56.75%
# Epoch 0. Batch 2520/4290: AvgLoss: 2.01, S.Acc: 49.65%, E.Acc: 56.88%
# Epoch 0. Batch 2530/4290: AvgLoss: 2.00, S.Acc: 49.65%, E.Acc: 57.03%
# Epoch 0. Batch 2540/4290: AvgLoss: 2.00, S.Acc: 49.65%, E.Acc: 57.16%
# Epoch 0. Batch 2550/4290: AvgLoss: 2.00, S.Acc: 49.70%, E.Acc: 57.30%
# Epoch 0. Batch 2560/4290: AvgLoss: 1.99, S.Acc: 49.72%, E.Acc: 57.41%
# Epoch 0. Batch 2570/4290: AvgLoss: 1.99, S.Acc: 49.77%, E.Acc: 57.54%
# Epoch 0. Batch 2580/4290: AvgLoss: 1.99, S.Acc: 49.80%, E.Acc: 57.67%
# Epoch 0. Batch 2590/4290: AvgLoss: 1.98, S.Acc: 49.86%, E.Acc: 57.81%
# Epoch 0. Batch 2600/4290: AvgLoss: 1.98, S.Acc: 49.91%, E.Acc: 57.95%
# Epoch 0. Batch 2610/4290: AvgLoss: 1.98, S.Acc: 49.95%, E.Acc: 58.06%
# Epoch 0. Batch 2620/4290: AvgLoss: 1.97, S.Acc: 49.99%, E.Acc: 58.17%
# Epoch 0. Batch 2630/4290: AvgLoss: 1.97, S.Acc: 50.01%, E.Acc: 58.30%
# Epoch 0. Batch 2640/4290: AvgLoss: 1.97, S.Acc: 50.05%, E.Acc: 58.43%
# Epoch 0. Batch 2650/4290: AvgLoss: 1.96, S.Acc: 50.07%, E.Acc: 58.54%
# Epoch 0. Batch 2660/4290: AvgLoss: 1.96, S.Acc: 50.10%, E.Acc: 58.67%
# Epoch 0. Batch 2670/4290: AvgLoss: 1.96, S.Acc: 50.12%, E.Acc: 58.80%
# Epoch 0. Batch 2680/4290: AvgLoss: 1.95, S.Acc: 50.14%, E.Acc: 58.91%
# Epoch 0. Batch 2690/4290: AvgLoss: 1.95, S.Acc: 50.19%, E.Acc: 59.04%
# Epoch 0. Batch 2700/4290: AvgLoss: 1.95, S.Acc: 50.22%, E.Acc: 59.17%
# Epoch 0. Batch 2710/4290: AvgLoss: 1.94, S.Acc: 50.27%, E.Acc: 59.28%
# Epoch 0. Batch 2720/4290: AvgLoss: 1.94, S.Acc: 50.31%, E.Acc: 59.40%
# Epoch 0. Batch 2730/4290: AvgLoss: 1.94, S.Acc: 50.32%, E.Acc: 59.51%
# Epoch 0. Batch 2740/4290: AvgLoss: 1.94, S.Acc: 50.37%, E.Acc: 59.62%
# Epoch 0. Batch 2750/4290: AvgLoss: 1.93, S.Acc: 50.40%, E.Acc: 59.73%
# Epoch 0. Batch 2760/4290: AvgLoss: 1.93, S.Acc: 50.42%, E.Acc: 59.84%
# Epoch 0. Batch 2770/4290: AvgLoss: 1.93, S.Acc: 50.48%, E.Acc: 59.95%
# Epoch 0. Batch 2780/4290: AvgLoss: 1.92, S.Acc: 50.53%, E.Acc: 60.06%
# Epoch 0. Batch 2790/4290: AvgLoss: 1.92, S.Acc: 50.57%, E.Acc: 60.18%
# Epoch 0. Batch 2800/4290: AvgLoss: 1.92, S.Acc: 50.62%, E.Acc: 60.29%
# Epoch 0. Batch 2810/4290: AvgLoss: 1.91, S.Acc: 50.63%, E.Acc: 60.40%
# Epoch 0. Batch 2820/4290: AvgLoss: 1.91, S.Acc: 50.65%, E.Acc: 60.51%
# Epoch 0. Batch 2830/4290: AvgLoss: 1.91, S.Acc: 50.69%, E.Acc: 60.62%
# Epoch 0. Batch 2840/4290: AvgLoss: 1.91, S.Acc: 50.71%, E.Acc: 60.72%
# Epoch 0. Batch 2850/4290: AvgLoss: 1.90, S.Acc: 50.74%, E.Acc: 60.83%
# Epoch 0. Batch 2860/4290: AvgLoss: 1.90, S.Acc: 50.76%, E.Acc: 60.93%
# Epoch 0. Batch 2870/4290: AvgLoss: 1.90, S.Acc: 50.79%, E.Acc: 61.02%
# Epoch 0. Batch 2880/4290: AvgLoss: 1.90, S.Acc: 50.79%, E.Acc: 61.12%
# Epoch 0. Batch 2890/4290: AvgLoss: 1.89, S.Acc: 50.84%, E.Acc: 61.24%
# Epoch 0. Batch 2900/4290: AvgLoss: 1.89, S.Acc: 50.89%, E.Acc: 61.34%
# Epoch 0. Batch 2910/4290: AvgLoss: 1.89, S.Acc: 50.94%, E.Acc: 61.45%
# Epoch 0. Batch 2920/4290: AvgLoss: 1.88, S.Acc: 50.99%, E.Acc: 61.57%
# Epoch 0. Batch 2930/4290: AvgLoss: 1.88, S.Acc: 51.01%, E.Acc: 61.66%
# Epoch 0. Batch 2940/4290: AvgLoss: 1.88, S.Acc: 51.06%, E.Acc: 61.76%
# Epoch 0. Batch 2950/4290: AvgLoss: 1.88, S.Acc: 51.09%, E.Acc: 61.87%
# Epoch 0. Batch 2960/4290: AvgLoss: 1.87, S.Acc: 51.09%, E.Acc: 61.98%
# Epoch 0. Batch 2970/4290: AvgLoss: 1.87, S.Acc: 51.13%, E.Acc: 62.09%
# Epoch 0. Batch 2980/4290: AvgLoss: 1.87, S.Acc: 51.17%, E.Acc: 62.19%
# Epoch 0. Batch 2990/4290: AvgLoss: 1.87, S.Acc: 51.21%, E.Acc: 62.30%
# Epoch 0. Batch 3000/4290: AvgLoss: 1.86, S.Acc: 51.24%, E.Acc: 62.40%
# Epoch 0. Batch 3010/4290: AvgLoss: 1.86, S.Acc: 51.26%, E.Acc: 62.51%
# Epoch 0. Batch 3020/4290: AvgLoss: 1.86, S.Acc: 51.29%, E.Acc: 62.61%
# Epoch 0. Batch 3030/4290: AvgLoss: 1.85, S.Acc: 51.31%, E.Acc: 62.70%
# Epoch 0. Batch 3040/4290: AvgLoss: 1.85, S.Acc: 51.34%, E.Acc: 62.80%
# Epoch 0. Batch 3050/4290: AvgLoss: 1.85, S.Acc: 51.36%, E.Acc: 62.89%
# Epoch 0. Batch 3060/4290: AvgLoss: 1.85, S.Acc: 51.41%, E.Acc: 63.00%
# Epoch 0. Batch 3070/4290: AvgLoss: 1.84, S.Acc: 51.42%, E.Acc: 63.09%
# Epoch 0. Batch 3080/4290: AvgLoss: 1.84, S.Acc: 51.44%, E.Acc: 63.18%
# Epoch 0. Batch 3090/4290: AvgLoss: 1.84, S.Acc: 51.47%, E.Acc: 63.27%
# Epoch 0. Batch 3100/4290: AvgLoss: 1.84, S.Acc: 51.51%, E.Acc: 63.35%
# Epoch 0. Batch 3110/4290: AvgLoss: 1.84, S.Acc: 51.53%, E.Acc: 63.43%
# Epoch 0. Batch 3120/4290: AvgLoss: 1.83, S.Acc: 51.55%, E.Acc: 63.50%
# Epoch 0. Batch 3130/4290: AvgLoss: 1.83, S.Acc: 51.57%, E.Acc: 63.59%
# Epoch 0. Batch 3140/4290: AvgLoss: 1.83, S.Acc: 51.63%, E.Acc: 63.69%
# Epoch 0. Batch 3150/4290: AvgLoss: 1.83, S.Acc: 51.65%, E.Acc: 63.78%
# Epoch 0. Batch 3160/4290: AvgLoss: 1.82, S.Acc: 51.69%, E.Acc: 63.86%
# Epoch 0. Batch 3170/4290: AvgLoss: 1.82, S.Acc: 51.70%, E.Acc: 63.94%
# Epoch 0. Batch 3180/4290: AvgLoss: 1.82, S.Acc: 51.71%, E.Acc: 64.03%
# Epoch 0. Batch 3190/4290: AvgLoss: 1.82, S.Acc: 51.72%, E.Acc: 64.11%
# Epoch 0. Batch 3200/4290: AvgLoss: 1.81, S.Acc: 51.74%, E.Acc: 64.21%
# Epoch 0. Batch 3210/4290: AvgLoss: 1.81, S.Acc: 51.77%, E.Acc: 64.30%
# Epoch 0. Batch 3220/4290: AvgLoss: 1.81, S.Acc: 51.77%, E.Acc: 64.39%
# Epoch 0. Batch 3230/4290: AvgLoss: 1.81, S.Acc: 51.78%, E.Acc: 64.48%
# Epoch 0. Batch 3240/4290: AvgLoss: 1.80, S.Acc: 51.81%, E.Acc: 64.57%
# Epoch 0. Batch 3250/4290: AvgLoss: 1.80, S.Acc: 51.85%, E.Acc: 64.66%
# Epoch 0. Batch 3260/4290: AvgLoss: 1.80, S.Acc: 51.87%, E.Acc: 64.74%
# Epoch 0. Batch 3270/4290: AvgLoss: 1.80, S.Acc: 51.88%, E.Acc: 64.82%
# Epoch 0. Batch 3280/4290: AvgLoss: 1.80, S.Acc: 51.90%, E.Acc: 64.90%
# Epoch 0. Batch 3290/4290: AvgLoss: 1.79, S.Acc: 51.94%, E.Acc: 64.98%
# Epoch 0. Batch 3300/4290: AvgLoss: 1.79, S.Acc: 51.96%, E.Acc: 65.06%
# Epoch 0. Batch 3310/4290: AvgLoss: 1.79, S.Acc: 52.00%, E.Acc: 65.14%
# Epoch 0. Batch 3320/4290: AvgLoss: 1.79, S.Acc: 52.03%, E.Acc: 65.23%
# Epoch 0. Batch 3330/4290: AvgLoss: 1.78, S.Acc: 52.05%, E.Acc: 65.31%
# Epoch 0. Batch 3340/4290: AvgLoss: 1.78, S.Acc: 52.08%, E.Acc: 65.37%
# Epoch 0. Batch 3350/4290: AvgLoss: 1.78, S.Acc: 52.12%, E.Acc: 65.45%
# Epoch 0. Batch 3360/4290: AvgLoss: 1.78, S.Acc: 52.14%, E.Acc: 65.53%
# Epoch 0. Batch 3370/4290: AvgLoss: 1.78, S.Acc: 52.17%, E.Acc: 65.60%
# Epoch 0. Batch 3380/4290: AvgLoss: 1.77, S.Acc: 52.19%, E.Acc: 65.69%
# Epoch 0. Batch 3390/4290: AvgLoss: 1.77, S.Acc: 52.21%, E.Acc: 65.76%
# Epoch 0. Batch 3400/4290: AvgLoss: 1.77, S.Acc: 52.22%, E.Acc: 65.84%
# Epoch 0. Batch 3410/4290: AvgLoss: 1.77, S.Acc: 52.26%, E.Acc: 65.90%
# Epoch 0. Batch 3420/4290: AvgLoss: 1.77, S.Acc: 52.27%, E.Acc: 65.97%
# Epoch 0. Batch 3430/4290: AvgLoss: 1.76, S.Acc: 52.28%, E.Acc: 66.05%
# Epoch 0. Batch 3440/4290: AvgLoss: 1.76, S.Acc: 52.31%, E.Acc: 66.13%
# Epoch 0. Batch 3450/4290: AvgLoss: 1.76, S.Acc: 52.34%, E.Acc: 66.21%
# Epoch 0. Batch 3460/4290: AvgLoss: 1.76, S.Acc: 52.35%, E.Acc: 66.28%
# Epoch 0. Batch 3470/4290: AvgLoss: 1.75, S.Acc: 52.37%, E.Acc: 66.37%
# Epoch 0. Batch 3480/4290: AvgLoss: 1.75, S.Acc: 52.40%, E.Acc: 66.45%
# Epoch 0. Batch 3490/4290: AvgLoss: 1.75, S.Acc: 52.43%, E.Acc: 66.54%
# Epoch 0. Batch 3500/4290: AvgLoss: 1.75, S.Acc: 52.46%, E.Acc: 66.61%
# Epoch 0. Batch 3510/4290: AvgLoss: 1.75, S.Acc: 52.49%, E.Acc: 66.69%
# Epoch 0. Batch 3520/4290: AvgLoss: 1.74, S.Acc: 52.52%, E.Acc: 66.76%
# Epoch 0. Batch 3530/4290: AvgLoss: 1.74, S.Acc: 52.53%, E.Acc: 66.84%
# Epoch 0. Batch 3540/4290: AvgLoss: 1.74, S.Acc: 52.56%, E.Acc: 66.92%
# Epoch 0. Batch 3550/4290: AvgLoss: 1.74, S.Acc: 52.59%, E.Acc: 66.98%
# Epoch 0. Batch 3560/4290: AvgLoss: 1.74, S.Acc: 52.62%, E.Acc: 67.05%
# Epoch 0. Batch 3570/4290: AvgLoss: 1.73, S.Acc: 52.64%, E.Acc: 67.12%
# Epoch 0. Batch 3580/4290: AvgLoss: 1.73, S.Acc: 52.65%, E.Acc: 67.18%
# Epoch 0. Batch 3590/4290: AvgLoss: 1.73, S.Acc: 52.66%, E.Acc: 67.25%
# Epoch 0. Batch 3600/4290: AvgLoss: 1.73, S.Acc: 52.69%, E.Acc: 67.33%
# Epoch 0. Batch 3610/4290: AvgLoss: 1.73, S.Acc: 52.72%, E.Acc: 67.41%
# Epoch 0. Batch 3620/4290: AvgLoss: 1.72, S.Acc: 52.75%, E.Acc: 67.48%
# Epoch 0. Batch 3630/4290: AvgLoss: 1.72, S.Acc: 52.78%, E.Acc: 67.56%
# Epoch 0. Batch 3640/4290: AvgLoss: 1.72, S.Acc: 52.80%, E.Acc: 67.62%
# Epoch 0. Batch 3650/4290: AvgLoss: 1.72, S.Acc: 52.82%, E.Acc: 67.70%
# Epoch 0. Batch 3660/4290: AvgLoss: 1.72, S.Acc: 52.85%, E.Acc: 67.77%
# Epoch 0. Batch 3670/4290: AvgLoss: 1.71, S.Acc: 52.88%, E.Acc: 67.84%
# Epoch 0. Batch 3680/4290: AvgLoss: 1.71, S.Acc: 52.89%, E.Acc: 67.91%
# Epoch 0. Batch 3690/4290: AvgLoss: 1.71, S.Acc: 52.93%, E.Acc: 67.98%
# Epoch 0. Batch 3700/4290: AvgLoss: 1.71, S.Acc: 52.97%, E.Acc: 68.04%
# Epoch 0. Batch 3710/4290: AvgLoss: 1.71, S.Acc: 52.98%, E.Acc: 68.10%
# Epoch 0. Batch 3720/4290: AvgLoss: 1.70, S.Acc: 53.00%, E.Acc: 68.17%
# Epoch 0. Batch 3730/4290: AvgLoss: 1.70, S.Acc: 53.01%, E.Acc: 68.23%
# Epoch 0. Batch 3740/4290: AvgLoss: 1.70, S.Acc: 53.04%, E.Acc: 68.29%
# Epoch 0. Batch 3750/4290: AvgLoss: 1.70, S.Acc: 53.05%, E.Acc: 68.35%
# Epoch 0. Batch 3760/4290: AvgLoss: 1.70, S.Acc: 53.07%, E.Acc: 68.41%
# Epoch 0. Batch 3770/4290: AvgLoss: 1.70, S.Acc: 53.09%, E.Acc: 68.48%
# Epoch 0. Batch 3780/4290: AvgLoss: 1.69, S.Acc: 53.11%, E.Acc: 68.54%
# Epoch 0. Batch 3790/4290: AvgLoss: 1.69, S.Acc: 53.13%, E.Acc: 68.60%
# Epoch 0. Batch 3800/4290: AvgLoss: 1.69, S.Acc: 53.15%, E.Acc: 68.66%
# Epoch 0. Batch 3810/4290: AvgLoss: 1.69, S.Acc: 53.15%, E.Acc: 68.71%
# Epoch 0. Batch 3820/4290: AvgLoss: 1.69, S.Acc: 53.16%, E.Acc: 68.78%
# Epoch 0. Batch 3830/4290: AvgLoss: 1.69, S.Acc: 53.18%, E.Acc: 68.84%
# Epoch 0. Batch 3840/4290: AvgLoss: 1.68, S.Acc: 53.22%, E.Acc: 68.90%
# Epoch 0. Batch 3850/4290: AvgLoss: 1.68, S.Acc: 53.24%, E.Acc: 68.96%
# Epoch 0. Batch 3860/4290: AvgLoss: 1.68, S.Acc: 53.29%, E.Acc: 69.02%
# Epoch 0. Batch 3870/4290: AvgLoss: 1.68, S.Acc: 53.30%, E.Acc: 69.08%
# Epoch 0. Batch 3880/4290: AvgLoss: 1.68, S.Acc: 53.31%, E.Acc: 69.15%
# Epoch 0. Batch 3890/4290: AvgLoss: 1.68, S.Acc: 53.35%, E.Acc: 69.20%
# Epoch 0. Batch 3900/4290: AvgLoss: 1.67, S.Acc: 53.35%, E.Acc: 69.26%
# Epoch 0. Batch 3910/4290: AvgLoss: 1.67, S.Acc: 53.36%, E.Acc: 69.32%
# Epoch 0. Batch 3920/4290: AvgLoss: 1.67, S.Acc: 53.37%, E.Acc: 69.37%
# Epoch 0. Batch 3930/4290: AvgLoss: 1.67, S.Acc: 53.39%, E.Acc: 69.42%
# Epoch 0. Batch 3940/4290: AvgLoss: 1.67, S.Acc: 53.43%, E.Acc: 69.47%
# Epoch 0. Batch 3950/4290: AvgLoss: 1.67, S.Acc: 53.45%, E.Acc: 69.53%
# Epoch 0. Batch 3960/4290: AvgLoss: 1.66, S.Acc: 53.47%, E.Acc: 69.58%
# Epoch 0. Batch 3970/4290: AvgLoss: 1.66, S.Acc: 53.48%, E.Acc: 69.63%
# Epoch 0. Batch 3980/4290: AvgLoss: 1.66, S.Acc: 53.49%, E.Acc: 69.69%
# Epoch 0. Batch 3990/4290: AvgLoss: 1.66, S.Acc: 53.50%, E.Acc: 69.73%
# Epoch 0. Batch 4000/4290: AvgLoss: 1.66, S.Acc: 53.53%, E.Acc: 69.79%
# Epoch 0. Batch 4010/4290: AvgLoss: 1.66, S.Acc: 53.54%, E.Acc: 69.84%
# Epoch 0. Batch 4020/4290: AvgLoss: 1.65, S.Acc: 53.57%, E.Acc: 69.90%
# Epoch 0. Batch 4030/4290: AvgLoss: 1.65, S.Acc: 53.60%, E.Acc: 69.95%
# Epoch 0. Batch 4040/4290: AvgLoss: 1.65, S.Acc: 53.61%, E.Acc: 70.00%
# Epoch 0. Batch 4050/4290: AvgLoss: 1.65, S.Acc: 53.64%, E.Acc: 70.06%
# Epoch 0. Batch 4060/4290: AvgLoss: 1.65, S.Acc: 53.66%, E.Acc: 70.11%
# Epoch 0. Batch 4070/4290: AvgLoss: 1.65, S.Acc: 53.68%, E.Acc: 70.17%
# Epoch 0. Batch 4080/4290: AvgLoss: 1.65, S.Acc: 53.69%, E.Acc: 70.21%
# Epoch 0. Batch 4090/4290: AvgLoss: 1.64, S.Acc: 53.71%, E.Acc: 70.27%
# Epoch 0. Batch 4100/4290: AvgLoss: 1.64, S.Acc: 53.73%, E.Acc: 70.33%
# Epoch 0. Batch 4110/4290: AvgLoss: 1.64, S.Acc: 53.76%, E.Acc: 70.37%
# Epoch 0. Batch 4120/4290: AvgLoss: 1.64, S.Acc: 53.78%, E.Acc: 70.43%
# Epoch 0. Batch 4130/4290: AvgLoss: 1.64, S.Acc: 53.81%, E.Acc: 70.49%
# Epoch 0. Batch 4140/4290: AvgLoss: 1.64, S.Acc: 53.84%, E.Acc: 70.54%
# Epoch 0. Batch 4150/4290: AvgLoss: 1.63, S.Acc: 53.87%, E.Acc: 70.60%
# Epoch 0. Batch 4160/4290: AvgLoss: 1.63, S.Acc: 53.89%, E.Acc: 70.64%
# Epoch 0. Batch 4170/4290: AvgLoss: 1.63, S.Acc: 53.88%, E.Acc: 70.69%
# Epoch 0. Batch 4180/4290: AvgLoss: 1.63, S.Acc: 53.90%, E.Acc: 70.74%
# Epoch 0. Batch 4190/4290: AvgLoss: 1.63, S.Acc: 53.93%, E.Acc: 70.81%
# Epoch 0. Batch 4200/4290: AvgLoss: 1.63, S.Acc: 53.95%, E.Acc: 70.87%
# Epoch 0. Batch 4210/4290: AvgLoss: 1.63, S.Acc: 53.97%, E.Acc: 70.92%
# Epoch 0. Batch 4220/4290: AvgLoss: 1.62, S.Acc: 54.00%, E.Acc: 70.97%
# Epoch 0. Batch 4230/4290: AvgLoss: 1.62, S.Acc: 54.00%, E.Acc: 71.02%
# Epoch 0. Batch 4240/4290: AvgLoss: 1.62, S.Acc: 54.01%, E.Acc: 71.07%
# Epoch 0. Batch 4250/4290: AvgLoss: 1.62, S.Acc: 54.05%, E.Acc: 71.12%
# Epoch 0. Batch 4260/4290: AvgLoss: 1.62, S.Acc: 54.06%, E.Acc: 71.17%
# Epoch 0. Batch 4270/4290: AvgLoss: 1.62, S.Acc: 54.06%, E.Acc: 71.22%
# Epoch 0. Batch 4280/4290: AvgLoss: 1.62, S.Acc: 54.09%, E.Acc: 71.27%
4290: AvgLoss: 0.88, S.Acc: 67.14%, E.Acc: 93.77%
# Epoch 1. Batch 1770/4290: AvgLoss: 0.88, S.Acc: 67.15%, E.Acc: 93.79%
# Epoch 1. Batch 1780/4290: AvgLoss: 0.88, S.Acc: 67.15%, E.Acc: 93.78%
# Epoch 1. Batch 1790/4290: AvgLoss: 0.88, S.Acc: 67.15%, E.Acc: 93.79%
# Epoch 1. Batch 1800/4290: AvgLoss: 0.88, S.Acc: 67.14%, E.Acc: 93.79%
# Epoch 1. Batch 1810/4290: AvgLoss: 0.88, S.Acc: 67.16%, E.Acc: 93.81%
# Epoch 1. Batch 1820/4290: AvgLoss: 0.88, S.Acc: 67.15%, E.Acc: 93.80%
# Epoch 1. Batch 1830/4290: AvgLoss: 0.88, S.Acc: 67.18%, E.Acc: 93.80%
# Epoch 1. Batch 1840/4290: AvgLoss: 0.88, S.Acc: 67.17%, E.Acc: 93.82%
# Epoch 1. Batch 1850/4290: AvgLoss: 0.88, S.Acc: 67.15%, E.Acc: 93.80%
# Epoch 1. Batch 1860/4290: AvgLoss: 0.88, S.Acc: 67.14%, E.Acc: 93.81%
# Epoch 1. Batch 1870/4290: AvgLoss: 0.88, S.Acc: 67.13%, E.Acc: 93.82%
# Epoch 1. Batch 1880/4290: AvgLoss: 0.88, S.Acc: 67.14%, E.Acc: 93.81%
# Epoch 1. Batch 1890/4290: AvgLoss: 0.88, S.Acc: 67.14%, E.Acc: 93.82%
# Epoch 1. Batch 1900/4290: AvgLoss: 0.88, S.Acc: 67.14%, E.Acc: 93.81%
# Epoch 1. Batch 1910/4290: AvgLoss: 0.88, S.Acc: 67.19%, E.Acc: 93.81%
# Epoch 1. Batch 1920/4290: AvgLoss: 0.88, S.Acc: 67.23%, E.Acc: 93.78%
# Epoch 1. Batch 1930/4290: AvgLoss: 0.88, S.Acc: 67.24%, E.Acc: 93.77%
# Epoch 1. Batch 1940/4290: AvgLoss: 0.88, S.Acc: 67.23%, E.Acc: 93.77%
# Epoch 1. Batch 1950/4290: AvgLoss: 0.88, S.Acc: 67.23%, E.Acc: 93.75%
# Epoch 1. Batch 1960/4290: AvgLoss: 0.88, S.Acc: 67.21%, E.Acc: 93.76%
# Epoch 1. Batch 1970/4290: AvgLoss: 0.88, S.Acc: 67.22%, E.Acc: 93.76%
# Epoch 1. Batch 1980/4290: AvgLoss: 0.88, S.Acc: 67.21%, E.Acc: 93.76%
# Epoch 1. Batch 1990/4290: AvgLoss: 0.88, S.Acc: 67.22%, E.Acc: 93.76%
# Epoch 1. Batch 2000/4290: AvgLoss: 0.88, S.Acc: 67.22%, E.Acc: 93.77%
# Epoch 1. Batch 2010/4290: AvgLoss: 0.88, S.Acc: 67.23%, E.Acc: 93.79%
# Epoch 1. Batch 2020/4290: AvgLoss: 0.88, S.Acc: 67.25%, E.Acc: 93.80%
# Epoch 1. Batch 2030/4290: AvgLoss: 0.88, S.Acc: 67.25%, E.Acc: 93.80%
# Epoch 1. Batch 2040/4290: AvgLoss: 0.88, S.Acc: 67.25%, E.Acc: 93.80%
# Epoch 1. Batch 2050/4290: AvgLoss: 0.88, S.Acc: 67.23%, E.Acc: 93.80%
# Epoch 1. Batch 2060/4290: AvgLoss: 0.88, S.Acc: 67.22%, E.Acc: 93.77%
# Epoch 1. Batch 2070/4290: AvgLoss: 0.88, S.Acc: 67.21%, E.Acc: 93.78%
# Epoch 1. Batch 2080/4290: AvgLoss: 0.88, S.Acc: 67.19%, E.Acc: 93.77%
# Epoch 1. Batch 2090/4290: AvgLoss: 0.88, S.Acc: 67.19%, E.Acc: 93.79%
# Epoch 1. Batch 2100/4290: AvgLoss: 0.88, S.Acc: 67.19%, E.Acc: 93.79%
# Epoch 1. Batch 2110/4290: AvgLoss: 0.88, S.Acc: 67.21%, E.Acc: 93.80%
# Epoch 1. Batch 2120/4290: AvgLoss: 0.88, S.Acc: 67.21%, E.Acc: 93.79%
# Epoch 1. Batch 2130/4290: AvgLoss: 0.88, S.Acc: 67.18%, E.Acc: 93.79%
# Epoch 1. Batch 2140/4290: AvgLoss: 0.88, S.Acc: 67.16%, E.Acc: 93.79%
# Epoch 1. Batch 2150/4290: AvgLoss: 0.88, S.Acc: 67.19%, E.Acc: 93.78%
# Epoch 1. Batch 2160/4290: AvgLoss: 0.88, S.Acc: 67.17%, E.Acc: 93.78%
# Epoch 1. Batch 2170/4290: AvgLoss: 0.88, S.Acc: 67.20%, E.Acc: 93.79%
# Epoch 1. Batch 2180/4290: AvgLoss: 0.88, S.Acc: 67.19%, E.Acc: 93.78%
# Epoch 1. Batch 2190/4290: AvgLoss: 0.88, S.Acc: 67.20%, E.Acc: 93.79%
# Epoch 1. Batch 2200/4290: AvgLoss: 0.88, S.Acc: 67.20%, E.Acc: 93.80%
# Epoch 1. Batch 2210/4290: AvgLoss: 0.88, S.Acc: 67.19%, E.Acc: 93.78%
# Epoch 1. Batch 2220/4290: AvgLoss: 0.88, S.Acc: 67.20%, E.Acc: 93.78%
# Epoch 1. Batch 2230/4290: AvgLoss: 0.88, S.Acc: 67.19%, E.Acc: 93.77%
# Epoch 1. Batch 2240/4290: AvgLoss: 0.88, S.Acc: 67.17%, E.Acc: 93.75%
# Epoch 1. Batch 2250/4290: AvgLoss: 0.88, S.Acc: 67.17%, E.Acc: 93.75%
# Epoch 1. Batch 2260/4290: AvgLoss: 0.88, S.Acc: 67.16%, E.Acc: 93.74%
# Epoch 1. Batch 2270/4290: AvgLoss: 0.88, S.Acc: 67.15%, E.Acc: 93.74%
# Epoch 1. Batch 2280/4290: AvgLoss: 0.88, S.Acc: 67.14%, E.Acc: 93.75%
# Epoch 1. Batch 2290/4290: AvgLoss: 0.88, S.Acc: 67.15%, E.Acc: 93.75%
# Epoch 1. Batch 2300/4290: AvgLoss: 0.88, S.Acc: 67.16%, E.Acc: 93.74%
# Epoch 1. Batch 2310/4290: AvgLoss: 0.88, S.Acc: 67.18%, E.Acc: 93.74%
# Epoch 1. Batch 2320/4290: AvgLoss: 0.88, S.Acc: 67.19%, E.Acc: 93.76%
# Epoch 1. Batch 2330/4290: AvgLoss: 0.88, S.Acc: 67.19%, E.Acc: 93.76%
# Epoch 1. Batch 2340/4290: AvgLoss: 0.88, S.Acc: 67.19%, E.Acc: 93.76%
# Epoch 1. Batch 2350/4290: AvgLoss: 0.88, S.Acc: 67.16%, E.Acc: 93.76%
# Epoch 1. Batch 2360/4290: AvgLoss: 0.88, S.Acc: 67.16%, E.Acc: 93.76%
# Epoch 1. Batch 2370/4290: AvgLoss: 0.88, S.Acc: 67.18%, E.Acc: 93.77%
# Epoch 1. Batch 2380/4290: AvgLoss: 0.88, S.Acc: 67.16%, E.Acc: 93.76%
# Epoch 1. Batch 2390/4290: AvgLoss: 0.88, S.Acc: 67.16%, E.Acc: 93.77%
# Epoch 1. Batch 2400/4290: AvgLoss: 0.88, S.Acc: 67.18%, E.Acc: 93.77%
# Epoch 1. Batch 2410/4290: AvgLoss: 0.88, S.Acc: 67.19%, E.Acc: 93.78%
# Epoch 1. Batch 2420/4290: AvgLoss: 0.88, S.Acc: 67.16%, E.Acc: 93.78%
# Epoch 1. Batch 2430/4290: AvgLoss: 0.88, S.Acc: 67.17%, E.Acc: 93.79%
# Epoch 1. Batch 2440/4290: AvgLoss: 0.88, S.Acc: 67.17%, E.Acc: 93.80%
# Epoch 1. Batch 2450/4290: AvgLoss: 0.88, S.Acc: 67.17%, E.Acc: 93.81%
# Epoch 1. Batch 2460/4290: AvgLoss: 0.88, S.Acc: 67.14%, E.Acc: 93.81%
# Epoch 1. Batch 2470/4290: AvgLoss: 0.88, S.Acc: 67.14%, E.Acc: 93.81%
# Epoch 1. Batch 2480/4290: AvgLoss: 0.88, S.Acc: 67.12%, E.Acc: 93.82%
# Epoch 1. Batch 2490/4290: AvgLoss: 0.88, S.Acc: 67.11%, E.Acc: 93.82%
# Epoch 1. Batch 2500/4290: AvgLoss: 0.88, S.Acc: 67.12%, E.Acc: 93.81%
# Epoch 1. Batch 2510/4290: AvgLoss: 0.88, S.Acc: 67.10%, E.Acc: 93.81%
# Epoch 1. Batch 2520/4290: AvgLoss: 0.88, S.Acc: 67.09%, E.Acc: 93.82%
# Epoch 1. Batch 2530/4290: AvgLoss: 0.88, S.Acc: 67.10%, E.Acc: 93.81%
# Epoch 1. Batch 2540/4290: AvgLoss: 0.88, S.Acc: 67.10%, E.Acc: 93.81%
# Epoch 1. Batch 2550/4290: AvgLoss: 0.88, S.Acc: 67.07%, E.Acc: 93.81%
# Epoch 1. Batch 2560/4290: AvgLoss: 0.88, S.Acc: 67.08%, E.Acc: 93.81%
# Epoch 1. Batch 2570/4290: AvgLoss: 0.88, S.Acc: 67.11%, E.Acc: 93.80%
# Epoch 1. Batch 2580/4290: AvgLoss: 0.88, S.Acc: 67.07%, E.Acc: 93.79%
# Epoch 1. Batch 2590/4290: AvgLoss: 0.88, S.Acc: 67.08%, E.Acc: 93.81%
# Epoch 1. Batch 2600/4290: AvgLoss: 0.88, S.Acc: 67.10%, E.Acc: 93.81%
# Epoch 1. Batch 2610/4290: AvgLoss: 0.88, S.Acc: 67.10%, E.Acc: 93.81%
# Epoch 1. Batch 2620/4290: AvgLoss: 0.88, S.Acc: 67.12%, E.Acc: 93.80%
# Epoch 1. Batch 2630/4290: AvgLoss: 0.88, S.Acc: 67.13%, E.Acc: 93.79%
# Epoch 1. Batch 2640/4290: AvgLoss: 0.88, S.Acc: 67.12%, E.Acc: 93.78%
# Epoch 1. Batch 2650/4290: AvgLoss: 0.88, S.Acc: 67.13%, E.Acc: 93.79%
# Epoch 1. Batch 2660/4290: AvgLoss: 0.88, S.Acc: 67.10%, E.Acc: 93.78%
# Epoch 1. Batch 2960/4290: AvgLoss: 0.88, S.Acc: 67.04%, E.Acc: 93.80%
# Epoch 1. Batch 2970/4290: AvgLoss: 0.88, S.Acc: 67.04%, E.Acc: 93.80%
# Epoch 1. Batch 2980/4290: AvgLoss: 0.88, S.Acc: 67.06%, E.Acc: 93.80%
# Epoch 1. Batch 2990/4290: AvgLoss: 0.88, S.Acc: 67.06%, E.Acc: 93.81%
# Epoch 1. Batch 3000/4290: AvgLoss: 0.88, S.Acc: 67.07%, E.Acc: 93.81%
# Epoch 1. Batch 3010/4290: AvgLoss: 0.88, S.Acc: 67.09%, E.Acc: 93.81%
# Epoch 1. Batch 3020/4290: AvgLoss: 0.88, S.Acc: 67.08%, E.Acc: 93.81%
# Epoch 1. Batch 3030/4290: AvgLoss: 0.88, S.Acc: 67.08%, E.Acc: 93.82%
# Epoch 1. Batch 3040/4290: AvgLoss: 0.88, S.Acc: 67.07%, E.Acc: 93.83%
# Epoch 1. Batch 3050/4290: AvgLoss: 0.88, S.Acc: 67.05%, E.Acc: 93.83%
# Epoch 1. Batch 3060/4290: AvgLoss: 0.88, S.Acc: 67.06%, E.Acc: 93.83%
# Epoch 1. Batch 3070/4290: AvgLoss: 0.88, S.Acc: 67.07%, E.Acc: 93.84%
# Epoch 1. Batch 3080/4290: AvgLoss: 0.88, S.Acc: 67.04%, E.Acc: 93.84%
# Epoch 1. Batch 3090/4290: AvgLoss: 0.88, S.Acc: 67.04%, E.Acc: 93.84%
# Epoch 1. Batch 3100/4290: AvgLoss: 0.88, S.Acc: 67.06%, E.Acc: 93.84%
# Epoch 1. Batch 3110/4290: AvgLoss: 0.88, S.Acc: 67.07%, E.Acc: 93.84%
# Epoch 1. Batch 3120/4290: AvgLoss: 0.88, S.Acc: 67.06%, E.Acc: 93.84%
# Epoch 1. Batch 3130/4290: AvgLoss: 0.88, S.Acc: 67.07%, E.Acc: 93.84%
# Epoch 1. Batch 3140/4290: AvgLoss: 0.88, S.Acc: 67.03%, E.Acc: 93.85%
# Epoch 1. Batch 3150/4290: AvgLoss: 0.88, S.Acc: 67.01%, E.Acc: 93.86%
# Epoch 1. Batch 3160/4290: AvgLoss: 0.88, S.Acc: 67.02%, E.Acc: 93.86%
# Epoch 1. Batch 3170/4290: AvgLoss: 0.88, S.Acc: 67.00%, E.Acc: 93.86%
# Epoch 1. Batch 3180/4290: AvgLoss: 0.88, S.Acc: 67.01%, E.Acc: 93.85%
# Epoch 1. Batch 3190/4290: AvgLoss: 0.88, S.Acc: 67.01%, E.Acc: 93.84%
# Epoch 1. Batch 3200/4290: AvgLoss: 0.88, S.Acc: 67.00%, E.Acc: 93.84%
# Epoch 1. Batch 3210/4290: AvgLoss: 0.88, S.Acc: 66.98%, E.Acc: 93.84%
# Epoch 1. Batch 3220/4290: AvgLoss: 0.88, S.Acc: 66.98%, E.Acc: 93.84%
# Epoch 1. Batch 3230/4290: AvgLoss: 0.88, S.Acc: 66.97%, E.Acc: 93.84%
# Epoch 1. Batch 3240/4290: AvgLoss: 0.88, S.Acc: 66.97%, E.Acc: 93.83%
# Epoch 1. Batch 3250/4290: AvgLoss: 0.88, S.Acc: 66.96%, E.Acc: 93.83%
# Epoch 1. Batch 3260/4290: AvgLoss: 0.88, S.Acc: 66.96%, E.Acc: 93.83%
# Epoch 1. Batch 3270/4290: AvgLoss: 0.88, S.Acc: 66.99%, E.Acc: 93.82%
# Epoch 1. Batch 3280/4290: AvgLoss: 0.88, S.Acc: 67.00%, E.Acc: 93.82%
# Epoch 1. Batch 3290/4290: AvgLoss: 0.88, S.Acc: 67.00%, E.Acc: 93.83%
# Epoch 1. Batch 3300/4290: AvgLoss: 0.88, S.Acc: 66.99%, E.Acc: 93.83%
# Epoch 1. Batch 3310/4290: AvgLoss: 0.88, S.Acc: 66.99%, E.Acc: 93.84%
# Epoch 1. Batch 3320/4290: AvgLoss: 0.88, S.Acc: 67.01%, E.Acc: 93.85%
# Epoch 1. Batch 3330/4290: AvgLoss: 0.88, S.Acc: 67.01%, E.Acc: 93.84%
# Epoch 1. Batch 3340/4290: AvgLoss: 0.88, S.Acc: 67.03%, E.Acc: 93.85%
# Epoch 1. Batch 3350/4290: AvgLoss: 0.88, S.Acc: 67.04%, E.Acc: 93.85%
# Epoch 1. Batch 3360/4290: AvgLoss: 0.88, S.Acc: 67.03%, E.Acc: 93.84%
# Epoch 1. Batch 3370/4290: AvgLoss: 0.88, S.Acc: 67.02%, E.Acc: 93.85%
# Epoch 1. Batch 3380/4290: AvgLoss: 0.88, S.Acc: 67.02%, E.Acc: 93.85%
# Epoch 1. Batch 3390/4290: AvgLoss: 0.88, S.Acc: 67.04%, E.Acc: 93.86%
# Epoch 1. Batch 3400/4290: AvgLoss: 0.88, S.Acc: 67.03%, E.Acc: 93.86%
# Epoch 1. Batch 3410/4290: AvgLoss: 0.88, S.Acc: 67.05%, E.Acc: 93.87%
# Epoch 1. Batch 3420/4290: AvgLoss: 0.88, S.Acc: 67.02%, E.Acc: 93.87%
# Epoch 1. Batch 3430/4290: AvgLoss: 0.88, S.Acc: 67.02%, E.Acc: 93.87%
# Epoch 1. Batch 3440/4290: AvgLoss: 0.88, S.Acc: 67.02%, E.Acc: 93.87%
# Epoch 1. Batch 3450/4290: AvgLoss: 0.88, S.Acc: 67.02%, E.Acc: 93.87%
# Epoch 1. Batch 3460/4290: AvgLoss: 0.88, S.Acc: 67.01%, E.Acc: 93.87%
# Epoch 1. Batch 3470/4290: AvgLoss: 0.88, S.Acc: 67.01%, E.Acc: 93.87%
# Epoch 1. Batch 3480/4290: AvgLoss: 0.88, S.Acc: 67.00%, E.Acc: 93.86%
# Epoch 1. Batch 3490/4290: AvgLoss: 0.88, S.Acc: 66.98%, E.Acc: 93.87%
# Epoch 1. Batch 3500/4290: AvgLoss: 0.88, S.Acc: 66.96%, E.Acc: 93.87%
# Epoch 1. Batch 3510/4290: AvgLoss: 0.88, S.Acc: 66.95%, E.Acc: 93.87%
# Epoch 1. Batch 3520/4290: AvgLoss: 0.88, S.Acc: 66.94%, E.Acc: 93.87%
# Epoch 1. Batch 3530/4290: AvgLoss: 0.88, S.Acc: 66.95%, E.Acc: 93.87%
# Epoch 1. Batch 3540/4290: AvgLoss: 0.88, S.Acc: 66.95%, E.Acc: 93.88%
# Epoch 1. Batch 3550/4290: AvgLoss: 0.88, S.Acc: 66.95%, E.Acc: 93.88%
# Epoch 1. Batch 3560/4290: AvgLoss: 0.88, S.Acc: 66.94%, E.Acc: 93.88%
# Epoch 1. Batch 3570/4290: AvgLoss: 0.88, S.Acc: 66.91%, E.Acc: 93.88%
# Epoch 1. Batch 3580/4290: AvgLoss: 0.88, S.Acc: 66.92%, E.Acc: 93.89%
# Epoch 1. Batch 3590/4290: AvgLoss: 0.88, S.Acc: 66.92%, E.Acc: 93.89%
# Epoch 1. Batch 3600/4290: AvgLoss: 0.88, S.Acc: 66.91%, E.Acc: 93.88%
# Epoch 1. Batch 3610/4290: AvgLoss: 0.88, S.Acc: 66.88%, E.Acc: 93.88%
# Epoch 1. Batch 3620/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.87%
# Epoch 1. Batch 3630/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.87%
# Epoch 1. Batch 3640/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.88%
# Epoch 1. Batch 3650/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.88%
# Epoch 1. Batch 3660/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.88%
# Epoch 1. Batch 3670/4290: AvgLoss: 0.88, S.Acc: 66.88%, E.Acc: 93.88%
# Epoch 1. Batch 3680/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.88%
# Epoch 1. Batch 3690/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.88%
# Epoch 1. Batch 3700/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.88%
# Epoch 1. Batch 3710/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.88%
# Epoch 1. Batch 3720/4290: AvgLoss: 0.88, S.Acc: 66.90%, E.Acc: 93.88%
# Epoch 1. Batch 3730/4290: AvgLoss: 0.88, S.Acc: 66.90%, E.Acc: 93.89%
# Epoch 1. Batch 3740/4290: AvgLoss: 0.88, S.Acc: 66.90%, E.Acc: 93.89%
# Epoch 1. Batch 3750/4290: AvgLoss: 0.88, S.Acc: 66.90%, E.Acc: 93.89%
# Epoch 1. Batch 3760/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.89%
# Epoch 1. Batch 3770/4290: AvgLoss: 0.88, S.Acc: 66.90%, E.Acc: 93.89%
# Epoch 1. Batch 3780/4290: AvgLoss: 0.88, S.Acc: 66.90%, E.Acc: 93.90%
# Epoch 1. Batch 3790/4290: AvgLoss: 0.88, S.Acc: 66.90%, E.Acc: 93.89%
# Epoch 1. Batch 3800/4290: AvgLoss: 0.88, S.Acc: 66.90%, E.Acc: 93.90%
# Epoch 1. Batch 3810/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.90%
# Epoch 1. Batch 3820/4290: AvgLoss: 0.88, S.Acc: 66.88%, E.Acc: 93.90%
# Epoch 1. Batch 3830/4290: AvgLoss: 0.88, S.Acc: 66.88%, E.Acc: 93.90%
# Epoch 1. Batch 3840/4290: AvgLoss: 0.88, S.Acc: 66.88%, E.Acc: 93.90%
# Epoch 1. Batch 3850/4290: AvgLoss: 0.88, S.Acc: 66.87%, E.Acc: 93.90%
# Epoch 1. Batch 3860/4290: AvgLoss: 0.88, S.Acc: 66.88%, E.Acc: 93.91%
# Epoch 1. Batch 3870/4290: AvgLoss: 0.88, S.Acc: 66.87%, E.Acc: 93.90%
# Epoch 1. Batch 3880/4290: AvgLoss: 0.88, S.Acc: 66.87%, E.Acc: 93.90%
# Epoch 1. Batch 3890/4290: AvgLoss: 0.88, S.Acc: 66.86%, E.Acc: 93.91%
# Epoch 1. Batch 3900/4290: AvgLoss: 0.88, S.Acc: 66.86%, E.Acc: 93.91%
# Epoch 1. Batch 3910/4290: AvgLoss: 0.88, S.Acc: 66.87%, E.Acc: 93.91%
# Epoch 1. Batch 3920/4290: AvgLoss: 0.88, S.Acc: 66.87%, E.Acc: 93.90%
# Epoch 1. Batch 3930/4290: AvgLoss: 0.88, S.Acc: 66.87%, E.Acc: 93.90%
# Epoch 1. Batch 3940/4290: AvgLoss: 0.88, S.Acc: 66.88%, E.Acc: 93.90%
# Epoch 1. Batch 3950/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.91%
# Epoch 1. Batch 3960/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.91%
# Epoch 1. Batch 3970/4290: AvgLoss: 0.88, S.Acc: 66.90%, E.Acc: 93.90%
# Epoch 1. Batch 3980/4290: AvgLoss: 0.88, S.Acc: 66.90%, E.Acc: 93.90%
# Epoch 1. Batch 3990/4290: AvgLoss: 0.88, S.Acc: 66.88%, E.Acc: 93.89%
# Epoch 1. Batch 4000/4290: AvgLoss: 0.88, S.Acc: 66.87%, E.Acc: 93.89%
# Epoch 1. Batch 4010/4290: AvgLoss: 0.88, S.Acc: 66.87%, E.Acc: 93.88%
# Epoch 1. Batch 4020/4290: AvgLoss: 0.88, S.Acc: 66.88%, E.Acc: 93.89%
# Epoch 1. Batch 4030/4290: AvgLoss: 0.88, S.Acc: 66.89%, E.Acc: 93.89%
# Epoch 1. Batch 4040/4290: AvgLoss: 0.88, S.Acc: 66.90%, E.Acc: 93.90%
# Epoch 1. Batch 4050/4290: AvgLoss: 0.88, S.Acc: 66.90%, E.Acc: 93.90%
# Epoch 1. Batch 4060/4290: AvgLoss: 0.88, S.Acc: 66.91%, E.Acc: 93.90%
# Epoch 1. Batch 4070/4290: AvgLoss: 0.88, S.Acc: 66.91%, E.Acc: 93.91%
# Epoch 1. Batch 4080/4290: AvgLoss: 0.88, S.Acc: 66.92%, E.Acc: 93.91%
# Epoch 1. Batch 4090/4290: AvgLoss: 0.88, S.Acc: 66.92%, E.Acc: 93.91%
# Epoch 1. Batch 4100/4290: AvgLoss: 0.88, S.Acc: 66.91%, E.Acc: 93.91%
# Epoch 1. Batch 4110/4290: AvgLoss: 0.88, S.Acc: 66.91%, E.Acc: 93.91%
# Epoch 1. Batch 4120/4290: AvgLoss: 0.88, S.Acc: 66.92%, E.Acc: 93.91%
# Epoch 1. Batch 4130/4290: AvgLoss: 0.88, S.Acc: 66.92%, E.Acc: 93.91%
# Epoch 1. Batch 4140/4290: AvgLoss: 0.88, S.Acc: 66.93%, E.Acc: 93.92%
# Epoch 1. Batch 4150/4290: AvgLoss: 0.88, S.Acc: 66.94%, E.Acc: 93.91%
# Epoch 1. Batch 4160/4290: AvgLoss: 0.88, S.Acc: 66.93%, E.Acc: 93.92%
# Epoch 1. Batch 4170/4290: AvgLoss: 0.88, S.Acc: 66.93%, E.Acc: 93.92%
# Epoch 1. Batch 4180/4290: AvgLoss: 0.88, S.Acc: 66.94%, E.Acc: 93.91%
# Epoch 1. Batch 4190/4290: AvgLoss: 0.88, S.Acc: 66.94%, E.Acc: 93.91%
# Epoch 1. Batch 4200/4290: AvgLoss: 0.88, S.Acc: 66.93%, E.Acc: 93.91%
# Epoch 1. Batch 4210/4290: AvgLoss: 0.88, S.Acc: 66.93%, E.Acc: 93.91%
# Epoch 1. Batch 4220/4290: AvgLoss: 0.88, S.Acc: 66.94%, E.Acc: 93.91%
# Epoch 1. Batch 4230/4290: AvgLoss: 0.88, S.Acc: 66.94%, E.Acc: 93.91%
# Epoch 1. Batch 4240/4290: AvgLoss: 0.88, S.Acc: 66.93%, E.Acc: 93.91%
# Epoch 1. Batch 4250/4290: AvgLoss: 0.88, S.Acc: 66.93%, E.Acc: 93.92%
# Epoch 1. Batch 4260/4290: AvgLoss: 0.88, S.Acc: 66.92%, E.Acc: 93.92%
# Epoch 1. Batch 4270/4290: AvgLoss: 0.88, S.Acc: 66.91%, E.Acc: 93.92%
# Epoch 1. Batch 4280/4290: AvgLoss: 0.88, S.Acc: 66.92%, E.Acc: 93.92%
# Train Loss: 0.8751, Train Sentiment Accuracy: 66.93%, Train Emotion Accuracy: 93.92%
# Validation Sentiment Accuracy: 66.13%, Validation Emotion Accuracy: 94.54%

# %% [markdown]
# # Model evaluation

# %%
test_acc_sent, test_acc_emot = eval_model(model, test_loader, device)

print(f"Test Sentiment Accuracy: {test_acc_sent:.2f}%")
print(f"Test Emotion Accuracy: {test_acc_emot:.2f}%")
# Out:
# Test Sentiment Accuracy: 66.88%
# Test Emotion Accuracy: 94.56%

# %% [markdown]
# # Summary
#
# | Epoch        | Train Accuracy Sentiment | Validation Accuracy Sentiment | Train Accuracy Emotion | Validation Accuracy Emotion |
# |--------------|--------------------------|-------------------------------|------------------------|-----------------------------|
# | **Epoch 1**  | 54.11%                   | 64.53%                        | 71.31%                 | 93.57%                      |
# | **Epoch 2**  | 66.93%                   | 66.13%                        | 93.92%                 | 94.54%                      |
#
# ### Observation
# * The training accuracy for both sentiment and emotion classification increases.

# %% [markdown]
# # Model serialization

# %%
torch.save(model.state_dict(), './LSTM_multitask_model/lstm_multitask_model.pth')
