# %% [markdown]
# # Model training: LSTM (multitasking)
#
# ---
#
# ## Table of Contents
#
# 1. [Imports](#imports)
# 2. [Data loading and splitting](#data-loading-and-splitting)
# 3. [Setting training parameters](#setting-training-parameters)
# 4. [Model training](#model-training)
# 5. [Model evaluation](#model-evaluation)
# 6. [Summary](#summary)
# 7. [Model serialization](#model-serialization)

# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# # Data loading and splitting

# %%
base_dir = os.path.abspath(os.path.join(os.path.dirname(os.getcwd()), '..'))

# %%
train_file_sentiment = os.path.join(base_dir, 'train_sentiment.csv')
val_file_sentiment = os.path.join(base_dir, 'val_sentiment.csv')
test_file_sentiment = os.path.join(base_dir, 'test_sentiment.csv')

if not all([os.path.exists(train_file_sentiment), os.path.exists(val_file_sentiment), os.path.exists(test_file_sentiment)]):
    sentiment_df = pd.read_parquet('../../data/sentiment_without_outliers/sentiment_without_outliers.parquet')
    sentiment_df = sentiment_df.drop(columns=['text_length'])
    
    train_data_sentiment, temp_data = train_test_split(sentiment_df, test_size=0.3, stratify=sentiment_df['label'], random_state=42)
    val_data_sentiment, test_data_sentiment = train_test_split(temp_data, test_size=0.5, stratify=temp_data['label'], random_state=42)

    train_data_sentiment.to_csv(train_file_sentiment, index=False)
    val_data_sentiment.to_csv(val_file_sentiment, index=False)
    test_data_sentiment.to_csv(test_file_sentiment, index=False)
else:
    train_data_sentiment = pd.read_csv(train_file_sentiment)
    val_data_sentiment = pd.read_csv(val_file_sentiment)
    test_data_sentiment = pd.read_csv(test_file_sentiment)

# %%
train_file_emotion = os.path.join(base_dir, 'train_emotion.csv')
val_file_emotion = os.path.join(base_dir, 'val_emotion.csv')
test_file_emotion = os.path.join(base_dir, 'test_emotion.csv')

if not all([os.path.exists(train_file_emotion), os.path.exists(val_file_emotion), os.path.exists(test_file_emotion)]):
    emotion_df = pd.read_parquet('../../data/emotion_without_outliers/emotion_without_outliers.parquet')
    emotion_df = emotion_df.drop(columns=['text_length'])
    
    target_samples_per_class = 16_667  # 100k / 6 classes of emotions
    
    balanced_data = emotion_df.groupby('label', group_keys=False).apply(
        lambda x: x.sample(n=min(len(x), target_samples_per_class), random_state=42)
    )
    
    train_data_emotion, temp_data = train_test_split(balanced_data, test_size=0.3, stratify=balanced_data['label'], random_state=42)
    val_data_emotion, test_data_emotion = train_test_split(temp_data, test_size=0.5, stratify=temp_data['label'], random_state=42)

    train_data_emotion.to_csv(train_file_emotion, index=False)
    val_data_emotion.to_csv(val_file_emotion, index=False)
    test_data_emotion.to_csv(test_file_emotion, index=False)
else:
    train_data_emotion = pd.read_csv(train_file_emotion)
    val_data_emotion = pd.read_csv(val_file_emotion)
    test_data_emotion = pd.read_csv(test_file_emotion)

# %% [markdown]
# # Setting training parameters
#
# Due to the uneven distribution of classes in the dataset, the classes will be weighted.

# %%
MAX_NUM_WORDS = 20000
MAX_SEQ_LENGTH = 256

tokenizer = Tokenizer(num_words=MAX_NUM_WORDS, oov_token="<OOV>")
tokenizer.fit_on_texts(train_data_sentiment['text'].tolist() + train_data_emotion['text'].tolist())

# %%
def encode_texts(texts):
    sequences = tokenizer.texts_to_sequences(texts)
    return pad_sequences(sequences, maxlen=MAX_SEQ_LENGTH, padding='post', truncating='post')

# %%
X_train_sentiment = encode_texts(train_data_sentiment['text'])
X_val_sentiment = encode_texts(val_data_sentiment['text'])
X_test_sentiment = encode_texts(test_data_sentiment['text'])

y_train_sentiment = train_data_sentiment['label'].values
y_val_sentiment = val_data_sentiment['label'].values
y_test_sentiment = test_data_sentiment['label'].values

# %%
X_train_emotion = encode_texts(train_data_emotion['text'])
X_val_emotion = encode_texts(val_data_emotion['text'])
X_test_emotion = encode_texts(test_data_emotion['text'])

y_train_emotion = train_data_emotion['label'].values
y_val_emotion = val_data_emotion['label'].values
y_test_emotion = test_data_emotion['label'].values

# %%
class_weights_sentiment = torch.tensor(compute_class_weight('balanced', classes=np.unique(y_train_sentiment), y=y_train_sentiment), dtype=torch.float)
class_weights_emotion = torch.tensor(compute_class_weight('balanced', classes=np.unique(y_train_emotion), y=y_train_emotion), dtype=torch.float)

# %%
class MultiTaskDataset(Dataset):
    def __init__(self, X_sent, y_sent, X_emot, y_emot):
        self.X_sent = torch.tensor(X_sent, dtype=torch.long)
        self.y_sent = torch.tensor(y_sent, dtype=torch.long)
        self.X_emot = torch.tensor(X_emot, dtype=torch.long)
        self.y_emot = torch.tensor(y_emot, dtype=torch.long)

    def __len__(self):
        return min(len(self.y_sent), len(self.y_emot))

    def __getitem__(self, idx):
        return {
            'input_ids_sent': self.X_sent[idx],
            'label_sent': self.y_sent[idx],
            'input_ids_emot': self.X_emot[idx],
            'label_emot': self.y_emot[idx]
        }

# %%
train_dataset = MultiTaskDataset(X_train_sentiment, y_train_sentiment, X_train_emotion, y_train_emotion)
val_dataset = MultiTaskDataset(X_val_sentiment, y_val_sentiment, X_val_emotion, y_val_emotion)
test_dataset = MultiTaskDataset(X_test_sentiment, y_test_sentiment, X_test_emotion, y_test_emotion)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)

# %% [markdown]
# # Model training

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class MultiTaskLSTM(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_labels_sentiment, num_labels_emotion):
        super(MultiTaskLSTM, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
        self.fc_sentiment = nn.Linear(hidden_dim, num_labels_sentiment)
        self.fc_emotion = nn.Linear(hidden_dim, num_labels_emotion)
    
    def forward(self, input_ids_sent, input_ids_emot):
        embedded_sent = self.embedding(input_ids_sent)
        embedded_emot = self.embedding(input_ids_emot)

        lstm_out_sent, _ = self.lstm(embedded_sent)
        lstm_out_emot, _ = self.lstm(embedded_emot)

        out_sentiment = self.fc_sentiment(lstm_out_sent[:, -1, :])
        out_emotion = self.fc_emotion(lstm_out_emot[:, -1, :])

        return out_sentiment, out_emotion

# %%
model = MultiTaskLSTM(vocab_size=MAX_NUM_WORDS, embed_dim=256, hidden_dim=256, num_labels_sentiment=3, num_labels_emotion=6).to(device)

# %%
loss_fn_sentiment = nn.CrossEntropyLoss(weight=class_weights_sentiment.to(device))
loss_fn_emotion = nn.CrossEntropyLoss(weight=class_weights_emotion.to(device))
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
def train_epoch(model, data_loader, loss_fn_sent, loss_fn_emot, optimizer, device, epoch):
    model.train()
    total_loss = 0
    correct_sentiment = 0
    correct_emotion = 0
    total_sentiment_samples = 0
    total_emotion_samples = 0

    for batch_idx, batch in enumerate(data_loader):
        input_ids_sent = batch['input_ids_sent'].to(device)
        labels_sent = batch['label_sent'].to(device)
        input_ids_emot = batch['input_ids_emot'].to(device)
        labels_emot = batch['label_emot'].to(device)

        optimizer.zero_grad()

        logits_sent, logits_emot = model(input_ids_sent, input_ids_emot)

        loss_sent = loss_fn_sent(logits_sent, labels_sent)
        loss_emot = loss_fn_emot(logits_emot, labels_emot)

        loss = loss_sent + loss_emot
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        _, preds_sent = torch.max(logits_sent, dim=1)
        _, preds_emot = torch.max(logits_emot, dim=1)

        correct_sentiment += (preds_sent == labels_sent).sum().item()
        correct_emotion += (preds_emot == labels_emot).sum().item()
        total_sentiment_samples += labels_sent.size(0)
        total_emotion_samples += labels_emot.size(0)
        
        if batch_idx % 10 == 0:
            avg_loss = total_loss / (batch_idx + 1)
            acc_sent = 100. * correct_sentiment / total_sentiment_samples
            acc_emot = 100. * correct_emotion / total_emotion_samples
            print(f"Epoch {epoch}. Batch {batch_idx}/{len(data_loader)}: "
                  f"AvgLoss: {avg_loss:.2f}, S.Acc: {acc_sent:.2f}%, E.Acc: {acc_emot:.2f}%")

    avg_loss = total_loss / len(data_loader)
    accuracy_sentiment = 100. * correct_sentiment / total_sentiment_samples
    accuracy_emotion = 100. * correct_emotion / total_emotion_samples
    return avg_loss, accuracy_sentiment, accuracy_emotion

# %%
def eval_model(model, data_loader, device):
    model.eval()
    correct_sentiment = 0
    correct_emotion = 0
    total_sentiment_samples = 0
    total_emotion_samples = 0

    with torch.no_grad():
        for batch in data_loader:
            input_ids_sent = batch['input_ids_sent'].to(device)
            labels_sent = batch['label_sent'].to(device)
            input_ids_emot = batch['input_ids_emot'].to(device)
            labels_emot = batch['label_emot'].to(device)

            logits_sent, logits_emot = model(input_ids_sent, input_ids_emot)

            _, preds_sent = torch.max(logits_sent, dim=1)
            _, preds_emot = torch.max(logits_emot, dim=1)

            correct_sentiment += (preds_sent == labels_sent).sum().item()
            correct_emotion += (preds_emot == labels_emot).sum().item()
            total_sentiment_samples += labels_sent.size(0)
            total_emotion_samples += labels_emot.size(0)

    accuracy_sentiment = 100. * correct_sentiment / total_sentiment_samples
    accuracy_emotion = 100. * correct_emotion / total_emotion_samples
    return accuracy_sentiment, accuracy_emotion

# %%
for epoch in range(2):
    train_loss, train_acc_sent, train_acc_emot = train_epoch(
        model, train_loader, loss_fn_sentiment, loss_fn_emotion, optimizer, device, epoch
    )
    print(f"Train Loss: {train_loss:.4f}, "
          f"Train Sentiment Accuracy: {train_acc_sent:.2f}%, "
          f"Train Emotion Accuracy: {train_acc_emot:.2f}%")
    val_acc_sent, val_acc_emot = eval_model(model, val_loader, device)
    print(f"Validation Sentiment Accuracy: {val_acc_sent:.2f}%, Validation Emotion Accuracy: {val_acc_emot:.2f}%")
# Out:
# Epoch 0. Batch 0/4290: AvgLoss: 2.86, S.Acc: 50.00%, E.Acc: 18.75%
# Epoch 0. Batch 10/4290: AvgLoss: 3.04, S.Acc: 26.14%, E.Acc: 18.75%
# Epoch 0. Batch 20/4290: AvgLoss: 2.98, S.Acc: 26.19%, E.Acc: 17.26%
# Epoch 0. Batch 30/4290: AvgLoss: 2.95, S.Acc: 29.03%, E.Acc: 17.94%
# Epoch 0. Batch 40/4290: AvgLoss: 2.94, S.Acc: 30.79%, E.Acc: 17.53%
# Epoch 0. Batch 50/4290: AvgLoss: 2.93, S.Acc: 32.48%, E.Acc: 18.63%
# Epoch 0. Batch 60/4290: AvgLoss: 2.92, S.Acc: 34.43%, E.Acc: 18.65%
# Epoch 0. Batch 70/4290: AvgLoss: 2.92, S.Acc: 33.98%, E.Acc: 18.93%
# Epoch 0. Batch 80/4290: AvgLoss: 2.92, S.Acc: 32.33%, E.Acc: 18.44%
# Epoch 0. Batch 90/4290: AvgLoss: 2.92, S.Acc: 33.38%, E.Acc: 17.99%
# Epoch 0. Batch 100/4290: AvgLoss: 2.91, S.Acc: 34.16%, E.Acc: 17.82%
# Epoch 0. Batch 110/4290: AvgLoss: 2.91, S.Acc: 34.68%, E.Acc: 17.79%
# Epoch 0. Batch 120/4290: AvgLoss: 2.91, S.Acc: 34.14%, E.Acc: 17.30%
# Epoch 0. Batch 130/4290: AvgLoss: 2.91, S.Acc: 33.11%, E.Acc: 17.51%
# Epoch 0. Batch 140/4290: AvgLoss: 2.91, S.Acc: 32.76%, E.Acc: 17.60%
# Epoch 0. Batch 150/4290: AvgLoss: 2.91, S.Acc: 33.40%, E.Acc: 17.34%
# Epoch 0. Batch 160/4290: AvgLoss: 2.91, S.Acc: 34.12%, E.Acc: 17.62%
# Epoch 0. Batch 170/4290: AvgLoss: 2.91, S.Acc: 34.80%, E.Acc: 17.47%
# Epoch 0. Batch 180/4290: AvgLoss: 2.91, S.Acc: 34.74%, E.Acc: 17.54%
# Epoch 0. Batch 190/4290: AvgLoss: 2.91, S.Acc: 34.69%, E.Acc: 17.34%
# Epoch 0. Batch 200/4290: AvgLoss: 2.91, S.Acc: 34.48%, E.Acc: 17.54%
# Epoch 0. Batch 210/4290: AvgLoss: 2.91, S.Acc: 34.57%, E.Acc: 17.65%
# Epoch 0. Batch 220/4290: AvgLoss: 2.90, S.Acc: 34.22%, E.Acc: 17.53%
# Epoch 0. Batch 230/4290: AvgLoss: 2.90, S.Acc: 34.55%, E.Acc: 17.32%
# Epoch 0. Batch 240/4290: AvgLoss: 2.90, S.Acc: 34.93%, E.Acc: 17.19%
# Epoch 0. Batch 250/4290: AvgLoss: 2.90, S.Acc: 34.49%, E.Acc: 17.08%
# Epoch 0. Batch 260/4290: AvgLoss: 2.90, S.Acc: 34.12%, E.Acc: 17.10%
# Epoch 0. Batch 270/4290: AvgLoss: 2.90, S.Acc: 33.95%, E.Acc: 17.07%
# Epoch 0. Batch 280/4290: AvgLoss: 2.90, S.Acc: 33.94%, E.Acc: 17.10%
# Epoch 0. Batch 290/4290: AvgLoss: 2.90, S.Acc: 34.04%, E.Acc: 17.16%
# Epoch 0. Batch 300/4290: AvgLoss: 2.90, S.Acc: 34.07%, E.Acc: 17.07%
# Epoch 0. Batch 310/4290: AvgLoss: 2.90, S.Acc: 34.14%, E.Acc: 17.12%
# Epoch 0. Batch 320/4290: AvgLoss: 2.90, S.Acc: 34.09%, E.Acc: 16.98%
# Epoch 0. Batch 330/4290: AvgLoss: 2.90, S.Acc: 34.08%, E.Acc: 16.82%
# Epoch 0. Batch 340/4290: AvgLoss: 2.90, S.Acc: 34.13%, E.Acc: 16.81%
# Epoch 0. Batch 350/4290: AvgLoss: 2.90, S.Acc: 34.01%, E.Acc: 16.86%
# Epoch 0. Batch 360/4290: AvgLoss: 2.90, S.Acc: 34.38%, E.Acc: 16.91%
# Epoch 0. Batch 370/4290: AvgLoss: 2.90, S.Acc: 34.48%, E.Acc: 16.93%
# Epoch 0. Batch 380/4290: AvgLoss: 2.90, S.Acc: 34.71%, E.Acc: 16.90%
# Epoch 0. Batch 390/4290: AvgLoss: 2.90, S.Acc: 35.07%, E.Acc: 16.88%
# Epoch 0. Batch 400/4290: AvgLoss: 2.90, S.Acc: 35.13%, E.Acc: 16.77%
# Epoch 0. Batch 410/4290: AvgLoss: 2.90, S.Acc: 35.55%, E.Acc: 16.88%
# Epoch 0. Batch 420/4290: AvgLoss: 2.90, S.Acc: 35.85%, E.Acc: 16.98%
# Epoch 0. Batch 430/4290: AvgLoss: 2.90, S.Acc: 36.05%, E.Acc: 17.15%
# Epoch 0. Batch 440/4290: AvgLoss: 2.90, S.Acc: 36.25%, E.Acc: 17.04%
# Epoch 0. Batch 450/4290: AvgLoss: 2.90, S.Acc: 36.42%, E.Acc: 16.95%
# Epoch 0. Batch 460/4290: AvgLoss: 2.90, S.Acc: 36.48%, E.Acc: 16.93%
# Epoch 0. Batch 470/4290: AvgLoss: 2.90, S.Acc: 36.68%, E.Acc: 16.96%
# Epoch 0. Batch 480/4290: AvgLoss: 2.90, S.Acc: 36.88%, E.Acc: 16.93%
# Epoch 0. Batch 490/4290: AvgLoss: 2.90, S.Acc: 36.99%, E.Acc: 16.90%
# Epoch 0. Batch 500/4290: AvgLoss: 2.90, S.Acc: 37.09%, E.Acc: 16.97%
# Epoch 0. Batch 510/4290: AvgLoss: 2.90, S.Acc: 37.13%, E.Acc: 17.01%
# Epoch 0. Batch 520/4290: AvgLoss: 2.90, S.Acc: 37.43%, E.Acc: 17.00%
# Epoch 0. Batch 530/4290: AvgLoss: 2.90, S.Acc: 37.54%, E.Acc: 16.95%
# Epoch 0. Batch 540/4290: AvgLoss: 2.90, S.Acc: 37.63%, E.Acc: 16.89%
# Epoch 0. Batch 550/4290: AvgLoss: 2.90, S.Acc: 37.67%, E.Acc: 16.87%
# Epoch 0. Batch 560/4290: AvgLoss: 2.90, S.Acc: 37.69%, E.Acc: 16.98%
# Epoch 0. Batch 570/4290: AvgLoss: 2.90, S.Acc: 37.74%, E.Acc: 16.98%
# Epoch 0. Batch 580/4290: AvgLoss: 2.90, S.Acc: 37.70%, E.Acc: 17.02%
# Epoch 0. Batch 590/4290: AvgLoss: 2.90, S.Acc: 37.67%, E.Acc: 17.05%
# Epoch 0. Batch 600/4290: AvgLoss: 2.90, S.Acc: 37.67%, E.Acc: 17.02%
# Epoch 0. Batch 610/4290: AvgLoss: 2.90, S.Acc: 37.64%, E.Acc: 16.96%
# Epoch 0. Batch 620/4290: AvgLoss: 2.90, S.Acc: 37.39%, E.Acc: 17.02%
# Epoch 0. Batch 630/4290: AvgLoss: 2.90, S.Acc: 37.22%, E.Acc: 17.01%
# Epoch 0. Batch 640/4290: AvgLoss: 2.90, S.Acc: 36.92%, E.Acc: 17.00%
# Epoch 0. Batch 650/4290: AvgLoss: 2.90, S.Acc: 36.80%, E.Acc: 17.04%
# Epoch 0. Batch 660/4290: AvgLoss: 2.90, S.Acc: 36.58%, E.Acc: 17.04%
# Epoch 0. Batch 670/4290: AvgLoss: 2.90, S.Acc: 36.42%, E.Acc: 17.06%
# Epoch 0. Batch 680/4290: AvgLoss: 2.90, S.Acc: 36.34%, E.Acc: 17.04%
# Epoch 0. Batch 690/4290: AvgLoss: 2.90, S.Acc: 36.29%, E.Acc: 17.08%
# Epoch 0. Batch 700/4290: AvgLoss: 2.90, S.Acc: 36.23%, E.Acc: 17.14%
# Epoch 0. Batch 710/4290: AvgLoss: 2.90, S.Acc: 36.23%, E.Acc: 17.17%
# Epoch 0. Batch 720/4290: AvgLoss: 2.90, S.Acc: 36.16%, E.Acc: 17.24%
# Epoch 0. Batch 730/4290: AvgLoss: 2.90, S.Acc: 35.94%, E.Acc: 17.24%
# Epoch 0. Batch 740/4290: AvgLoss: 2.90, S.Acc: 35.76%, E.Acc: 17.26%
# Epoch 0. Batch 750/4290: AvgLoss: 2.90, S.Acc: 35.67%, E.Acc: 17.22%
# Epoch 0. Batch 760/4290: AvgLoss: 2.90, S.Acc: 35.45%, E.Acc: 17.20%
# Epoch 0. Batch 770/4290: AvgLoss: 2.90, S.Acc: 35.33%, E.Acc: 17.27%
# Epoch 0. Batch 780/4290: AvgLoss: 2.90, S.Acc: 35.09%, E.Acc: 17.33%
# Epoch 0. Batch 790/4290: AvgLoss: 2.90, S.Acc: 35.10%, E.Acc: 17.33%
# Epoch 0. Batch 800/4290: AvgLoss: 2.90, S.Acc: 34.97%, E.Acc: 17.37%
# Epoch 0. Batch 810/4290: AvgLoss: 2.90, S.Acc: 34.81%, E.Acc: 17.35%
# Epoch 0. Batch 820/4290: AvgLoss: 2.90, S.Acc: 34.86%, E.Acc: 17.38%
# Epoch 0. Batch 830/4290: AvgLoss: 2.90, S.Acc: 34.85%, E.Acc: 17.37%
# Epoch 0. Batch 840/4290: AvgLoss: 2.90, S.Acc: 34.79%, E.Acc: 17.38%
# Epoch 0. Batch 850/4290: AvgLoss: 2.90, S.Acc: 34.91%, E.Acc: 17.37%
# Epoch 0. Batch 860/4290: AvgLoss: 2.90, S.Acc: 35.04%, E.Acc: 17.40%
# Epoch 0. Batch 870/4290: AvgLoss: 2.90, S.Acc: 35.07%, E.Acc: 17.34%
# Epoch 0. Batch 880/4290: AvgLoss: 2.90, S.Acc: 35.13%, E.Acc: 17.33%
# Epoch 0. Batch 890/4290: AvgLoss: 2.90, S.Acc: 35.25%, E.Acc: 17.29%
# Epoch 0. Batch 900/4290: AvgLoss: 2.90, S.Acc: 35.29%, E.Acc: 17.27%
# Epoch 0. Batch 910/4290: AvgLoss: 2.90, S.Acc: 35.29%, E.Acc: 17.23%
# Epoch 0. Batch 920/4290: AvgLoss: 2.90, S.Acc: 35.29%, E.Acc: 17.19%
# Epoch 0. Batch 930/4290: AvgLoss: 2.90, S.Acc: 35.27%, E.Acc: 17.15%
# Epoch 0. Batch 940/4290: AvgLoss: 2.89, S.Acc: 35.28%, E.Acc: 17.22%
# Epoch 0. Batch 950/4290: AvgLoss: 2.89, S.Acc: 35.29%, E.Acc: 17.23%
# Epoch 0. Batch 960/4290: AvgLoss: 2.89, S.Acc: 35.28%, E.Acc: 17.23%
# Epoch 0. Batch 970/4290: AvgLoss: 2.89, S.Acc: 35.24%, E.Acc: 17.24%
# Epoch 0. Batch 980/4290: AvgLoss: 2.89, S.Acc: 35.24%, E.Acc: 17.18%
# Epoch 0. Batch 990/4290: AvgLoss: 2.89, S.Acc: 35.24%, E.Acc: 17.22%
# Epoch 0. Batch 1000/4290: AvgLoss: 2.89, S.Acc: 35.17%, E.Acc: 17.28%
# Epoch 0. Batch 1010/4290: AvgLoss: 2.89, S.Acc: 35.17%, E.Acc: 17.27%
# Epoch 0. Batch 1020/4290: AvgLoss: 2.89, S.Acc: 35.17%, E.Acc: 17.24%
# Epoch 0. Batch 1030/4290: AvgLoss: 2.89, S.Acc: 35.22%, E.Acc: 17.22%
# Epoch 0. Batch 1040/4290: AvgLoss: 2.89, S.Acc: 35.22%, E.Acc: 17.27%
# Epoch 0. Batch 1050/4290: AvgLoss: 2.89, S.Acc: 35.17%, E.Acc: 17.23%
# Epoch 0. Batch 1060/4290: AvgLoss: 2.89, S.Acc: 35.17%, E.Acc: 17.20%
# Epoch 0. Batch 1070/4290: AvgLoss: 2.89, S.Acc: 35.15%, E.Acc: 17.23%
# Epoch 0. Batch 1080/4290: AvgLoss: 2.89, S.Acc: 35.15%, E.Acc: 17.26%
# Epoch 0. Batch 1090/4290: AvgLoss: 2.89, S.Acc: 35.15%, E.Acc: 17.28%
# Epoch 0. Batch 1100/4290: AvgLoss: 2.89, S.Acc: 35.20%, E.Acc: 17.28%
# Epoch 0. Batch 1110/4290: AvgLoss: 2.89, S.Acc: 35.13%, E.Acc: 17.26%
# Epoch 0. Batch 1120/4290: AvgLoss: 2.89, S.Acc: 35.15%, E.Acc: 17.24%
# Epoch 0. Batch 1130/4290: AvgLoss: 2.89, S.Acc: 35.13%, E.Acc: 17.20%
# Epoch 0. Batch 1140/4290: AvgLoss: 2.89, S.Acc: 35.08%, E.Acc: 17.22%
# Epoch 0. Batch 1150/4290: AvgLoss: 2.89, S.Acc: 35.04%, E.Acc: 17.20%
# Epoch 0. Batch 1160/4290: AvgLoss: 2.89, S.Acc: 34.91%, E.Acc: 17.20%
# Epoch 0. Batch 1170/4290: AvgLoss: 2.89, S.Acc: 34.87%, E.Acc: 17.18%
# Epoch 0. Batch 2040/4290: AvgLoss: 2.89, S.Acc: 36.24%, E.Acc: 17.09%
# Epoch 0. Batch 2050/4290: AvgLoss: 2.89, S.Acc: 36.27%, E.Acc: 17.10%
# Epoch 0. Batch 2060/4290: AvgLoss: 2.89, S.Acc: 36.30%, E.Acc: 17.11%
# Epoch 0. Batch 2070/4290: AvgLoss: 2.89, S.Acc: 36.30%, E.Acc: 17.08%
# Epoch 0. Batch 2080/4290: AvgLoss: 2.89, S.Acc: 36.34%, E.Acc: 17.06%
# Epoch 0. Batch 2090/4290: AvgLoss: 2.89, S.Acc: 36.38%, E.Acc: 17.03%
# Epoch 0. Batch 2100/4290: AvgLoss: 2.89, S.Acc: 36.45%, E.Acc: 17.01%
# Epoch 0. Batch 2110/4290: AvgLoss: 2.89, S.Acc: 36.45%, E.Acc: 17.02%
# Epoch 0. Batch 2120/4290: AvgLoss: 2.89, S.Acc: 36.47%, E.Acc: 17.03%
# Epoch 0. Batch 2130/4290: AvgLoss: 2.89, S.Acc: 36.49%, E.Acc: 17.05%
# Epoch 0. Batch 2140/4290: AvgLoss: 2.89, S.Acc: 36.51%, E.Acc: 17.05%
# Epoch 0. Batch 2150/4290: AvgLoss: 2.89, S.Acc: 36.58%, E.Acc: 17.03%
# Epoch 0. Batch 2160/4290: AvgLoss: 2.89, S.Acc: 36.63%, E.Acc: 17.02%
# Epoch 0. Batch 2170/4290: AvgLoss: 2.89, S.Acc: 36.67%, E.Acc: 17.01%
# Epoch 0. Batch 2180/4290: AvgLoss: 2.89, S.Acc: 36.72%, E.Acc: 17.00%
# Epoch 0. Batch 2190/4290: AvgLoss: 2.89, S.Acc: 36.74%, E.Acc: 16.98%
# Epoch 0. Batch 2200/4290: AvgLoss: 2.89, S.Acc: 36.79%, E.Acc: 16.99%
# Epoch 0. Batch 2210/4290: AvgLoss: 2.89, S.Acc: 36.80%, E.Acc: 17.01%
# Epoch 0. Batch 2220/4290: AvgLoss: 2.89, S.Acc: 36.83%, E.Acc: 17.00%
# Epoch 0. Batch 2230/4290: AvgLoss: 2.89, S.Acc: 36.84%, E.Acc: 16.99%
# Epoch 0. Batch 2240/4290: AvgLoss: 2.89, S.Acc: 36.88%, E.Acc: 16.97%
# Epoch 0. Batch 2250/4290: AvgLoss: 2.89, S.Acc: 36.90%, E.Acc: 16.98%
# Epoch 0. Batch 2260/4290: AvgLoss: 2.89, S.Acc: 36.95%, E.Acc: 16.97%
# Epoch 0. Batch 2270/4290: AvgLoss: 2.89, S.Acc: 36.94%, E.Acc: 16.98%
# Epoch 0. Batch 2280/4290: AvgLoss: 2.89, S.Acc: 36.97%, E.Acc: 16.97%
# Epoch 0. Batch 2290/4290: AvgLoss: 2.89, S.Acc: 37.00%, E.Acc: 17.00%
# Epoch 0. Batch 2300/4290: AvgLoss: 2.89, S.Acc: 37.02%, E.Acc: 17.00%
# Epoch 0. Batch 2310/4290: AvgLoss: 2.89, S.Acc: 37.05%, E.Acc: 17.00%
# Epoch 0. Batch 2320/4290: AvgLoss: 2.89, S.Acc: 37.07%, E.Acc: 17.01%
# Epoch 0. Batch 3770/4290: AvgLoss: 2.89, S.Acc: 38.24%, E.Acc: 16.93%
# Epoch 0. Batch 3780/4290: AvgLoss: 2.89, S.Acc: 38.26%, E.Acc: 16.94%
# Epoch 0. Batch 3790/4290: AvgLoss: 2.89, S.Acc: 38.27%, E.Acc: 16.94%
# Epoch 0. Batch 3800/4290: AvgLoss: 2.89, S.Acc: 38.28%, E.Acc: 16.94%
# Epoch 0. Batch 3810/4290: AvgLoss: 2.89, S.Acc: 38.30%, E.Acc: 16.93%
# Epoch 0. Batch 3820/4290: AvgLoss: 2.89, S.Acc: 38.31%, E.Acc: 16.91%
# Epoch 0. Batch 3830/4290: AvgLoss: 2.89, S.Acc: 38.32%, E.Acc: 16.92%
# Epoch 0. Batch 3840/4290: AvgLoss: 2.89, S.Acc: 38.33%, E.Acc: 16.91%
# Epoch 0. Batch 3850/4290: AvgLoss: 2.89, S.Acc: 38.34%, E.Acc: 16.90%
# Epoch 0. Batch 3860/4290: AvgLoss: 2.89, S.Acc: 38.35%, E.Acc: 16.88%
# Epoch 0. Batch 3870/4290: AvgLoss: 2.89, S.Acc: 38.37%, E.Acc: 16.87%
# Epoch 0. Batch 3880/4290: AvgLoss: 2.89, S.Acc: 38.41%, E.Acc: 16.86%
# Epoch 0. Batch 3890/4290: AvgLoss: 2.89, S.Acc: 38.41%, E.Acc: 16.85%
# Epoch 0. Batch 3900/4290: AvgLoss: 2.89, S.Acc: 38.43%, E.Acc: 16.86%
# Epoch 0. Batch 3910/4290: AvgLoss: 2.89, S.Acc: 38.43%, E.Acc: 16.86%
# Epoch 0. Batch 3920/4290: AvgLoss: 2.89, S.Acc: 38.45%, E.Acc: 16.87%
# Epoch 0. Batch 3930/4290: AvgLoss: 2.89, S.Acc: 38.46%, E.Acc: 16.86%
# Epoch 0. Batch 3940/4290: AvgLoss: 2.89, S.Acc: 38.47%, E.Acc: 16.86%
# Epoch 0. Batch 3950/4290: AvgLoss: 2.89, S.Acc: 38.47%, E.Acc: 16.84%
# Epoch 0. Batch 3960/4290: AvgLoss: 2.89, S.Acc: 38.49%, E.Acc: 16.83%
# Epoch 0. Batch 3970/4290: AvgLoss: 2.89, S.Acc: 38.50%, E.Acc: 16.82%
# Epoch 0. Batch 3980/4290: AvgLoss: 2.89, S.Acc: 38.50%, E.Acc: 16.82%
# Epoch 0. Batch 3990/4290: AvgLoss: 2.89, S.Acc: 38.52%, E.Acc: 16.82%
# Epoch 0. Batch 4000/4290: AvgLoss: 2.89, S.Acc: 38.52%, E.Acc: 16.82%
# Epoch 0. Batch 4010/4290: AvgLoss: 2.89, S.Acc: 38.53%, E.Acc: 16.82%
# Epoch 0. Batch 4020/4290: AvgLoss: 2.89, S.Acc: 38.55%, E.Acc: 16.82%
# Epoch 0. Batch 4030/4290: AvgLoss: 2.89, S.Acc: 38.56%, E.Acc: 16.82%
# Epoch 0. Batch 4040/4290: AvgLoss: 2.89, S.Acc: 38.57%, E.Acc: 16.83%
# Epoch 0. Batch 4050/4290: AvgLoss: 2.89, S.Acc: 38.58%, E.Acc: 16.84%
# Epoch 0. Batch 4060/4290: AvgLoss: 2.89, S.Acc: 38.60%, E.Acc: 16.86%
# Epoch 0. Batch 4070/4290: AvgLoss: 2.89, S.Acc: 38.60%, E.Acc: 16.86%
# Epoch 0. Batch 4080/4290: AvgLoss: 2.89, S.Acc: 38.60%, E.Acc: 16.86%
# Epoch 0. Batch 4090/4290: AvgLoss: 2.89, S.Acc: 38.62%, E.Acc: 16.86%
# Epoch 0. Batch 4100/4290: AvgLoss: 2.89, S.Acc: 38.62%, E.Acc: 16.88%
# Epoch 0. Batch 4110/4290: AvgLoss: 2.89, S.Acc: 38.63%, E.Acc: 16.87%
# Epoch 0. Batch 4120/4290: AvgLoss: 2.89, S.Acc: 38.64%, E.Acc: 16.89%
# Epoch 0. Batch 4130/4290: AvgLoss: 2.89, S.Acc: 38.65%, E.Acc: 16.89%
# Epoch 0. Batch 4140/4290: AvgLoss: 2.89, S.Acc: 38.64%, E.Acc: 16.90%
# Epoch 0. Batch 4150/4290: AvgLoss: 2.89, S.Acc: 38.62%, E.Acc: 16.89%
# Epoch 0. Batch 4160/4290: AvgLoss: 2.89, S.Acc: 38.62%, E.Acc: 16.89%
# Epoch 0. Batch 4170/4290: AvgLoss: 2.89, S.Acc: 38.63%, E.Acc: 16.90%
# Epoch 0. Batch 4180/4290: AvgLoss: 2.89, S.Acc: 38.64%, E.Acc: 16.88%
# Epoch 0. Batch 4190/4290: AvgLoss: 2.89, S.Acc: 38.66%, E.Acc: 16.88%
# Epoch 0. Batch 4200/4290: AvgLoss: 2.89, S.Acc: 38.66%, E.Acc: 16.88%
# Epoch 0. Batch 4210/4290: AvgLoss: 2.89, S.Acc: 38.68%, E.Acc: 16.88%
# Epoch 0. Batch 4220/4290: AvgLoss: 2.89, S.Acc: 38.68%, E.Acc: 16.89%
# Epoch 0. Batch 4230/4290: AvgLoss: 2.89, S.Acc: 38.68%, E.Acc: 16.91%
# Epoch 0. Batch 4240/4290: AvgLoss: 2.89, S.Acc: 38.70%, E.Acc: 16.92%
# Epoch 0. Batch 4250/4290: AvgLoss: 2.89, S.Acc: 38.69%, E.Acc: 16.93%
# Epoch 0. Batch 4260/4290: AvgLoss: 2.89, S.Acc: 38.67%, E.Acc: 16.92%
# Epoch 0. Batch 4270/4290: AvgLoss: 2.89, S.Acc: 38.67%, E.Acc: 16.92%
# Epoch 0. Batch 4280/4290: AvgLoss: 2.89, S.Acc: 38.66%, E.Acc: 16.93%
# Train Loss: 2.8915, Train Sentiment Accuracy: 38.65%, Train Emotion Accuracy: 16.94%
# Validation Sentiment Accuracy: 34.34%, Validation Emotion Accuracy: 17.00%
# Epoch 1. Batch 0/4290: AvgLoss: 2.90, S.Acc: 25.00%, E.Acc: 12.50%
# Epoch 1. Batch 10/4290: AvgLoss: 2.89, S.Acc: 28.41%, E.Acc: 18.75%
# Epoch 1. Batch 20/4290: AvgLoss: 2.90, S.Acc: 29.17%, E.Acc: 19.35%
# Epoch 1. Batch 30/4290: AvgLoss: 2.89, S.Acc: 30.44%, E.Acc: 19.76%
# Epoch 1. Batch 40/4290: AvgLoss: 2.89, S.Acc: 30.34%, E.Acc: 19.05%
# Epoch 1. Batch 2370/4290: AvgLoss: 2.89, S.Acc: 39.37%, E.Acc: 16.53%
# Epoch 1. Batch 2380/4290: AvgLoss: 2.89, S.Acc: 39.37%, E.Acc: 16.54%
# Epoch 1. Batch 2390/4290: AvgLoss: 2.89, S.Acc: 39.39%, E.Acc: 16.54%
# Epoch 1. Batch 2400/4290: AvgLoss: 2.89, S.Acc: 39.42%, E.Acc: 16.53%
# Epoch 1. Batch 2410/4290: AvgLoss: 2.89, S.Acc: 39.39%, E.Acc: 16.55%
# Epoch 1. Batch 2420/4290: AvgLoss: 2.89, S.Acc: 39.44%, E.Acc: 16.57%
# Epoch 1. Batch 2430/4290: AvgLoss: 2.89, S.Acc: 39.46%, E.Acc: 16.56%
# Epoch 1. Batch 2440/4290: AvgLoss: 2.89, S.Acc: 39.46%, E.Acc: 16.55%
# Epoch 1. Batch 2450/4290: AvgLoss: 2.89, S.Acc: 39.47%, E.Acc: 16.56%
# Epoch 1. Batch 2460/4290: AvgLoss: 2.89, S.Acc: 39.51%, E.Acc: 16.57%
# Epoch 1. Batch 2470/4290: AvgLoss: 2.89, S.Acc: 39.54%, E.Acc: 16.56%
# Epoch 1. Batch 2480/4290: AvgLoss: 2.89, S.Acc: 39.54%, E.Acc: 16.55%
# Epoch 1. Batch 2490/4290: AvgLoss: 2.89, S.Acc: 39.57%, E.Acc: 16.55%
# Epoch 1. Batch 2500/4290: AvgLoss: 2.89, S.Acc: 39.58%, E.Acc: 16.57%
# Epoch 1. Batch 2510/4290: AvgLoss: 2.89, S.Acc: 39.59%, E.Acc: 16.58%
# Epoch 1. Batch 2520/4290: AvgLoss: 2.89, S.Acc: 39.60%, E.Acc: 16.56%
# Epoch 1. Batch 2530/4290: AvgLoss: 2.89, S.Acc: 39.63%, E.Acc: 16.56%
# Epoch 1. Batch 2540/4290: AvgLoss: 2.89, S.Acc: 39.65%, E.Acc: 16.57%
# Epoch 1. Batch 2550/4290: AvgLoss: 2.89, S.Acc: 39.65%, E.Acc: 16.57%
# Epoch 1. Batch 2560/4290: AvgLoss: 2.89, S.Acc: 39.66%, E.Acc: 16.55%
# Epoch 1. Batch 2570/4290: AvgLoss: 2.89, S.Acc: 39.65%, E.Acc: 16.55%
# Epoch 1. Batch 2580/4290: AvgLoss: 2.89, S.Acc: 39.66%, E.Acc: 16.54%
# Epoch 1. Batch 2590/4290: AvgLoss: 2.89, S.Acc: 39.68%, E.Acc: 16.54%
# Epoch 1. Batch 2600/4290: AvgLoss: 2.89, S.Acc: 39.70%, E.Acc: 16.55%
# Epoch 1. Batch 2610/4290: AvgLoss: 2.89, S.Acc: 39.70%, E.Acc: 16.55%
# Epoch 1. Batch 2620/4290: AvgLoss: 2.89, S.Acc: 39.72%, E.Acc: 16.57%
# Epoch 1. Batch 2630/4290: AvgLoss: 2.89, S.Acc: 39.75%, E.Acc: 16.58%
# Epoch 1. Batch 2640/4290: AvgLoss: 2.89, S.Acc: 39.77%, E.Acc: 16.58%
# Epoch 1. Batch 2650/4290: AvgLoss: 2.89, S.Acc: 39.76%, E.Acc: 16.58%
# Epoch 1. Batch 2660/4290: AvgLoss: 2.89, S.Acc: 39.77%, E.Acc: 16.57%
# Epoch 1. Batch 2670/4290: AvgLoss: 2.89, S.Acc: 39.77%, E.Acc: 16.59%
# Epoch 1. Batch 2680/4290: AvgLoss: 2.89, S.Acc: 39.78%, E.Acc: 16.60%
# Epoch 1. Batch 2690/4290: AvgLoss: 2.89, S.Acc: 39.79%, E.Acc: 16.61%
# Epoch 1. Batch 2700/4290: AvgLoss: 2.89, S.Acc: 39.82%, E.Acc: 16.62%
# Epoch 1. Batch 2710/4290: AvgLoss: 2.89, S.Acc: 39.83%, E.Acc: 16.63%
# Epoch 1. Batch 2720/4290: AvgLoss: 2.89, S.Acc: 39.84%, E.Acc: 16.64%
# Epoch 1. Batch 2730/4290: AvgLoss: 2.89, S.Acc: 39.84%, E.Acc: 16.63%
# Epoch 1. Batch 2740/4290: AvgLoss: 2.89, S.Acc: 39.85%, E.Acc: 16.64%
# Epoch 1. Batch 2750/4290: AvgLoss: 2.89, S.Acc: 39.84%, E.Acc: 16.66%
# Epoch 1. Batch 2760/4290: AvgLoss: 2.89, S.Acc: 39.85%, E.Acc: 16.66%
# Epoch 1. Batch 2770/4290: AvgLoss: 2.89, S.Acc: 39.85%, E.Acc: 16.66%
# Epoch 1. Batch 2780/4290: AvgLoss: 2.89, S.Acc: 39.87%, E.Acc: 16.65%
# Epoch 1. Batch 2790/4290: AvgLoss: 2.89, S.Acc: 39.89%, E.Acc: 16.65%
# Epoch 1. Batch 2800/4290: AvgLoss: 2.89, S.Acc: 39.91%, E.Acc: 16.66%
# Epoch 1. Batch 2810/4290: AvgLoss: 2.89, S.Acc: 39.91%, E.Acc: 16.66%
# Epoch 1. Batch 2820/4290: AvgLoss: 2.89, S.Acc: 39.91%, E.Acc: 16.66%
# Epoch 1. Batch 2830/4290: AvgLoss: 2.89, S.Acc: 39.88%, E.Acc: 16.67%
# Epoch 1. Batch 2840/4290: AvgLoss: 2.89, S.Acc: 39.82%, E.Acc: 16.69%
# Epoch 1. Batch 2850/4290: AvgLoss: 2.89, S.Acc: 39.75%, E.Acc: 16.68%
# Epoch 1. Batch 2860/4290: AvgLoss: 2.89, S.Acc: 39.68%, E.Acc: 16.69%
# Epoch 1. Batch 2870/4290: AvgLoss: 2.89, S.Acc: 39.64%, E.Acc: 16.69%
# Epoch 1. Batch 2880/4290: AvgLoss: 2.89, S.Acc: 39.58%, E.Acc: 16.70%
# Epoch 1. Batch 2890/4290: AvgLoss: 2.89, S.Acc: 39.54%, E.Acc: 16.69%
# Epoch 1. Batch 2900/4290: AvgLoss: 2.89, S.Acc: 39.48%, E.Acc: 16.66%
# Epoch 1. Batch 2910/4290: AvgLoss: 2.89, S.Acc: 39.42%, E.Acc: 16.65%
# Epoch 1. Batch 2920/4290: AvgLoss: 2.89, S.Acc: 39.38%, E.Acc: 16.66%
# Epoch 1. Batch 2930/4290: AvgLoss: 2.89, S.Acc: 39.38%, E.Acc: 16.66%
# Epoch 1. Batch 2940/4290: AvgLoss: 2.89, S.Acc: 39.37%, E.Acc: 16.65%
# Epoch 1. Batch 2950/4290: AvgLoss: 2.89, S.Acc: 39.36%, E.Acc: 16.66%
# Epoch 1. Batch 2960/4290: AvgLoss: 2.89, S.Acc: 39.34%, E.Acc: 16.66%
# Epoch 1. Batch 2970/4290: AvgLoss: 2.89, S.Acc: 39.32%, E.Acc: 16.67%
# Epoch 1. Batch 2980/4290: AvgLoss: 2.89, S.Acc: 39.32%, E.Acc: 16.68%
# Epoch 1. Batch 2990/4290: AvgLoss: 2.89, S.Acc: 39.29%, E.Acc: 16.69%
# Epoch 1. Batch 3000/4290: AvgLoss: 2.89, S.Acc: 39.29%, E.Acc: 16.69%
# Epoch 1. Batch 3010/4290: AvgLoss: 2.89, S.Acc: 39.26%, E.Acc: 16.67%
# Epoch 1. Batch 3020/4290: AvgLoss: 2.89, S.Acc: 39.25%, E.Acc: 16.66%
# Epoch 1. Batch 3030/4290: AvgLoss: 2.89, S.Acc: 39.23%, E.Acc: 16.64%
# Epoch 1. Batch 3040/4290: AvgLoss: 2.89, S.Acc: 39.22%, E.Acc: 16.65%
# Epoch 1. Batch 3050/4290: AvgLoss: 2.89, S.Acc: 39.20%, E.Acc: 16.63%
# Epoch 1. Batch 3060/4290: AvgLoss: 2.89, S.Acc: 39.19%, E.Acc: 16.63%
# Epoch 1. Batch 3070/4290: AvgLoss: 2.89, S.Acc: 39.18%, E.Acc: 16.66%
# Epoch 1. Batch 3080/4290: AvgLoss: 2.89, S.Acc: 39.19%, E.Acc: 16.65%
# Epoch 1. Batch 3090/4290: AvgLoss: 2.89, S.Acc: 39.17%, E.Acc: 16.65%
# Epoch 1. Batch 3100/4290: AvgLoss: 2.89, S.Acc: 39.17%, E.Acc: 16.65%
# Epoch 1. Batch 3110/4290: AvgLoss: 2.89, S.Acc: 39.16%, E.Acc: 16.64%
# Epoch 1. Batch 3120/4290: AvgLoss: 2.89, S.Acc: 39.15%, E.Acc: 16.65%
# Epoch 1. Batch 3130/4290: AvgLoss: 2.89, S.Acc: 39.13%, E.Acc: 16.67%
# Epoch 1. Batch 3140/4290: AvgLoss: 2.89, S.Acc: 39.13%, E.Acc: 16.65%
# Epoch 1. Batch 3150/4290: AvgLoss: 2.89, S.Acc: 39.12%, E.Acc: 16.66%
# Epoch 1. Batch 3160/4290: AvgLoss: 2.89, S.Acc: 39.11%, E.Acc: 16.67%
# Epoch 1. Batch 3170/4290: AvgLoss: 2.89, S.Acc: 39.09%, E.Acc: 16.66%
# Epoch 1. Batch 3180/4290: AvgLoss: 2.89, S.Acc: 39.08%, E.Acc: 16.66%
# Epoch 1. Batch 3190/4290: AvgLoss: 2.89, S.Acc: 39.07%, E.Acc: 16.65%
# Epoch 1. Batch 3200/4290: AvgLoss: 2.89, S.Acc: 39.05%, E.Acc: 16.65%
# Epoch 1. Batch 3210/4290: AvgLoss: 2.89, S.Acc: 39.04%, E.Acc: 16.64%
# Epoch 1. Batch 3220/4290: AvgLoss: 2.89, S.Acc: 39.02%, E.Acc: 16.63%
# Epoch 1. Batch 3230/4290: AvgLoss: 2.89, S.Acc: 39.00%, E.Acc: 16.64%
# Epoch 1. Batch 3530/4290: AvgLoss: 2.89, S.Acc: 38.89%, E.Acc: 16.58%
# Epoch 1. Batch 3540/4290: AvgLoss: 2.89, S.Acc: 38.90%, E.Acc: 16.58%
# Epoch 1. Batch 3550/4290: AvgLoss: 2.89, S.Acc: 38.91%, E.Acc: 16.57%
# Epoch 1. Batch 3560/4290: AvgLoss: 2.89, S.Acc: 38.92%, E.Acc: 16.56%
# Epoch 1. Batch 3570/4290: AvgLoss: 2.89, S.Acc: 38.92%, E.Acc: 16.56%
# Epoch 1. Batch 3580/4290: AvgLoss: 2.89, S.Acc: 38.90%, E.Acc: 16.58%
# Epoch 1. Batch 3590/4290: AvgLoss: 2.89, S.Acc: 38.89%, E.Acc: 16.58%
# Epoch 1. Batch 3600/4290: AvgLoss: 2.89, S.Acc: 38.87%, E.Acc: 16.59%
# Epoch 1. Batch 3610/4290: AvgLoss: 2.89, S.Acc: 38.87%, E.Acc: 16.59%
# Epoch 1. Batch 3620/4290: AvgLoss: 2.89, S.Acc: 38.87%, E.Acc: 16.59%
# Epoch 1. Batch 3630/4290: AvgLoss: 2.89, S.Acc: 38.87%, E.Acc: 16.57%
# Epoch 1. Batch 3640/4290: AvgLoss: 2.89, S.Acc: 38.85%, E.Acc: 16.57%
# Epoch 1. Batch 3650/4290: AvgLoss: 2.89, S.Acc: 38.84%, E.Acc: 16.58%
# Epoch 1. Batch 3660/4290: AvgLoss: 2.89, S.Acc: 38.84%, E.Acc: 16.58%
# Epoch 1. Batch 3670/4290: AvgLoss: 2.89, S.Acc: 38.83%, E.Acc: 16.59%
# Epoch 1. Batch 3680/4290: AvgLoss: 2.89, S.Acc: 38.84%, E.Acc: 16.59%
# Epoch 1. Batch 3690/4290: AvgLoss: 2.89, S.Acc: 38.84%, E.Acc: 16.59%
# Epoch 1. Batch 3700/4290: AvgLoss: 2.89, S.Acc: 38.82%, E.Acc: 16.60%
# Epoch 1. Batch 3710/4290: AvgLoss: 2.89, S.Acc: 38.81%, E.Acc: 16.59%
# Epoch 1. Batch 3720/4290: AvgLoss: 2.89, S.Acc: 38.80%, E.Acc: 16.59%
# Epoch 1. Batch 3730/4290: AvgLoss: 2.89, S.Acc: 38.78%, E.Acc: 16.58%
# Epoch 1. Batch 3740/4290: AvgLoss: 2.89, S.Acc: 38.77%, E.Acc: 16.58%
# Epoch 1. Batch 3750/4290: AvgLoss: 2.89, S.Acc: 38.76%, E.Acc: 16.58%
# Epoch 1. Batch 3760/4290: AvgLoss: 2.89, S.Acc: 38.74%, E.Acc: 16.59%
# Epoch 1. Batch 3770/4290: AvgLoss: 2.89, S.Acc: 38.73%, E.Acc: 16.59%
# Epoch 1. Batch 3780/4290: AvgLoss: 2.89, S.Acc: 38.72%, E.Acc: 16.59%
# Epoch 1. Batch 3790/4290: AvgLoss: 2.89, S.Acc: 38.71%, E.Acc: 16.58%
# Epoch 1. Batch 3800/4290: AvgLoss: 2.89, S.Acc: 38.72%, E.Acc: 16.58%
# Epoch 1. Batch 3810/4290: AvgLoss: 2.89, S.Acc: 38.71%, E.Acc: 16.59%
# Epoch 1. Batch 3820/4290: AvgLoss: 2.89, S.Acc: 38.70%, E.Acc: 16.58%
# Epoch 1. Batch 3830/4290: AvgLoss: 2.89, S.Acc: 38.71%, E.Acc: 16.60%
# Epoch 1. Batch 3840/4290: AvgLoss: 2.89, S.Acc: 38.71%, E.Acc: 16.60%
# Epoch 1. Batch 3850/4290: AvgLoss: 2.89, S.Acc: 38.71%, E.Acc: 16.59%
# Epoch 1. Batch 3860/4290: AvgLoss: 2.89, S.Acc: 38.69%, E.Acc: 16.61%
# Epoch 1. Batch 3870/4290: AvgLoss: 2.89, S.Acc: 38.68%, E.Acc: 16.60%
# Epoch 1. Batch 3880/4290: AvgLoss: 2.89, S.Acc: 38.67%, E.Acc: 16.62%
# Epoch 1. Batch 3890/4290: AvgLoss: 2.89, S.Acc: 38.66%, E.Acc: 16.62%
# Epoch 1. Batch 3900/4290: AvgLoss: 2.89, S.Acc: 38.65%, E.Acc: 16.61%
# Epoch 1. Batch 3910/4290: AvgLoss: 2.89, S.Acc: 38.65%, E.Acc: 16.61%
# Epoch 1. Batch 3920/4290: AvgLoss: 2.89, S.Acc: 38.63%, E.Acc: 16.60%
# Epoch 1. Batch 3930/4290: AvgLoss: 2.89, S.Acc: 38.63%, E.Acc: 16.60%
# Epoch 1. Batch 3940/4290: AvgLoss: 2.89, S.Acc: 38.62%, E.Acc: 16.61%
# Epoch 1. Batch 3950/4290: AvgLoss: 2.89, S.Acc: 38.60%, E.Acc: 16.62%
# Epoch 1. Batch 3960/4290: AvgLoss: 2.89, S.Acc: 38.60%, E.Acc: 16.63%
# Epoch 1. Batch 3970/4290: AvgLoss: 2.89, S.Acc: 38.59%, E.Acc: 16.63%
# Epoch 1. Batch 3980/4290: AvgLoss: 2.89, S.Acc: 38.57%, E.Acc: 16.61%
# Epoch 1. Batch 3990/4290: AvgLoss: 2.89, S.Acc: 38.58%, E.Acc: 16.62%
# Epoch 1. Batch 4000/4290: AvgLoss: 2.89, S.Acc: 38.61%, E.Acc: 16.62%
# Epoch 1. Batch 4010/4290: AvgLoss: 2.89, S.Acc: 38.61%, E.Acc: 16.62%
# Epoch 1. Batch 4020/4290: AvgLoss: 2.89, S.Acc: 38.62%, E.Acc: 16.62%
# Epoch 1. Batch 4030/4290: AvgLoss: 2.89, S.Acc: 38.64%, E.Acc: 16.62%
# Epoch 1. Batch 4040/4290: AvgLoss: 2.89, S.Acc: 38.65%, E.Acc: 16.62%
# Epoch 1. Batch 4050/4290: AvgLoss: 2.89, S.Acc: 38.67%, E.Acc: 16.62%
# Epoch 1. Batch 4060/4290: AvgLoss: 2.89, S.Acc: 38.67%, E.Acc: 16.61%
# Epoch 1. Batch 4070/4290: AvgLoss: 2.89, S.Acc: 38.69%, E.Acc: 16.61%
# Epoch 1. Batch 4080/4290: AvgLoss: 2.89, S.Acc: 38.71%, E.Acc: 16.61%
# Epoch 1. Batch 4090/4290: AvgLoss: 2.89, S.Acc: 38.73%, E.Acc: 16.60%
# Epoch 1. Batch 4100/4290: AvgLoss: 2.89, S.Acc: 38.73%, E.Acc: 16.60%
# Epoch 1. Batch 4110/4290: AvgLoss: 2.89, S.Acc: 38.73%, E.Acc: 16.61%
# Epoch 1. Batch 4120/4290: AvgLoss: 2.89, S.Acc: 38.75%, E.Acc: 16.60%
# Epoch 1. Batch 4130/4290: AvgLoss: 2.89, S.Acc: 38.76%, E.Acc: 16.60%
# Epoch 1. Batch 4140/4290: AvgLoss: 2.89, S.Acc: 38.76%, E.Acc: 16.60%
# Epoch 1. Batch 4150/4290: AvgLoss: 2.89, S.Acc: 38.76%, E.Acc: 16.60%
# Epoch 1. Batch 4160/4290: AvgLoss: 2.89, S.Acc: 38.77%, E.Acc: 16.61%
# Epoch 1. Batch 4170/4290: AvgLoss: 2.89, S.Acc: 38.79%, E.Acc: 16.63%
# Epoch 1. Batch 4180/4290: AvgLoss: 2.89, S.Acc: 38.79%, E.Acc: 16.63%
# Epoch 1. Batch 4190/4290: AvgLoss: 2.89, S.Acc: 38.82%, E.Acc: 16.63%
# Epoch 1. Batch 4200/4290: AvgLoss: 2.89, S.Acc: 38.83%, E.Acc: 16.63%
# Epoch 1. Batch 4210/4290: AvgLoss: 2.89, S.Acc: 38.85%, E.Acc: 16.63%
# Epoch 1. Batch 4220/4290: AvgLoss: 2.89, S.Acc: 38.87%, E.Acc: 16.63%
# Epoch 1. Batch 4230/4290: AvgLoss: 2.89, S.Acc: 38.89%, E.Acc: 16.63%
# Epoch 1. Batch 4240/4290: AvgLoss: 2.89, S.Acc: 38.89%, E.Acc: 16.63%
# Epoch 1. Batch 4250/4290: AvgLoss: 2.89, S.Acc: 38.89%, E.Acc: 16.63%
# Epoch 1. Batch 4260/4290: AvgLoss: 2.89, S.Acc: 38.89%, E.Acc: 16.63%
# Epoch 1. Batch 4270/4290: AvgLoss: 2.89, S.Acc: 38.90%, E.Acc: 16.63%
# Epoch 1. Batch 4280/4290: AvgLoss: 2.89, S.Acc: 38.92%, E.Acc: 16.63%
# Train Loss: 2.8907, Train Sentiment Accuracy: 38.92%, Train Emotion Accuracy: 16.63%
# Validation Sentiment Accuracy: 42.72%, Validation Emotion Accuracy: 17.00%

# %% [markdown]
# # Model evaluation

# %%
test_acc_sent, test_acc_emot = eval_model(model, test_loader, device)

print(f"Test Sentiment Accuracy: {test_acc_sent:.2f}%")
print(f"Test Emotion Accuracy: {test_acc_emot:.2f}%")
# Out:
# Test Sentiment Accuracy: 42.69%
# Test Emotion Accuracy: 17.00%

# %% [markdown]
# # Summary
#
# | Epoch        | Train Accuracy Sentiment | Validation Accuracy Sentiment | Train Accuracy Emotion | Validation Accuracy Emotion |
# |--------------|--------------------------|-------------------------------|------------------------|-----------------------------|
# | **Epoch 1**  | 38.65%                   | 34.34%                        | 16.94%                 | 17.00%                      |
# | **Epoch 2**  | 38.92%                   | 42.72%                        | 16.63%                 | 17.00%                      |
#
# ### Observation
# * The training accuracy for both sentiment and emotion classification remains virtually unchanged across epochs.

# %% [markdown]
# # Model serialization

# %%
torch.save(model.state_dict(), './LSTM_multitask_model/lstm_multitask_model.pth')
